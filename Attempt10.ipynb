# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavdayal/EIP_Session4/blob/master/Attempt10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, NumpyArrayIterator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import numpy as np
import os
# Out:
# TensorFlow 2.x selected.

# %%
# Training parameters
batch_size = 128
epochs = 50
data_augmentation = False
num_classes = 10

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=False,
                 dropout=0.1):
  
    #TODO: add dropout
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  use_bias=False,
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2_block(x, num_filters, downscale=False, first=False):
  
  # Residual path
  if first:
    y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1), batch_normalization=False, activation=None) # already getting activated input!
  else:  
    y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1))
  y = resnet_layer(inputs=y, num_filters=num_filters)

  # identity. Need to match the output for addition
  if first or downscale:
    x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1, strides = (2 if downscale else 1),  batch_normalization=False, activation=None)

  # add
  x = keras.layers.add([x, y])

  return x

# %%
def resnet_v2(input_shape, res_blocks, num_classes=10):
    # Start model definition.
    num_filters = 16

    inputs = Input(shape=input_shape)

    # first convolution before Resnet starts.
    # Should this be done, because we dont want to modify the input
    # But in actual resnet they are doing 7x7, may be they are not doing BN or activation here!!!
    x = resnet_layer(inputs=inputs, num_filters=num_filters)

    # Instantiate the stack of residual units
    for i, blockcount in enumerate(res_blocks):
        num_filters = num_filters*2
        #num_filters *= 2
        for layer in range(blockcount):
          x = resnet_v2_block(x, num_filters=num_filters, downscale=i>0 and layer==0, first = layer==0 and i==0)

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes,
                    activation='softmax', use_bias=False,
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def lr_schedule(epoch):
    lr = round(0.01 * 1/(1 + 0.219 * epoch), 10)
    print('Learning rate: ', lr)
    return lr
    
model = resnet_v2(input_shape=input_shape, res_blocks=(2, 2, 2, 2))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# Learning rate:  0.01
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 3)    12          dropout[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 3)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   432         activation[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 16)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   4608        dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 16)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   512         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   9216        activation_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 32)   0           conv2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   9216        activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32, 32, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9216        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           add[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 32)   128         dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   18432       activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 64)   256         dropout_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32, 32, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   2048        dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   36864       activation_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 64)   0           conv2d_8[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 16, 16, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 64)   256         dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   36864       activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 16, 16, 64)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 64)   256         dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36864       activation_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 64)   0           add_2[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 16, 16, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 128)    73728       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 128)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 128)    512         dropout_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 128)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 128)    8192        dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 128)    147456      activation_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 128)    0           conv2d_13[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 8, 8, 128)    0           add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 128)    512         dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    147456      activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 8, 8, 128)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 128)    512         dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    147456      activation_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 128)    0           add_4[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 8, 8, 128)    0           add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 128)    512         dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 128)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 256)    294912      activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 4, 4, 256)    0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 256)    1024        dropout_17[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 8, 8, 128)    0           add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 256)    32768       dropout_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 256)    589824      activation_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 256)    0           conv2d_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 4, 4, 256)    0           add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 256)    1024        dropout_19[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 256)    589824      activation_14[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 4, 4, 256)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 256)    1024        dropout_20[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    589824      activation_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 256)    0           add_6[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 256)    1024        add_7[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           2560        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 2,795,964
# Trainable params: 2,792,118
# Non-trainable params: 3,846
# __________________________________________________________________________________________________

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_Resnet18.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
    
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w # area of cutout
            r = np.random.uniform(r_1, r_2) # 
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=20,
        # randomly shift images horizontally
        width_shift_range=0.2,
        # randomly shift images vertically
        height_shift_range=0.2,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.2,
        # set range for random channel shifts
        channel_shift_range=0.2,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=True),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    #datagen.fit(x_train)

    train_iter = NumpyArrayIterator(x=x_train, y=y_train, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    val_iter = NumpyArrayIterator(x=x_test, y=y_test, image_data_generator=datagen, batch_size=batch_size, shuffle=True)

    model.fit_generator(generator = train_iter,
                        steps_per_epoch = (x_train.shape[0]//batch_size), epochs = 50, 
                        validation_data = val_iter, verbose=1, workers=4, callbacks=callbacks)
# Out:
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Learning rate:  0.01
# Epoch 1/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.9459 - accuracy: 0.3491
# Epoch 00001: val_accuracy improved from -inf to 0.25520, saving model to /content/saved_models/cifar10_Tesnet18.001.h5
# 50000/50000 [==============================] - 62s 1ms/sample - loss: 1.9452 - accuracy: 0.3493 - val_loss: 2.3773 - val_accuracy: 0.2552
# Learning rate:  0.0082034454
# Epoch 2/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.5649 - accuracy: 0.4859
# Epoch 00002: val_accuracy improved from 0.25520 to 0.45290, saving model to /content/saved_models/cifar10_Tesnet18.002.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.5648 - accuracy: 0.4859 - val_loss: 1.6261 - val_accuracy: 0.4529
# Learning rate:  0.0069541029
# Epoch 3/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.4275 - accuracy: 0.5433
# Epoch 00003: val_accuracy improved from 0.45290 to 0.48370, saving model to /content/saved_models/cifar10_Tesnet18.003.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.4273 - accuracy: 0.5433 - val_loss: 1.6971 - val_accuracy: 0.4837
# Learning rate:  0.006035003
# Epoch 4/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.3364 - accuracy: 0.5750
# Epoch 00004: val_accuracy improved from 0.48370 to 0.54740, saving model to /content/saved_models/cifar10_Tesnet18.004.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.3366 - accuracy: 0.5749 - val_loss: 1.4178 - val_accuracy: 0.5474
# Learning rate:  0.0053304904
# Epoch 5/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.2662 - accuracy: 0.6004
# Epoch 00005: val_accuracy improved from 0.54740 to 0.56410, saving model to /content/saved_models/cifar10_Tesnet18.005.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.2667 - accuracy: 0.6002 - val_loss: 1.3467 - val_accuracy: 0.5641
# Learning rate:  0.0047732697
# Epoch 6/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.2105 - accuracy: 0.6191
# Epoch 00006: val_accuracy did not improve from 0.56410
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.2104 - accuracy: 0.6192 - val_loss: 1.6153 - val_accuracy: 0.5024
# Learning rate:  0.0043215212
# Epoch 7/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.1726 - accuracy: 0.6330
# Epoch 00007: val_accuracy did not improve from 0.56410
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.1728 - accuracy: 0.6329 - val_loss: 1.4905 - val_accuracy: 0.5097
# Learning rate:  0.0039478879
# Epoch 8/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.1327 - accuracy: 0.6465
# Epoch 00008: val_accuracy improved from 0.56410 to 0.58750, saving model to /content/saved_models/cifar10_Tesnet18.008.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.1330 - accuracy: 0.6464 - val_loss: 1.3441 - val_accuracy: 0.5875
# Learning rate:  0.0036337209
# Epoch 9/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.0966 - accuracy: 0.6607
# Epoch 00009: val_accuracy did not improve from 0.58750
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.0968 - accuracy: 0.6606 - val_loss: 1.5133 - val_accuracy: 0.5432
# Learning rate:  0.0033658701
# Epoch 10/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.0706 - accuracy: 0.6703
# Epoch 00010: val_accuracy did not improve from 0.58750
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.0707 - accuracy: 0.6703 - val_loss: 1.6696 - val_accuracy: 0.5057
# Learning rate:  0.0031347962
# Epoch 11/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.0431 - accuracy: 0.6797
# Epoch 00011: val_accuracy did not improve from 0.58750
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.0432 - accuracy: 0.6796 - val_loss: 1.5615 - val_accuracy: 0.5282
# Learning rate:  0.0029334116
# Epoch 12/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.0174 - accuracy: 0.6885
# Epoch 00012: val_accuracy did not improve from 0.58750
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.0178 - accuracy: 0.6883 - val_loss: 1.5124 - val_accuracy: 0.5812
# Learning rate:  0.0027563396
# Epoch 13/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.9933 - accuracy: 0.7002
# Epoch 00013: val_accuracy did not improve from 0.58750
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.9933 - accuracy: 0.7002 - val_loss: 1.5343 - val_accuracy: 0.5666
# Learning rate:  0.0025994281
# Epoch 14/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.9654 - accuracy: 0.7073
# Epoch 00014: val_accuracy improved from 0.58750 to 0.65590, saving model to /content/saved_models/cifar10_Tesnet18.014.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.9653 - accuracy: 0.7073 - val_loss: 1.1284 - val_accuracy: 0.6559
# Learning rate:  0.0024594196
# Epoch 15/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.9450 - accuracy: 0.7181
# Epoch 00015: val_accuracy improved from 0.65590 to 0.66840, saving model to /content/saved_models/cifar10_Tesnet18.015.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.9450 - accuracy: 0.7181 - val_loss: 1.1271 - val_accuracy: 0.6684
# Learning rate:  0.0023337223
# Epoch 16/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.9206 - accuracy: 0.7232
# Epoch 00016: val_accuracy improved from 0.66840 to 0.67260, saving model to /content/saved_models/cifar10_Tesnet18.016.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.9205 - accuracy: 0.7232 - val_loss: 1.0949 - val_accuracy: 0.6726
# Learning rate:  0.0022202487
# Epoch 17/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.9018 - accuracy: 0.7308
# Epoch 00017: val_accuracy did not improve from 0.67260
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.9018 - accuracy: 0.7308 - val_loss: 1.2877 - val_accuracy: 0.6293
# Learning rate:  0.0021172983
# Epoch 18/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.8846 - accuracy: 0.7393
# Epoch 00018: val_accuracy did not improve from 0.67260
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.8847 - accuracy: 0.7392 - val_loss: 1.3561 - val_accuracy: 0.6206
# Learning rate:  0.0020234723
# Epoch 19/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.8571 - accuracy: 0.7472
# Epoch 00019: val_accuracy did not improve from 0.67260
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.8571 - accuracy: 0.7472 - val_loss: 1.2084 - val_accuracy: 0.6531
# Learning rate:  0.001937609
# Epoch 20/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.8413 - accuracy: 0.7538
# Epoch 00020: val_accuracy improved from 0.67260 to 0.70060, saving model to /content/saved_models/cifar10_Tesnet18.020.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.8415 - accuracy: 0.7537 - val_loss: 0.9806 - val_accuracy: 0.7006
# Learning rate:  0.0018587361
# Epoch 21/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.8254 - accuracy: 0.7578
# Epoch 00021: val_accuracy did not improve from 0.70060
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.8251 - accuracy: 0.7579 - val_loss: 1.0689 - val_accuracy: 0.6820
# Learning rate:  0.0017860332
# Epoch 22/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.8032 - accuracy: 0.7646
# Epoch 00022: val_accuracy did not improve from 0.70060
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.8032 - accuracy: 0.7646 - val_loss: 1.1125 - val_accuracy: 0.6937
# Learning rate:  0.0017188037
# Epoch 23/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7863 - accuracy: 0.7722
# Epoch 00023: val_accuracy did not improve from 0.70060
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.7865 - accuracy: 0.7721 - val_loss: 1.1202 - val_accuracy: 0.6968
# Learning rate:  0.0016564519
# Epoch 24/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7716 - accuracy: 0.7757
# Epoch 00024: val_accuracy improved from 0.70060 to 0.73770, saving model to /content/saved_models/cifar10_Tesnet18.024.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.7716 - accuracy: 0.7756 - val_loss: 0.9610 - val_accuracy: 0.7377
# Learning rate:  0.0015984655
# Epoch 25/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7541 - accuracy: 0.7830
# Epoch 00025: val_accuracy did not improve from 0.73770
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.7541 - accuracy: 0.7830 - val_loss: 0.9977 - val_accuracy: 0.7262
# Learning rate:  0.0015444015
# Epoch 26/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7451 - accuracy: 0.7854
# Epoch 00026: val_accuracy improved from 0.73770 to 0.76030, saving model to /content/saved_models/cifar10_Tesnet18.026.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.7452 - accuracy: 0.7854 - val_loss: 0.8590 - val_accuracy: 0.7603
# Learning rate:  0.0014938751
# Epoch 27/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7323 - accuracy: 0.7891
# Epoch 00027: val_accuracy did not improve from 0.76030
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.7323 - accuracy: 0.7891 - val_loss: 1.2410 - val_accuracy: 0.6508
# Learning rate:  0.00144655
# Epoch 28/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7173 - accuracy: 0.7947
# Epoch 00028: val_accuracy did not improve from 0.76030
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.7173 - accuracy: 0.7947 - val_loss: 0.9115 - val_accuracy: 0.7504
# Learning rate:  0.0014021312
# Epoch 29/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7083 - accuracy: 0.7966
# Epoch 00029: val_accuracy did not improve from 0.76030
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.7084 - accuracy: 0.7965 - val_loss: 0.9925 - val_accuracy: 0.7141
# Learning rate:  0.0013603591
# Epoch 30/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6975 - accuracy: 0.7995
# Epoch 00030: val_accuracy did not improve from 0.76030
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.6975 - accuracy: 0.7995 - val_loss: 1.0056 - val_accuracy: 0.7357
# Learning rate:  0.001321004
# Epoch 31/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.8065
# Epoch 00031: val_accuracy did not improve from 0.76030
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.6863 - accuracy: 0.8066 - val_loss: 0.9048 - val_accuracy: 0.7454
# Learning rate:  0.0012838619
# Epoch 32/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6763 - accuracy: 0.8078
# Epoch 00032: val_accuracy did not improve from 0.76030
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.6762 - accuracy: 0.8078 - val_loss: 1.1045 - val_accuracy: 0.7190
# Learning rate:  0.0012487512
# Epoch 33/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6671 - accuracy: 0.8104
# Epoch 00033: val_accuracy did not improve from 0.76030
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.6670 - accuracy: 0.8104 - val_loss: 0.9932 - val_accuracy: 0.7239
# Learning rate:  0.0012155099
# Epoch 34/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6610 - accuracy: 0.8109
# Epoch 00034: val_accuracy did not improve from 0.76030
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.6612 - accuracy: 0.8108 - val_loss: 1.1191 - val_accuracy: 0.6996
# Learning rate:  0.0011839924
# Epoch 35/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6522 - accuracy: 0.8171
# Epoch 00035: val_accuracy improved from 0.76030 to 0.76360, saving model to /content/saved_models/cifar10_Tesnet18.035.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.6523 - accuracy: 0.8171 - val_loss: 0.8494 - val_accuracy: 0.7636
# Learning rate:  0.0011540681
# Epoch 36/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6433 - accuracy: 0.8185
# Epoch 00036: val_accuracy improved from 0.76360 to 0.76820, saving model to /content/saved_models/cifar10_Tesnet18.036.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.6431 - accuracy: 0.8186 - val_loss: 0.8221 - val_accuracy: 0.7682
# Learning rate:  0.0011256191
# Epoch 37/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6349 - accuracy: 0.8216
# Epoch 00037: val_accuracy improved from 0.76820 to 0.79310, saving model to /content/saved_models/cifar10_Tesnet18.037.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.6346 - accuracy: 0.8218 - val_loss: 0.7903 - val_accuracy: 0.7931
# Learning rate:  0.0010985389
# Epoch 38/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6251 - accuracy: 0.8241
# Epoch 00038: val_accuracy did not improve from 0.79310
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.6252 - accuracy: 0.8241 - val_loss: 0.8684 - val_accuracy: 0.7576
# Learning rate:  0.0010727312
# Epoch 39/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6218 - accuracy: 0.8285
# Epoch 00039: val_accuracy did not improve from 0.79310
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.6221 - accuracy: 0.8284 - val_loss: 0.8515 - val_accuracy: 0.7721
# Learning rate:  0.0010481082
# Epoch 40/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6115 - accuracy: 0.8300
# Epoch 00040: val_accuracy did not improve from 0.79310
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.6115 - accuracy: 0.8300 - val_loss: 0.9326 - val_accuracy: 0.7554
# Learning rate:  0.0010245902
# Epoch 41/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6047 - accuracy: 0.8322
# Epoch 00041: val_accuracy did not improve from 0.79310
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.6046 - accuracy: 0.8322 - val_loss: 0.8377 - val_accuracy: 0.7681
# Learning rate:  0.0010021044
# Epoch 42/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5987 - accuracy: 0.8314
# Epoch 00042: val_accuracy did not improve from 0.79310
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.5987 - accuracy: 0.8315 - val_loss: 0.8568 - val_accuracy: 0.7692
# Learning rate:  0.0009805844
# Epoch 43/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5940 - accuracy: 0.8358
# Epoch 00043: val_accuracy did not improve from 0.79310
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.5940 - accuracy: 0.8358 - val_loss: 0.7860 - val_accuracy: 0.7875
# Learning rate:  0.0009599693
# Epoch 44/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5891 - accuracy: 0.8344
# Epoch 00044: val_accuracy did not improve from 0.79310
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.5889 - accuracy: 0.8345 - val_loss: 0.8146 - val_accuracy: 0.7848
# Learning rate:  0.0009402031
# Epoch 45/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5807 - accuracy: 0.8383
# Epoch 00045: val_accuracy did not improve from 0.79310
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.5805 - accuracy: 0.8384 - val_loss: 0.7805 - val_accuracy: 0.7837
# Learning rate:  0.0009212345
# Epoch 46/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5790 - accuracy: 0.8397
# Epoch 00046: val_accuracy did not improve from 0.79310
# 50000/50000 [==============================] - 51s 1ms/sample - loss: 0.5792 - accuracy: 0.8397 - val_loss: 0.7481 - val_accuracy: 0.7908
# Learning rate:  0.0009030161
# Epoch 47/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5683 - accuracy: 0.8422
# Epoch 00047: val_accuracy did not improve from 0.79310
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.5680 - accuracy: 0.8424 - val_loss: 0.7986 - val_accuracy: 0.7827
# Learning rate:  0.0008855043
# Epoch 48/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5627 - accuracy: 0.8428
# Epoch 00048: val_accuracy improved from 0.79310 to 0.81210, saving model to /content/saved_models/cifar10_Tesnet18.048.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 0.5627 - accuracy: 0.8429 - val_loss: 0.6900 - val_accuracy: 0.8121
# Learning rate:  0.0008686588
# Epoch 49/50
# 44544/50000 [=========================>....] - ETA: 5s - loss: 0.5536 - accuracy: 0.8454

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
