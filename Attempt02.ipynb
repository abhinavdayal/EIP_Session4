# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavdayal/EIP_Session4/blob/master/Attempt02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, NumpyArrayIterator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import numpy as np
import os
# Out:
# TensorFlow 2.x selected.

# %%
# Training parameters
batch_size = 256
epochs = 50
data_augmentation = True
num_classes = 10

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def lr_schedule(epoch):
    lr = round(0.01 * 1/(1 + 0.319 * epoch), 10)
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=False,
                 dropout=0):
  
    #TODO: add dropout
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  use_bias=False,
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2_block(x, num_filters_in, num_filters_out, downscale=False, first=False):
  
  # Residual path
  if first:
    y = resnet_layer(inputs=x, kernel_size=1, num_filters=num_filters_in, strides = (2 if downscale else 1), batch_normalization=False, activation=None)
  else:
    y = resnet_layer(inputs=x, kernel_size=1, num_filters=num_filters_in, strides = (2 if downscale else 1))
  y = resnet_layer(inputs=y, num_filters=num_filters_in)
  y = resnet_layer(inputs=y, kernel_size=1, num_filters=num_filters_out)

  # identity. Need to match the output for addition
  if first or downscale:
    x = resnet_layer(inputs=x, num_filters=num_filters_out, kernel_size=1, strides = (2 if downscale else 1),  batch_normalization=False, activation=None)

  # add
  x = keras.layers.add([x, y])

  return x

# %%
def resnet_v2(input_shape, res_blocks, num_classes=10):
    # Start model definition.
    num_filters = 16

    inputs = Input(shape=input_shape)

    # first convolution before Resnet starts.
    # Should this be done, because we dont want to modify the input
    # But in actual resnet they are doing 7x7, may be they are not doing BN or activation here!!!
    x = resnet_layer(inputs=inputs, num_filters=num_filters)

    # Instantiate the stack of residual units
    for i, blockcount in enumerate(res_blocks):
        for layer in range(blockcount):
          x = resnet_v2_block(x, num_filters_in=num_filters, num_filters_out=num_filters*2, downscale=i>0 and layer==0, first = layer==0 and i==0)

        num_filters *= 2

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=4)(x)
    x = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax', use_bias=False,
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v2(input_shape=input_shape, res_blocks=(2, 2, 2, 2))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# Learning rate:  0.01
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 3)    12          input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 3)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   432         activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2304        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   512         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   512         activation_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 32)   0           conv2d_4[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         add[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   512         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   2304        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 32)   512         activation_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           add[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32)   128         add_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 32)   1024        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 32)   9216        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   2048        add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   2048        activation_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 64)   0           conv2d_11[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   2048        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9216        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   2048        activation_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 64)   0           add_2[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     4096        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 64)     0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 64)     36864       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 64)     256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 64)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 128)    8192        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 128)    8192        activation_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 128)    0           conv2d_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 128)    512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     8192        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 64)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     36864       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 64)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 128)    8192        activation_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 128)    0           add_4[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 128)    512         add_5[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 128)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 128)    16384       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 128)    512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, 4, 128)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 4, 4, 128)    147456      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 4, 4, 128)    512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, 4, 128)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 4, 4, 256)    32768       add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 4, 4, 256)    32768       activation_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 256)    0           conv2d_25[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, 4, 256)    1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4, 4, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 4, 4, 128)    32768       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, 4, 128)    512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 4, 4, 128)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 4, 4, 128)    147456      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, 4, 128)    512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, 4, 128)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 4, 4, 256)    32768       activation_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 256)    0           add_6[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 4, 4, 256)    1024        add_7[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, 4, 256)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 256)    0           activation_24[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           2560        flatten[0][0]
# ==================================================================================================
# Total params: 598,204
# Trainable params: 594,358
# Non-trainable params: 3,846
# __________________________________________________________________________________________________

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_Tesnet18.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w # area of cutout
            r = np.random.uniform(r_1, r_2) # 
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=True,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=True,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=20,
        # randomly shift images horizontally
        width_shift_range=0.2,
        # randomly shift images vertically
        height_shift_range=0.2,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.2,
        # set range for random channel shifts
        channel_shift_range=0.2,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=True),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    train_iter = NumpyArrayIterator(x=x_train, y=y_train, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    val_iter = NumpyArrayIterator(x=x_test, y=y_test, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    

    # Fit the model on the batches generated by datagen.flow().
    #model.fit_generator(,
    #                    val_iter,
    #                    epochs=epochs, verbose=1, workers=4,
    #                   callbacks=callbacks)
    model.fit_generator(generator = train_iter,
                        steps_per_epoch = (x_train.shape[0]//batch_size), epochs = 50, 
                        validation_data = val_iter, verbose=1, workers=4, callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Learning rate:  0.01
# Epoch 1/50
# 194/195 [============================>.] - ETA: 0s - loss: 2.1167 - accuracy: 0.3037
# Epoch 00001: val_accuracy improved from -inf to 0.27060, saving model to /content/saved_models/cifar10_Tesnet18.001.h5
# 195/195 [==============================] - 134s 689ms/step - loss: 2.1157 - accuracy: 0.3039 - val_loss: 2.1292 - val_accuracy: 0.2706
# Learning rate:  0.0075815011
# Epoch 2/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.6967 - accuracy: 0.4296
# Epoch 00002: val_accuracy improved from 0.27060 to 0.35470, saving model to /content/saved_models/cifar10_Tesnet18.002.h5
# 195/195 [==============================] - 134s 686ms/step - loss: 1.6962 - accuracy: 0.4299 - val_loss: 1.9023 - val_accuracy: 0.3547
# Learning rate:  0.0061050061
# Epoch 3/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.5501 - accuracy: 0.4867
# Epoch 00003: val_accuracy improved from 0.35470 to 0.40110, saving model to /content/saved_models/cifar10_Tesnet18.003.h5
# 195/195 [==============================] - 134s 688ms/step - loss: 1.5496 - accuracy: 0.4868 - val_loss: 1.7796 - val_accuracy: 0.4011
# Learning rate:  0.005109862
# Epoch 4/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.4568 - accuracy: 0.5205
# Epoch 00004: val_accuracy did not improve from 0.40110
# 195/195 [==============================] - 132s 675ms/step - loss: 1.4573 - accuracy: 0.5205 - val_loss: 1.8993 - val_accuracy: 0.3911
# Learning rate:  0.0043936731
# Epoch 5/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.3802 - accuracy: 0.5554
# Epoch 00005: val_accuracy did not improve from 0.40110
# 195/195 [==============================] - 133s 684ms/step - loss: 1.3808 - accuracy: 0.5551 - val_loss: 1.9473 - val_accuracy: 0.3877
# Learning rate:  0.0038535645
# Epoch 6/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.3339 - accuracy: 0.5698
# Epoch 00006: val_accuracy improved from 0.40110 to 0.45800, saving model to /content/saved_models/cifar10_Tesnet18.006.h5
# 195/195 [==============================] - 133s 683ms/step - loss: 1.3336 - accuracy: 0.5698 - val_loss: 1.6100 - val_accuracy: 0.4580
# Learning rate:  0.003431709
# Epoch 7/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.2843 - accuracy: 0.5900
# Epoch 00007: val_accuracy improved from 0.45800 to 0.49020, saving model to /content/saved_models/cifar10_Tesnet18.007.h5
# 195/195 [==============================] - 134s 685ms/step - loss: 1.2839 - accuracy: 0.5901 - val_loss: 1.6369 - val_accuracy: 0.4902
# Learning rate:  0.0030931024
# Epoch 8/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.2433 - accuracy: 0.6028
# Epoch 00008: val_accuracy improved from 0.49020 to 0.50140, saving model to /content/saved_models/cifar10_Tesnet18.008.h5
# 195/195 [==============================] - 133s 681ms/step - loss: 1.2435 - accuracy: 0.6027 - val_loss: 1.5928 - val_accuracy: 0.5014
# Learning rate:  0.0028153153
# Epoch 9/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.2020 - accuracy: 0.6179
# Epoch 00009: val_accuracy improved from 0.50140 to 0.54790, saving model to /content/saved_models/cifar10_Tesnet18.009.h5
# 195/195 [==============================] - 132s 679ms/step - loss: 1.2016 - accuracy: 0.6180 - val_loss: 1.3670 - val_accuracy: 0.5479
# Learning rate:  0.0025833118
# Epoch 10/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.1745 - accuracy: 0.6302
# Epoch 00010: val_accuracy improved from 0.54790 to 0.58150, saving model to /content/saved_models/cifar10_Tesnet18.010.h5
# 195/195 [==============================] - 134s 687ms/step - loss: 1.1748 - accuracy: 0.6302 - val_loss: 1.3188 - val_accuracy: 0.5815
# Learning rate:  0.0023866348
# Epoch 11/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.1447 - accuracy: 0.6404
# Epoch 00011: val_accuracy did not improve from 0.58150
# 195/195 [==============================] - 133s 680ms/step - loss: 1.1447 - accuracy: 0.6406 - val_loss: 1.8500 - val_accuracy: 0.4647
# Learning rate:  0.0022177866
# Epoch 12/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.1081 - accuracy: 0.6524
# Epoch 00012: val_accuracy improved from 0.58150 to 0.59420, saving model to /content/saved_models/cifar10_Tesnet18.012.h5
# 195/195 [==============================] - 134s 686ms/step - loss: 1.1079 - accuracy: 0.6525 - val_loss: 1.3000 - val_accuracy: 0.5942
# Learning rate:  0.002071251
# Epoch 13/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.0844 - accuracy: 0.6612
# Epoch 00013: val_accuracy improved from 0.59420 to 0.59540, saving model to /content/saved_models/cifar10_Tesnet18.013.h5
# 195/195 [==============================] - 132s 677ms/step - loss: 1.0851 - accuracy: 0.6610 - val_loss: 1.2559 - val_accuracy: 0.5954
# Learning rate:  0.0019428793
# Epoch 14/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.0638 - accuracy: 0.6695
# Epoch 00014: val_accuracy did not improve from 0.59540
# 195/195 [==============================] - 131s 671ms/step - loss: 1.0633 - accuracy: 0.6697 - val_loss: 1.3810 - val_accuracy: 0.5645
# Learning rate:  0.0018294914
# Epoch 15/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.0399 - accuracy: 0.6770
# Epoch 00015: val_accuracy improved from 0.59540 to 0.64660, saving model to /content/saved_models/cifar10_Tesnet18.015.h5
# 195/195 [==============================] - 131s 672ms/step - loss: 1.0398 - accuracy: 0.6769 - val_loss: 1.1166 - val_accuracy: 0.6466
# Learning rate:  0.0017286085
# Epoch 16/50
# 194/195 [============================>.] - ETA: 0s - loss: 1.0158 - accuracy: 0.6864
# Epoch 00016: val_accuracy did not improve from 0.64660
# 195/195 [==============================] - 131s 673ms/step - loss: 1.0161 - accuracy: 0.6863 - val_loss: 1.2512 - val_accuracy: 0.6029
# Learning rate:  0.00163827
# Epoch 17/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.9947 - accuracy: 0.6927
# Epoch 00017: val_accuracy did not improve from 0.64660
# 195/195 [==============================] - 132s 676ms/step - loss: 0.9939 - accuracy: 0.6928 - val_loss: 1.2063 - val_accuracy: 0.6176
# Learning rate:  0.0015569049
# Epoch 18/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.9782 - accuracy: 0.6982
# Epoch 00018: val_accuracy did not improve from 0.64660
# 195/195 [==============================] - 130s 668ms/step - loss: 0.9780 - accuracy: 0.6983 - val_loss: 1.2218 - val_accuracy: 0.6280
# Learning rate:  0.0014832394
# Epoch 19/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.9651 - accuracy: 0.7033
# Epoch 00019: val_accuracy improved from 0.64660 to 0.64960, saving model to /content/saved_models/cifar10_Tesnet18.019.h5
# 195/195 [==============================] - 133s 683ms/step - loss: 0.9652 - accuracy: 0.7033 - val_loss: 1.1231 - val_accuracy: 0.6496
# Learning rate:  0.00141623
# Epoch 20/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.9540 - accuracy: 0.7062
# Epoch 00020: val_accuracy improved from 0.64960 to 0.67340, saving model to /content/saved_models/cifar10_Tesnet18.020.h5
# 195/195 [==============================] - 132s 679ms/step - loss: 0.9537 - accuracy: 0.7065 - val_loss: 1.0441 - val_accuracy: 0.6734
# Learning rate:  0.0013550136
# Epoch 21/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.9362 - accuracy: 0.7103
# Epoch 00021: val_accuracy did not improve from 0.67340
# 195/195 [==============================] - 131s 674ms/step - loss: 0.9363 - accuracy: 0.7102 - val_loss: 1.0722 - val_accuracy: 0.6622
# Learning rate:  0.00129887
# Epoch 22/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.9262 - accuracy: 0.7170
# Epoch 00022: val_accuracy did not improve from 0.67340
# 195/195 [==============================] - 132s 675ms/step - loss: 0.9262 - accuracy: 0.7170 - val_loss: 1.1848 - val_accuracy: 0.6369
# Learning rate:  0.0012471938
# Epoch 23/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.9097 - accuracy: 0.7227
# Epoch 00023: val_accuracy did not improve from 0.67340
# 195/195 [==============================] - 130s 669ms/step - loss: 0.9100 - accuracy: 0.7226 - val_loss: 1.0925 - val_accuracy: 0.6697
# Learning rate:  0.0011994722
# Epoch 24/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.9004 - accuracy: 0.7241
# Epoch 00024: val_accuracy improved from 0.67340 to 0.67920, saving model to /content/saved_models/cifar10_Tesnet18.024.h5
# 195/195 [==============================] - 133s 680ms/step - loss: 0.9004 - accuracy: 0.7242 - val_loss: 1.0492 - val_accuracy: 0.6792
# Learning rate:  0.001155268
# Epoch 25/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.8891 - accuracy: 0.7292
# Epoch 00025: val_accuracy improved from 0.67920 to 0.70630, saving model to /content/saved_models/cifar10_Tesnet18.025.h5
# 195/195 [==============================] - 131s 674ms/step - loss: 0.8893 - accuracy: 0.7293 - val_loss: 0.9475 - val_accuracy: 0.7063
# Learning rate:  0.0011142061
# Epoch 26/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.8791 - accuracy: 0.7319
# Epoch 00026: val_accuracy did not improve from 0.70630
# 195/195 [==============================] - 131s 671ms/step - loss: 0.8787 - accuracy: 0.7320 - val_loss: 1.0361 - val_accuracy: 0.6786
# Learning rate:  0.001075963
# Epoch 27/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.8626 - accuracy: 0.7377
# Epoch 00027: val_accuracy improved from 0.70630 to 0.71220, saving model to /content/saved_models/cifar10_Tesnet18.027.h5
# 195/195 [==============================] - 131s 672ms/step - loss: 0.8631 - accuracy: 0.7375 - val_loss: 0.9407 - val_accuracy: 0.7122
# Learning rate:  0.001040258
# Epoch 28/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.8552 - accuracy: 0.7424
# Epoch 00028: val_accuracy improved from 0.71220 to 0.71900, saving model to /content/saved_models/cifar10_Tesnet18.028.h5
# 195/195 [==============================] - 133s 681ms/step - loss: 0.8560 - accuracy: 0.7420 - val_loss: 0.9114 - val_accuracy: 0.7190
# Learning rate:  0.0010068466
# Epoch 29/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.8488 - accuracy: 0.7435
# Epoch 00029: val_accuracy did not improve from 0.71900
# 195/195 [==============================] - 132s 676ms/step - loss: 0.8483 - accuracy: 0.7436 - val_loss: 1.0136 - val_accuracy: 0.6887
# Learning rate:  0.0009755146
# Epoch 30/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.8369 - accuracy: 0.7476
# Epoch 00030: val_accuracy did not improve from 0.71900
# 195/195 [==============================] - 130s 669ms/step - loss: 0.8368 - accuracy: 0.7476 - val_loss: 1.0022 - val_accuracy: 0.6908
# Learning rate:  0.0009460738
# Epoch 31/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.8247 - accuracy: 0.7506
# Epoch 00031: val_accuracy did not improve from 0.71900
# 195/195 [==============================] - 133s 680ms/step - loss: 0.8246 - accuracy: 0.7507 - val_loss: 0.9289 - val_accuracy: 0.7110
# Learning rate:  0.000918358
# Epoch 32/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.8227 - accuracy: 0.7515
# Epoch 00032: val_accuracy did not improve from 0.71900
# 195/195 [==============================] - 131s 671ms/step - loss: 0.8224 - accuracy: 0.7517 - val_loss: 1.0015 - val_accuracy: 0.6830
# Learning rate:  0.0008922198
# Epoch 33/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.8193 - accuracy: 0.7533
# Epoch 00033: val_accuracy did not improve from 0.71900
# 195/195 [==============================] - 131s 674ms/step - loss: 0.8191 - accuracy: 0.7533 - val_loss: 0.9202 - val_accuracy: 0.7187
# Learning rate:  0.0008675284
# Epoch 34/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.8003 - accuracy: 0.7590
# Epoch 00034: val_accuracy did not improve from 0.71900
# 195/195 [==============================] - 131s 674ms/step - loss: 0.8000 - accuracy: 0.7591 - val_loss: 0.9557 - val_accuracy: 0.7089
# Learning rate:  0.0008441668
# Epoch 35/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.8005 - accuracy: 0.7600
# Epoch 00035: val_accuracy improved from 0.71900 to 0.73390, saving model to /content/saved_models/cifar10_Tesnet18.035.h5
# 195/195 [==============================] - 131s 672ms/step - loss: 0.8002 - accuracy: 0.7602 - val_loss: 0.8713 - val_accuracy: 0.7339
# Learning rate:  0.0008220304
# Epoch 36/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7922 - accuracy: 0.7624
# Epoch 00036: val_accuracy did not improve from 0.73390
# 195/195 [==============================] - 131s 672ms/step - loss: 0.7917 - accuracy: 0.7625 - val_loss: 0.9093 - val_accuracy: 0.7217
# Learning rate:  0.0008010253
# Epoch 37/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7929 - accuracy: 0.7616
# Epoch 00037: val_accuracy improved from 0.73390 to 0.74350, saving model to /content/saved_models/cifar10_Tesnet18.037.h5
# 195/195 [==============================] - 132s 678ms/step - loss: 0.7929 - accuracy: 0.7617 - val_loss: 0.8820 - val_accuracy: 0.7435
# Learning rate:  0.0007810669
# Epoch 38/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7808 - accuracy: 0.7645
# Epoch 00038: val_accuracy did not improve from 0.74350
# 195/195 [==============================] - 132s 678ms/step - loss: 0.7805 - accuracy: 0.7647 - val_loss: 0.9574 - val_accuracy: 0.7133
# Learning rate:  0.000762079
# Epoch 39/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7779 - accuracy: 0.7645
# Epoch 00039: val_accuracy did not improve from 0.74350
# 195/195 [==============================] - 132s 678ms/step - loss: 0.7778 - accuracy: 0.7645 - val_loss: 0.8808 - val_accuracy: 0.7294
# Learning rate:  0.0007439923
# Epoch 40/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7656 - accuracy: 0.7697
# Epoch 00040: val_accuracy improved from 0.74350 to 0.74570, saving model to /content/saved_models/cifar10_Tesnet18.040.h5
# 195/195 [==============================] - 132s 679ms/step - loss: 0.7653 - accuracy: 0.7697 - val_loss: 0.8376 - val_accuracy: 0.7457
# Learning rate:  0.0007267442
# Epoch 41/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7655 - accuracy: 0.7705
# Epoch 00041: val_accuracy did not improve from 0.74570
# 195/195 [==============================] - 132s 675ms/step - loss: 0.7656 - accuracy: 0.7704 - val_loss: 0.8890 - val_accuracy: 0.7229
# Learning rate:  0.0007102777
# Epoch 42/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7569 - accuracy: 0.7725
# Epoch 00042: val_accuracy did not improve from 0.74570
# 195/195 [==============================] - 130s 669ms/step - loss: 0.7571 - accuracy: 0.7723 - val_loss: 0.8764 - val_accuracy: 0.7322
# Learning rate:  0.0006945409
# Epoch 43/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7502 - accuracy: 0.7742
# Epoch 00043: val_accuracy did not improve from 0.74570
# 195/195 [==============================] - 132s 677ms/step - loss: 0.7496 - accuracy: 0.7744 - val_loss: 0.8834 - val_accuracy: 0.7301
# Learning rate:  0.0006794863
# Epoch 44/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7491 - accuracy: 0.7739
# Epoch 00044: val_accuracy did not improve from 0.74570
# 195/195 [==============================] - 130s 667ms/step - loss: 0.7486 - accuracy: 0.7741 - val_loss: 0.8396 - val_accuracy: 0.7400
# Learning rate:  0.0006650705
# Epoch 45/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7415 - accuracy: 0.7781
# Epoch 00045: val_accuracy did not improve from 0.74570
# 195/195 [==============================] - 133s 680ms/step - loss: 0.7416 - accuracy: 0.7781 - val_loss: 0.8621 - val_accuracy: 0.7395
# Learning rate:  0.0006512537
# Epoch 46/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7415 - accuracy: 0.7793
# Epoch 00046: val_accuracy improved from 0.74570 to 0.75760, saving model to /content/saved_models/cifar10_Tesnet18.046.h5
# 195/195 [==============================] - 132s 679ms/step - loss: 0.7416 - accuracy: 0.7792 - val_loss: 0.7976 - val_accuracy: 0.7576
# Learning rate:  0.0006379992
# Epoch 47/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7331 - accuracy: 0.7808
# Epoch 00047: val_accuracy did not improve from 0.75760
# 195/195 [==============================] - 132s 677ms/step - loss: 0.7329 - accuracy: 0.7810 - val_loss: 0.8398 - val_accuracy: 0.7462
# Learning rate:  0.0006252736
# Epoch 48/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7289 - accuracy: 0.7824
# Epoch 00048: val_accuracy did not improve from 0.75760
# 195/195 [==============================] - 132s 679ms/step - loss: 0.7292 - accuracy: 0.7823 - val_loss: 0.8515 - val_accuracy: 0.7426
# Learning rate:  0.0006130456
# Epoch 49/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7306 - accuracy: 0.7805
# Epoch 00049: val_accuracy did not improve from 0.75760
# 195/195 [==============================] - 132s 678ms/step - loss: 0.7310 - accuracy: 0.7805 - val_loss: 0.8293 - val_accuracy: 0.7535
# Learning rate:  0.0006012868
# Epoch 50/50
# 194/195 [============================>.] - ETA: 0s - loss: 0.7192 - accuracy: 0.7855
# Epoch 00050: val_accuracy improved from 0.75760 to 0.75890, saving model to /content/saved_models/cifar10_Tesnet18.050.h5
# 195/195 [==============================] - 133s 684ms/step - loss: 0.7192 - accuracy: 0.7855 - val_loss: 0.8112 - val_accuracy: 0.7589

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
