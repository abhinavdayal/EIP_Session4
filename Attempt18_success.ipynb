# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavdayal/EIP_Session4/blob/master/Attempt18_success.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, NumpyArrayIterator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import numpy as np
import os

# Training parameters
batch_size = 128
epochs = 50
data_augmentation = True
num_classes = 10

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
subtract_pixel_mean = True

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True,
                 dropout=0):
  
    #TODO: add dropout
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  use_bias=False,
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

def resnet_v1_block(x, num_filters, downscale=False, first=False):
  
  # Residual path
  y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1))
  y = resnet_layer(inputs=y, num_filters=num_filters, activation=None)

  # identity. Need to match the output for addition
  if first or downscale:
    x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1, strides = (2 if downscale else 1),  batch_normalization=False, activation=None)

  # add
  x = keras.layers.add([x, y])
  x = Activation('relu')(x)
  return x
  
def resnet_v1(input_shape, res_blocks, num_classes=10):
    # Start model definition.
    num_filters = 8

    inputs = Input(shape=input_shape)

    # first convolution before Resnet starts.
    # Should this be done, because we dont want to modify the input
    # But in actual resnet they are doing 7x7, may be they are not doing BN or activation here!!!
    x = resnet_layer(inputs=inputs, num_filters=num_filters)

    # Instantiate the stack of residual units
    for i, blockcount in enumerate(res_blocks):
        num_filters = num_filters*2
        #num_filters *= 2
        for layer in range(blockcount):
          x = resnet_v1_block(x, num_filters=num_filters, downscale=i>1 and layer==0, first = layer==0 and i<2)

    # Add classifier on top.
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes,
                    activation='softmax', use_bias=False,
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def lr_schedule(epoch):
    lr = 0.003 * pow(0.5, epoch//5)
    print("Learning rate = ", lr)
    return lr

model = resnet_v1(input_shape=input_shape, res_blocks=(2, 2, 2, 2))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_Resnet18.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)


# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w # area of cutout
            r = np.random.uniform(r_1, r_2) # 
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=20,
        # randomly shift images horizontally
        width_shift_range=0.2,
        # randomly shift images vertically
        height_shift_range=0.2,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.2,
        # set range for random channel shifts
        channel_shift_range=0,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    train_iter = NumpyArrayIterator(x=x_train, y=y_train, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    val_iter = NumpyArrayIterator(x=x_test, y=y_test, image_data_generator=datagen, batch_size=batch_size, shuffle=True)

    model.fit_generator(generator = train_iter,
                        steps_per_epoch = (x_train.shape[0]//batch_size), epochs = 50, 
                        validation_data = val_iter, verbose=1, workers=4, callbacks=callbacks)
# Out:
# TensorFlow 2.x selected.
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# Learning rate =  0.003
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 8)    216         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 8)    32          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 8)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   1152        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2304        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   128         activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 16)   0           conv2d_3[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 16)   2304        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   2304        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 16)   0           activation_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 32)   4608        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 32)   9216        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 32)   512         activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 32)   0           conv2d_8[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 32)   9216        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   9216        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 32)   0           activation_6[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   18432       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   36864       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   2048        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 64)   0           conv2d_13[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 64)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   36864       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 64)   36864       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 64)   0           activation_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 128)    73728       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 128)    512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 128)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 128)    147456      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 128)    8192        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 128)    512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 128)    0           conv2d_18[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 128)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 128)    147456      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 128)    512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 128)    147456      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 128)    0           activation_14[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 128)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           1280        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 701,688
# Trainable params: 699,752
# Non-trainable params: 1,936
# __________________________________________________________________________________________________
# Using real-time data augmentation.
# Learning rate =  0.003
# Epoch 1/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.8222 - accuracy: 0.4244
# Epoch 00001: val_accuracy improved from -inf to 0.42180, saving model to /content/saved_models/cifar10_Resnet18.001.h5
# 390/390 [==============================] - 105s 268ms/step - loss: 1.8210 - accuracy: 0.4248 - val_loss: 1.8460 - val_accuracy: 0.4218
# Learning rate =  0.003
# Epoch 2/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.4250 - accuracy: 0.5682
# Epoch 00002: val_accuracy improved from 0.42180 to 0.53080, saving model to /content/saved_models/cifar10_Resnet18.002.h5
# 390/390 [==============================] - 101s 258ms/step - loss: 1.4251 - accuracy: 0.5681 - val_loss: 1.6750 - val_accuracy: 0.5308
# Learning rate =  0.003
# Epoch 3/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2446 - accuracy: 0.6381
# Epoch 00003: val_accuracy did not improve from 0.53080
# 390/390 [==============================] - 101s 259ms/step - loss: 1.2443 - accuracy: 0.6382 - val_loss: 1.8695 - val_accuracy: 0.4893
# Learning rate =  0.003
# Epoch 4/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1627 - accuracy: 0.6772
# Epoch 00004: val_accuracy improved from 0.53080 to 0.61990, saving model to /content/saved_models/cifar10_Resnet18.004.h5
# 390/390 [==============================] - 100s 257ms/step - loss: 1.1628 - accuracy: 0.6772 - val_loss: 1.2892 - val_accuracy: 0.6199
# Learning rate =  0.003
# Epoch 5/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1036 - accuracy: 0.7019
# Epoch 00005: val_accuracy improved from 0.61990 to 0.64290, saving model to /content/saved_models/cifar10_Resnet18.005.h5
# 390/390 [==============================] - 99s 255ms/step - loss: 1.1035 - accuracy: 0.7019 - val_loss: 1.2706 - val_accuracy: 0.6429
# Learning rate =  0.0015
# Epoch 6/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9603 - accuracy: 0.7482
# Epoch 00006: val_accuracy improved from 0.64290 to 0.66370, saving model to /content/saved_models/cifar10_Resnet18.006.h5
# 390/390 [==============================] - 98s 252ms/step - loss: 0.9603 - accuracy: 0.7483 - val_loss: 1.1898 - val_accuracy: 0.6637
# Learning rate =  0.0015
# Epoch 7/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9109 - accuracy: 0.7621
# Epoch 00007: val_accuracy improved from 0.66370 to 0.71140, saving model to /content/saved_models/cifar10_Resnet18.007.h5
# 390/390 [==============================] - 99s 253ms/step - loss: 0.9108 - accuracy: 0.7621 - val_loss: 1.0762 - val_accuracy: 0.7114
# Learning rate =  0.0015
# Epoch 8/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8776 - accuracy: 0.7738
# Epoch 00008: val_accuracy improved from 0.71140 to 0.71620, saving model to /content/saved_models/cifar10_Resnet18.008.h5
# 390/390 [==============================] - 98s 252ms/step - loss: 0.8775 - accuracy: 0.7738 - val_loss: 1.0487 - val_accuracy: 0.7162
# Learning rate =  0.0015
# Epoch 9/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8458 - accuracy: 0.7837
# Epoch 00009: val_accuracy did not improve from 0.71620
# 390/390 [==============================] - 98s 252ms/step - loss: 0.8462 - accuracy: 0.7835 - val_loss: 1.3000 - val_accuracy: 0.6540
# Learning rate =  0.0015
# Epoch 10/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8286 - accuracy: 0.7894
# Epoch 00010: val_accuracy improved from 0.71620 to 0.72740, saving model to /content/saved_models/cifar10_Resnet18.010.h5
# 390/390 [==============================] - 99s 254ms/step - loss: 0.8283 - accuracy: 0.7895 - val_loss: 1.0422 - val_accuracy: 0.7274
# Learning rate =  0.00075
# Epoch 11/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7280 - accuracy: 0.8225
# Epoch 00011: val_accuracy improved from 0.72740 to 0.78810, saving model to /content/saved_models/cifar10_Resnet18.011.h5
# 390/390 [==============================] - 98s 251ms/step - loss: 0.7286 - accuracy: 0.8223 - val_loss: 0.8286 - val_accuracy: 0.7881
# Learning rate =  0.00075
# Epoch 12/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6966 - accuracy: 0.8299
# Epoch 00012: val_accuracy improved from 0.78810 to 0.79610, saving model to /content/saved_models/cifar10_Resnet18.012.h5
# 390/390 [==============================] - 98s 250ms/step - loss: 0.6966 - accuracy: 0.8299 - val_loss: 0.8047 - val_accuracy: 0.7961
# Learning rate =  0.00075
# Epoch 13/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6761 - accuracy: 0.8348
# Epoch 00013: val_accuracy improved from 0.79610 to 0.80360, saving model to /content/saved_models/cifar10_Resnet18.013.h5
# 390/390 [==============================] - 99s 253ms/step - loss: 0.6760 - accuracy: 0.8349 - val_loss: 0.7705 - val_accuracy: 0.8036
# Learning rate =  0.00075
# Epoch 14/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6628 - accuracy: 0.8385
# Epoch 00014: val_accuracy did not improve from 0.80360
# 390/390 [==============================] - 99s 254ms/step - loss: 0.6626 - accuracy: 0.8386 - val_loss: 0.7723 - val_accuracy: 0.7982
# Learning rate =  0.00075
# Epoch 15/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6461 - accuracy: 0.8431
# Epoch 00015: val_accuracy did not improve from 0.80360
# 390/390 [==============================] - 98s 251ms/step - loss: 0.6460 - accuracy: 0.8431 - val_loss: 0.8187 - val_accuracy: 0.7848
# Learning rate =  0.000375
# Epoch 16/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5861 - accuracy: 0.8619
# Epoch 00016: val_accuracy improved from 0.80360 to 0.84420, saving model to /content/saved_models/cifar10_Resnet18.016.h5
# 390/390 [==============================] - 98s 251ms/step - loss: 0.5864 - accuracy: 0.8617 - val_loss: 0.6450 - val_accuracy: 0.8442
# Learning rate =  0.000375
# Epoch 17/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5633 - accuracy: 0.8685
# Epoch 00017: val_accuracy did not improve from 0.84420
# 390/390 [==============================] - 98s 251ms/step - loss: 0.5631 - accuracy: 0.8686 - val_loss: 0.6823 - val_accuracy: 0.8275
# Learning rate =  0.000375
# Epoch 18/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5553 - accuracy: 0.8694
# Epoch 00018: val_accuracy did not improve from 0.84420
# 390/390 [==============================] - 96s 247ms/step - loss: 0.5554 - accuracy: 0.8693 - val_loss: 0.6523 - val_accuracy: 0.8331
# Learning rate =  0.000375
# Epoch 19/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5407 - accuracy: 0.8738
# Epoch 00019: val_accuracy did not improve from 0.84420
# 390/390 [==============================] - 97s 249ms/step - loss: 0.5405 - accuracy: 0.8738 - val_loss: 0.6447 - val_accuracy: 0.8433
# Learning rate =  0.000375
# Epoch 20/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5355 - accuracy: 0.8748
# Epoch 00020: val_accuracy improved from 0.84420 to 0.84760, saving model to /content/saved_models/cifar10_Resnet18.020.h5
# 390/390 [==============================] - 98s 251ms/step - loss: 0.5355 - accuracy: 0.8747 - val_loss: 0.6220 - val_accuracy: 0.8476
# Learning rate =  0.0001875
# Epoch 21/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4993 - accuracy: 0.8866
# Epoch 00021: val_accuracy improved from 0.84760 to 0.84770, saving model to /content/saved_models/cifar10_Resnet18.021.h5
# 390/390 [==============================] - 97s 250ms/step - loss: 0.4991 - accuracy: 0.8867 - val_loss: 0.6093 - val_accuracy: 0.8477
# Learning rate =  0.0001875
# Epoch 22/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4864 - accuracy: 0.8902
# Epoch 00022: val_accuracy improved from 0.84770 to 0.85900, saving model to /content/saved_models/cifar10_Resnet18.022.h5
# 390/390 [==============================] - 98s 251ms/step - loss: 0.4864 - accuracy: 0.8903 - val_loss: 0.5821 - val_accuracy: 0.8590
# Learning rate =  0.0001875
# Epoch 23/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4738 - accuracy: 0.8944
# Epoch 00023: val_accuracy improved from 0.85900 to 0.86050, saving model to /content/saved_models/cifar10_Resnet18.023.h5
# 390/390 [==============================] - 98s 251ms/step - loss: 0.4738 - accuracy: 0.8943 - val_loss: 0.5772 - val_accuracy: 0.8605
# Learning rate =  0.0001875
# Epoch 24/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4682 - accuracy: 0.8950
# Epoch 00024: val_accuracy improved from 0.86050 to 0.86440, saving model to /content/saved_models/cifar10_Resnet18.024.h5
# 390/390 [==============================] - 97s 249ms/step - loss: 0.4685 - accuracy: 0.8949 - val_loss: 0.5597 - val_accuracy: 0.8644
# Learning rate =  0.0001875
# Epoch 25/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4616 - accuracy: 0.8956
# Epoch 00025: val_accuracy did not improve from 0.86440
# 390/390 [==============================] - 97s 249ms/step - loss: 0.4614 - accuracy: 0.8957 - val_loss: 0.5789 - val_accuracy: 0.8578
# Learning rate =  9.375e-05
# Epoch 26/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4436 - accuracy: 0.9013
# Epoch 00026: val_accuracy did not improve from 0.86440
# 390/390 [==============================] - 97s 249ms/step - loss: 0.4436 - accuracy: 0.9012 - val_loss: 0.5494 - val_accuracy: 0.8641
# Learning rate =  9.375e-05
# Epoch 27/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4393 - accuracy: 0.9035
# Epoch 00027: val_accuracy improved from 0.86440 to 0.87270, saving model to /content/saved_models/cifar10_Resnet18.027.h5
# 390/390 [==============================] - 97s 248ms/step - loss: 0.4394 - accuracy: 0.9035 - val_loss: 0.5357 - val_accuracy: 0.8727
# Learning rate =  9.375e-05
# Epoch 28/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4350 - accuracy: 0.9043
# Epoch 00028: val_accuracy did not improve from 0.87270
# 390/390 [==============================] - 98s 250ms/step - loss: 0.4350 - accuracy: 0.9042 - val_loss: 0.5371 - val_accuracy: 0.8680
# Learning rate =  9.375e-05
# Epoch 29/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4279 - accuracy: 0.9064
# Epoch 00029: val_accuracy did not improve from 0.87270
# 390/390 [==============================] - 98s 250ms/step - loss: 0.4284 - accuracy: 0.9063 - val_loss: 0.5328 - val_accuracy: 0.8718
# Learning rate =  9.375e-05
# Epoch 30/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4225 - accuracy: 0.9076
# Epoch 00030: val_accuracy did not improve from 0.87270
# 390/390 [==============================] - 98s 250ms/step - loss: 0.4227 - accuracy: 0.9075 - val_loss: 0.5377 - val_accuracy: 0.8710
# Learning rate =  4.6875e-05
# Epoch 31/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4212 - accuracy: 0.9079
# Epoch 00031: val_accuracy improved from 0.87270 to 0.87320, saving model to /content/saved_models/cifar10_Resnet18.031.h5
# 390/390 [==============================] - 98s 251ms/step - loss: 0.4210 - accuracy: 0.9080 - val_loss: 0.5329 - val_accuracy: 0.8732
# Learning rate =  4.6875e-05
# Epoch 32/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4107 - accuracy: 0.9119
# Epoch 00032: val_accuracy improved from 0.87320 to 0.87540, saving model to /content/saved_models/cifar10_Resnet18.032.h5
# 390/390 [==============================] - 97s 249ms/step - loss: 0.4106 - accuracy: 0.9119 - val_loss: 0.5265 - val_accuracy: 0.8754
# Learning rate =  4.6875e-05
# Epoch 33/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4110 - accuracy: 0.9126
# Epoch 00033: val_accuracy did not improve from 0.87540
# 390/390 [==============================] - 97s 249ms/step - loss: 0.4109 - accuracy: 0.9126 - val_loss: 0.5254 - val_accuracy: 0.8729
# Learning rate =  4.6875e-05
# Epoch 34/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4065 - accuracy: 0.9126
# Epoch 00034: val_accuracy improved from 0.87540 to 0.87740, saving model to /content/saved_models/cifar10_Resnet18.034.h5
# 390/390 [==============================] - 97s 250ms/step - loss: 0.4064 - accuracy: 0.9127 - val_loss: 0.5160 - val_accuracy: 0.8774
# Learning rate =  4.6875e-05
# Epoch 35/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4032 - accuracy: 0.9139
# Epoch 00035: val_accuracy improved from 0.87740 to 0.88040, saving model to /content/saved_models/cifar10_Resnet18.035.h5
# 390/390 [==============================] - 98s 252ms/step - loss: 0.4031 - accuracy: 0.9140 - val_loss: 0.5099 - val_accuracy: 0.8804
# Learning rate =  2.34375e-05
# Epoch 36/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4037 - accuracy: 0.9155
# Epoch 00036: val_accuracy did not improve from 0.88040
# 390/390 [==============================] - 98s 251ms/step - loss: 0.4036 - accuracy: 0.9155 - val_loss: 0.5124 - val_accuracy: 0.8765
# Learning rate =  2.34375e-05
# Epoch 37/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3994 - accuracy: 0.9147
# Epoch 00037: val_accuracy did not improve from 0.88040
# 390/390 [==============================] - 98s 251ms/step - loss: 0.3993 - accuracy: 0.9147 - val_loss: 0.5201 - val_accuracy: 0.8720
# Learning rate =  2.34375e-05
# Epoch 38/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3944 - accuracy: 0.9161
# Epoch 00038: val_accuracy did not improve from 0.88040
# 390/390 [==============================] - 97s 249ms/step - loss: 0.3944 - accuracy: 0.9161 - val_loss: 0.5211 - val_accuracy: 0.8748
# Learning rate =  2.34375e-05
# Epoch 39/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3964 - accuracy: 0.9164
# Epoch 00039: val_accuracy did not improve from 0.88040
# 390/390 [==============================] - 99s 253ms/step - loss: 0.3964 - accuracy: 0.9163 - val_loss: 0.5184 - val_accuracy: 0.8749
# Learning rate =  2.34375e-05
# Epoch 40/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3931 - accuracy: 0.9165
# Epoch 00040: val_accuracy did not improve from 0.88040
# 390/390 [==============================] - 98s 251ms/step - loss: 0.3932 - accuracy: 0.9165 - val_loss: 0.5158 - val_accuracy: 0.8751
# Learning rate =  1.171875e-05
# Epoch 41/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3947 - accuracy: 0.9158
# Epoch 00041: val_accuracy improved from 0.88040 to 0.88070, saving model to /content/saved_models/cifar10_Resnet18.041.h5
# 390/390 [==============================] - 98s 252ms/step - loss: 0.3948 - accuracy: 0.9157 - val_loss: 0.5041 - val_accuracy: 0.8807
# Learning rate =  1.171875e-05
# Epoch 42/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3910 - accuracy: 0.9174
# Epoch 00042: val_accuracy did not improve from 0.88070
# 390/390 [==============================] - 98s 252ms/step - loss: 0.3912 - accuracy: 0.9174 - val_loss: 0.5083 - val_accuracy: 0.8802
# Learning rate =  1.171875e-05
# Epoch 43/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3924 - accuracy: 0.9174
# Epoch 00043: val_accuracy did not improve from 0.88070
# 390/390 [==============================] - 98s 251ms/step - loss: 0.3924 - accuracy: 0.9173 - val_loss: 0.5177 - val_accuracy: 0.8794
# Learning rate =  1.171875e-05
# Epoch 44/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3907 - accuracy: 0.9174
# Epoch 00044: val_accuracy improved from 0.88070 to 0.88140, saving model to /content/saved_models/cifar10_Resnet18.044.h5
# 390/390 [==============================] - 99s 253ms/step - loss: 0.3907 - accuracy: 0.9174 - val_loss: 0.5023 - val_accuracy: 0.8814
# Learning rate =  1.171875e-05
# Epoch 45/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3946 - accuracy: 0.9163
# Epoch 00045: val_accuracy improved from 0.88140 to 0.88390, saving model to /content/saved_models/cifar10_Resnet18.045.h5
# 390/390 [==============================] - 99s 253ms/step - loss: 0.3944 - accuracy: 0.9164 - val_loss: 0.4988 - val_accuracy: 0.8839
# Learning rate =  5.859375e-06
# Epoch 46/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3875 - accuracy: 0.9177
# Epoch 00046: val_accuracy did not improve from 0.88390
# 390/390 [==============================] - 97s 249ms/step - loss: 0.3876 - accuracy: 0.9177 - val_loss: 0.4972 - val_accuracy: 0.8818
# Learning rate =  5.859375e-06
# Epoch 47/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3888 - accuracy: 0.9181
# Epoch 00047: val_accuracy did not improve from 0.88390
# 390/390 [==============================] - 97s 248ms/step - loss: 0.3891 - accuracy: 0.9181 - val_loss: 0.5100 - val_accuracy: 0.8788
# Learning rate =  5.859375e-06
# Epoch 48/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3869 - accuracy: 0.9188
# Epoch 00048: val_accuracy did not improve from 0.88390
# 390/390 [==============================] - 96s 247ms/step - loss: 0.3869 - accuracy: 0.9189 - val_loss: 0.5077 - val_accuracy: 0.8765
# Learning rate =  5.859375e-06
# Epoch 49/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3901 - accuracy: 0.9185
# Epoch 00049: val_accuracy did not improve from 0.88390
# 390/390 [==============================] - 97s 250ms/step - loss: 0.3901 - accuracy: 0.9185 - val_loss: 0.5118 - val_accuracy: 0.8805
# Learning rate =  5.859375e-06
# Epoch 50/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3893 - accuracy: 0.9175
# Epoch 00050: val_accuracy did not improve from 0.88390
# 390/390 [==============================] - 99s 254ms/step - loss: 0.3891 - accuracy: 0.9176 - val_loss: 0.5066 - val_accuracy: 0.8807
