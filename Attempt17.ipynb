# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavdayal/EIP_Session4/blob/master/Attempt17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, NumpyArrayIterator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import numpy as np
import os

# Training parameters
batch_size = 128
epochs = 50
data_augmentation = True
num_classes = 10

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
subtract_pixel_mean = True

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True,
                 dropout=0):
  
    #TODO: add dropout
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  use_bias=False,
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

def resnet_v1_block(x, num_filters, downscale=False, first=False):
  
  # Residual path
  y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1))
  y = resnet_layer(inputs=y, num_filters=num_filters, activation=None)

  # identity. Need to match the output for addition
  if first or downscale:
    x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1, strides = (2 if downscale else 1),  batch_normalization=False, activation=None)

  # add
  x = keras.layers.add([x, y])
  x = Activation('relu')(x)
  return x
  
def resnet_v1(input_shape, res_blocks, num_classes=10):
    # Start model definition.
    num_filters = 8

    inputs = Input(shape=input_shape)

    # first convolution before Resnet starts.
    # Should this be done, because we dont want to modify the input
    # But in actual resnet they are doing 7x7, may be they are not doing BN or activation here!!!
    x = resnet_layer(inputs=inputs, num_filters=num_filters)

    # Instantiate the stack of residual units
    for i, blockcount in enumerate(res_blocks):
        num_filters = num_filters*2
        #num_filters *= 2
        for layer in range(blockcount):
          x = resnet_v1_block(x, num_filters=num_filters, downscale=i>1 and layer==0, first = layer==0 and i<2)

    # Add classifier on top.
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes,
                    activation='softmax', use_bias=False,
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def lr_schedule(epoch):
    lr = 0.002
    if epoch >45:
      lr = 0.00001
    if epoch >=40:
      lr = 0.0001
    elif epoch >= 10:
      lr = 0.001
    print("learning rate = ", lr)
    return lr

model = resnet_v1(input_shape=input_shape, res_blocks=(2, 2, 2, 2))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_Resnet18.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)


# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w # area of cutout
            r = np.random.uniform(r_1, r_2) # 
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=20,
        # randomly shift images horizontally
        width_shift_range=0.2,
        # randomly shift images vertically
        height_shift_range=0.2,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.2,
        # set range for random channel shifts
        channel_shift_range=0,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_h=1),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    train_iter = NumpyArrayIterator(x=x_train, y=y_train, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    val_iter = NumpyArrayIterator(x=x_test, y=y_test, image_data_generator=datagen, batch_size=batch_size, shuffle=True)

    model.fit_generator(generator = train_iter,
                        steps_per_epoch = (x_train.shape[0]//batch_size), epochs = 50, 
                        validation_data = val_iter, verbose=1, workers=4, callbacks=callbacks)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# learning rate =  0.002
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 8)    216         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 8)    32          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 8)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 16)   1152        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 16)   64          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 16)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 16)   2304        activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 16)   128         activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 16)   64          conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 16)   0           conv2d_24[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 16)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 16)   2304        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 16)   64          conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 16)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 16)   2304        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 16)   64          conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 16)   0           activation_19[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 16)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 32)   4608        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 32)   9216        activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 32)   512         activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 32)   0           conv2d_29[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 32)   9216        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 32)   9216        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 32)   128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 32)   0           activation_23[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 32)   0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 64)   18432       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 64)   36864       activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 64)   2048        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 64)   0           conv2d_34[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 64)   0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 64)   36864       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 64)   36864       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 64)   0           activation_27[0][0]
#                                                                  batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 64)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 128)    73728       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 128)    512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 8, 8, 128)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 128)    147456      activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 128)    8192        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 128)    512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 128)    0           conv2d_39[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 128)    0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 128)    147456      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 128)    512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 8, 8, 128)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 128)    147456      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 128)    512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 128)    0           activation_31[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 8, 8, 128)    0           add_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           activation_33[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1280        global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 701,688
# Trainable params: 699,752
# Non-trainable params: 1,936
# __________________________________________________________________________________________________
# Using real-time data augmentation.
# learning rate =  0.002
# Epoch 1/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.8918 - accuracy: 0.3999
# Epoch 00001: val_accuracy improved from -inf to 0.38800, saving model to /content/saved_models/cifar10_Resnet18.001.h5
# 390/390 [==============================] - 109s 279ms/step - loss: 1.8908 - accuracy: 0.4002 - val_loss: 1.9842 - val_accuracy: 0.3880
# learning rate =  0.002
# Epoch 2/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.5406 - accuracy: 0.5190
# Epoch 00002: val_accuracy improved from 0.38800 to 0.46890, saving model to /content/saved_models/cifar10_Resnet18.002.h5
# 390/390 [==============================] - 107s 273ms/step - loss: 1.5402 - accuracy: 0.5191 - val_loss: 1.7953 - val_accuracy: 0.4689
# learning rate =  0.002
# Epoch 3/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.3733 - accuracy: 0.5803
# Epoch 00003: val_accuracy improved from 0.46890 to 0.55250, saving model to /content/saved_models/cifar10_Resnet18.003.h5
# 390/390 [==============================] - 107s 274ms/step - loss: 1.3734 - accuracy: 0.5802 - val_loss: 1.4528 - val_accuracy: 0.5525
# learning rate =  0.002
# Epoch 4/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2713 - accuracy: 0.6205
# Epoch 00004: val_accuracy improved from 0.55250 to 0.55830, saving model to /content/saved_models/cifar10_Resnet18.004.h5
# 390/390 [==============================] - 106s 273ms/step - loss: 1.2710 - accuracy: 0.6207 - val_loss: 1.4695 - val_accuracy: 0.5583
# learning rate =  0.002
# Epoch 5/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2007 - accuracy: 0.6487
# Epoch 00005: val_accuracy did not improve from 0.55830
# 390/390 [==============================] - 108s 276ms/step - loss: 1.2005 - accuracy: 0.6488 - val_loss: 2.4796 - val_accuracy: 0.4025
# learning rate =  0.002
# Epoch 6/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1370 - accuracy: 0.6733
# Epoch 00006: val_accuracy improved from 0.55830 to 0.63340, saving model to /content/saved_models/cifar10_Resnet18.006.h5
# 390/390 [==============================] - 107s 276ms/step - loss: 1.1368 - accuracy: 0.6734 - val_loss: 1.2486 - val_accuracy: 0.6334
# learning rate =  0.002
# Epoch 7/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1097 - accuracy: 0.6868
# Epoch 00007: val_accuracy did not improve from 0.63340
# 390/390 [==============================] - 104s 266ms/step - loss: 1.1099 - accuracy: 0.6867 - val_loss: 1.3387 - val_accuracy: 0.6132
# learning rate =  0.002
# Epoch 8/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0704 - accuracy: 0.7033
# Epoch 00008: val_accuracy did not improve from 0.63340
# 390/390 [==============================] - 104s 266ms/step - loss: 1.0708 - accuracy: 0.7032 - val_loss: 1.3745 - val_accuracy: 0.6157
# learning rate =  0.002
# Epoch 9/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0402 - accuracy: 0.7157
# Epoch 00009: val_accuracy did not improve from 0.63340
# 390/390 [==============================] - 103s 264ms/step - loss: 1.0399 - accuracy: 0.7158 - val_loss: 1.5103 - val_accuracy: 0.5746
# learning rate =  0.002
# Epoch 10/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0193 - accuracy: 0.7261
# Epoch 00010: val_accuracy improved from 0.63340 to 0.68360, saving model to /content/saved_models/cifar10_Resnet18.010.h5
# 390/390 [==============================] - 104s 266ms/step - loss: 1.0190 - accuracy: 0.7262 - val_loss: 1.1463 - val_accuracy: 0.6836
# learning rate =  0.001
# Epoch 11/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9044 - accuracy: 0.7648
# Epoch 00011: val_accuracy improved from 0.68360 to 0.69850, saving model to /content/saved_models/cifar10_Resnet18.011.h5
# 390/390 [==============================] - 104s 268ms/step - loss: 0.9043 - accuracy: 0.7648 - val_loss: 1.0925 - val_accuracy: 0.6985
# learning rate =  0.001
# Epoch 12/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8688 - accuracy: 0.7728
# Epoch 00012: val_accuracy improved from 0.69850 to 0.74580, saving model to /content/saved_models/cifar10_Resnet18.012.h5
# 390/390 [==============================] - 103s 264ms/step - loss: 0.8685 - accuracy: 0.7729 - val_loss: 0.9488 - val_accuracy: 0.7458
# learning rate =  0.001
# Epoch 13/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8474 - accuracy: 0.7804
# Epoch 00013: val_accuracy did not improve from 0.74580
# 390/390 [==============================] - 102s 262ms/step - loss: 0.8474 - accuracy: 0.7804 - val_loss: 1.0513 - val_accuracy: 0.7186
# learning rate =  0.001
# Epoch 14/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8305 - accuracy: 0.7811
# Epoch 00014: val_accuracy did not improve from 0.74580
# 390/390 [==============================] - 102s 263ms/step - loss: 0.8304 - accuracy: 0.7811 - val_loss: 0.9479 - val_accuracy: 0.7413
# learning rate =  0.001
# Epoch 15/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8033 - accuracy: 0.7902
# Epoch 00015: val_accuracy did not improve from 0.74580
# 390/390 [==============================] - 102s 261ms/step - loss: 0.8032 - accuracy: 0.7902 - val_loss: 0.9491 - val_accuracy: 0.7369
# learning rate =  0.001
# Epoch 16/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7976 - accuracy: 0.7927
# Epoch 00016: val_accuracy did not improve from 0.74580
# 390/390 [==============================] - 102s 262ms/step - loss: 0.7976 - accuracy: 0.7927 - val_loss: 0.9339 - val_accuracy: 0.7405
# learning rate =  0.001
# Epoch 17/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7837 - accuracy: 0.7962
# Epoch 00017: val_accuracy did not improve from 0.74580
# 390/390 [==============================] - 102s 262ms/step - loss: 0.7840 - accuracy: 0.7961 - val_loss: 1.0499 - val_accuracy: 0.7190
# learning rate =  0.001
# Epoch 18/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7652 - accuracy: 0.8013
# Epoch 00018: val_accuracy did not improve from 0.74580
# 390/390 [==============================] - 102s 261ms/step - loss: 0.7650 - accuracy: 0.8013 - val_loss: 1.2140 - val_accuracy: 0.6863
# learning rate =  0.001
# Epoch 19/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7630 - accuracy: 0.8037
# Epoch 00019: val_accuracy improved from 0.74580 to 0.76520, saving model to /content/saved_models/cifar10_Resnet18.019.h5
# 390/390 [==============================] - 102s 262ms/step - loss: 0.7629 - accuracy: 0.8038 - val_loss: 0.9001 - val_accuracy: 0.7652
# learning rate =  0.001
# Epoch 20/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7514 - accuracy: 0.8052
# Epoch 00020: val_accuracy improved from 0.76520 to 0.77800, saving model to /content/saved_models/cifar10_Resnet18.020.h5
# 390/390 [==============================] - 103s 263ms/step - loss: 0.7517 - accuracy: 0.8051 - val_loss: 0.8549 - val_accuracy: 0.7780
# learning rate =  0.001
# Epoch 21/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7488 - accuracy: 0.8065
# Epoch 00021: val_accuracy did not improve from 0.77800
# 390/390 [==============================] - 103s 263ms/step - loss: 0.7484 - accuracy: 0.8066 - val_loss: 0.8973 - val_accuracy: 0.7563
# learning rate =  0.001
# Epoch 22/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7340 - accuracy: 0.8114
# Epoch 00022: val_accuracy did not improve from 0.77800
# 390/390 [==============================] - 102s 262ms/step - loss: 0.7338 - accuracy: 0.8113 - val_loss: 0.8752 - val_accuracy: 0.7713
# learning rate =  0.001
# Epoch 23/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7226 - accuracy: 0.8172
# Epoch 00023: val_accuracy did not improve from 0.77800
# 390/390 [==============================] - 102s 262ms/step - loss: 0.7223 - accuracy: 0.8173 - val_loss: 0.9366 - val_accuracy: 0.7571
# learning rate =  0.001
# Epoch 24/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7209 - accuracy: 0.8173
# Epoch 00024: val_accuracy did not improve from 0.77800
# 390/390 [==============================] - 102s 261ms/step - loss: 0.7207 - accuracy: 0.8174 - val_loss: 1.2728 - val_accuracy: 0.6675
# learning rate =  0.001
# Epoch 25/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7141 - accuracy: 0.8192
# Epoch 00025: val_accuracy did not improve from 0.77800
# 390/390 [==============================] - 102s 262ms/step - loss: 0.7140 - accuracy: 0.8193 - val_loss: 0.9429 - val_accuracy: 0.7445
# learning rate =  0.001
# Epoch 26/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7058 - accuracy: 0.8225
# Epoch 00026: val_accuracy did not improve from 0.77800
# 390/390 [==============================] - 103s 265ms/step - loss: 0.7056 - accuracy: 0.8225 - val_loss: 0.9717 - val_accuracy: 0.7338
# learning rate =  0.001
# Epoch 27/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.8214
# Epoch 00027: val_accuracy did not improve from 0.77800
# 390/390 [==============================] - 102s 261ms/step - loss: 0.7058 - accuracy: 0.8214 - val_loss: 0.9581 - val_accuracy: 0.7550
# learning rate =  0.001
# Epoch 28/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6978 - accuracy: 0.8261
# Epoch 00028: val_accuracy improved from 0.77800 to 0.77820, saving model to /content/saved_models/cifar10_Resnet18.028.h5
# 390/390 [==============================] - 103s 263ms/step - loss: 0.6978 - accuracy: 0.8261 - val_loss: 0.8401 - val_accuracy: 0.7782
# learning rate =  0.001
# Epoch 29/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7002 - accuracy: 0.8242
# Epoch 00029: val_accuracy did not improve from 0.77820
# 390/390 [==============================] - 104s 267ms/step - loss: 0.7002 - accuracy: 0.8243 - val_loss: 0.9339 - val_accuracy: 0.7492
# learning rate =  0.001
# Epoch 30/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6871 - accuracy: 0.8294
# Epoch 00030: val_accuracy did not improve from 0.77820
# 390/390 [==============================] - 103s 263ms/step - loss: 0.6872 - accuracy: 0.8293 - val_loss: 1.0252 - val_accuracy: 0.7325
# learning rate =  0.001
# Epoch 31/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6846 - accuracy: 0.8297
# Epoch 00031: val_accuracy did not improve from 0.77820
# 390/390 [==============================] - 102s 262ms/step - loss: 0.6845 - accuracy: 0.8297 - val_loss: 0.9071 - val_accuracy: 0.7518
# learning rate =  0.001
# Epoch 32/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6740 - accuracy: 0.8327
# Epoch 00032: val_accuracy did not improve from 0.77820
# 390/390 [==============================] - 103s 264ms/step - loss: 0.6741 - accuracy: 0.8327 - val_loss: 0.8844 - val_accuracy: 0.7585
# learning rate =  0.001
# Epoch 33/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.8359
# Epoch 00033: val_accuracy improved from 0.77820 to 0.79600, saving model to /content/saved_models/cifar10_Resnet18.033.h5
# 390/390 [==============================] - 103s 263ms/step - loss: 0.6712 - accuracy: 0.8358 - val_loss: 0.7888 - val_accuracy: 0.7960
# learning rate =  0.001
# Epoch 34/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6678 - accuracy: 0.8350
# Epoch 00034: val_accuracy did not improve from 0.79600
# 390/390 [==============================] - 102s 261ms/step - loss: 0.6678 - accuracy: 0.8350 - val_loss: 1.0157 - val_accuracy: 0.7247
# learning rate =  0.001
# Epoch 35/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6677 - accuracy: 0.8363
# Epoch 00035: val_accuracy did not improve from 0.79600
# 390/390 [==============================] - 102s 262ms/step - loss: 0.6677 - accuracy: 0.8363 - val_loss: 0.8757 - val_accuracy: 0.7668
# learning rate =  0.001
# Epoch 36/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6634 - accuracy: 0.8376
# Epoch 00036: val_accuracy did not improve from 0.79600
# 390/390 [==============================] - 101s 260ms/step - loss: 0.6632 - accuracy: 0.8376 - val_loss: 0.9447 - val_accuracy: 0.7545
# learning rate =  0.001
# Epoch 37/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6558 - accuracy: 0.8401
# Epoch 00037: val_accuracy did not improve from 0.79600
# 390/390 [==============================] - 101s 260ms/step - loss: 0.6560 - accuracy: 0.8399 - val_loss: 0.9425 - val_accuracy: 0.7418
# learning rate =  0.001
# Epoch 38/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6565 - accuracy: 0.8403
# Epoch 00038: val_accuracy improved from 0.79600 to 0.79670, saving model to /content/saved_models/cifar10_Resnet18.038.h5
# 390/390 [==============================] - 103s 263ms/step - loss: 0.6565 - accuracy: 0.8403 - val_loss: 0.7937 - val_accuracy: 0.7967
# learning rate =  0.001
# Epoch 39/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6505 - accuracy: 0.8423
# Epoch 00039: val_accuracy did not improve from 0.79670
# 390/390 [==============================] - 102s 262ms/step - loss: 0.6505 - accuracy: 0.8423 - val_loss: 0.8940 - val_accuracy: 0.7659
# learning rate =  0.001
# Epoch 40/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6507 - accuracy: 0.8414
# Epoch 00040: val_accuracy did not improve from 0.79670
# 390/390 [==============================] - 102s 261ms/step - loss: 0.6505 - accuracy: 0.8414 - val_loss: 0.8339 - val_accuracy: 0.7877
# learning rate =  0.0001
# Epoch 41/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5760 - accuracy: 0.8667
# Epoch 00041: val_accuracy improved from 0.79670 to 0.84900, saving model to /content/saved_models/cifar10_Resnet18.041.h5
# 390/390 [==============================] - 102s 263ms/step - loss: 0.5758 - accuracy: 0.8667 - val_loss: 0.6309 - val_accuracy: 0.8490
# learning rate =  0.0001
# Epoch 42/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5489 - accuracy: 0.8768
# Epoch 00042: val_accuracy improved from 0.84900 to 0.85460, saving model to /content/saved_models/cifar10_Resnet18.042.h5
# 390/390 [==============================] - 102s 260ms/step - loss: 0.5489 - accuracy: 0.8768 - val_loss: 0.6114 - val_accuracy: 0.8546
# learning rate =  0.0001
# Epoch 43/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5335 - accuracy: 0.8808
# Epoch 00043: val_accuracy improved from 0.85460 to 0.85620, saving model to /content/saved_models/cifar10_Resnet18.043.h5
# 390/390 [==============================] - 101s 260ms/step - loss: 0.5336 - accuracy: 0.8808 - val_loss: 0.5985 - val_accuracy: 0.8562
# learning rate =  0.0001
# Epoch 44/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5283 - accuracy: 0.8812
# Epoch 00044: val_accuracy improved from 0.85620 to 0.85960, saving model to /content/saved_models/cifar10_Resnet18.044.h5
# 390/390 [==============================] - 102s 262ms/step - loss: 0.5281 - accuracy: 0.8812 - val_loss: 0.6086 - val_accuracy: 0.8596
# learning rate =  0.0001
# Epoch 45/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5169 - accuracy: 0.8856
# Epoch 00045: val_accuracy improved from 0.85960 to 0.86380, saving model to /content/saved_models/cifar10_Resnet18.045.h5
# 390/390 [==============================] - 103s 264ms/step - loss: 0.5170 - accuracy: 0.8856 - val_loss: 0.5841 - val_accuracy: 0.8638
# learning rate =  0.0001
# Epoch 46/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5035 - accuracy: 0.8884
# Epoch 00046: val_accuracy improved from 0.86380 to 0.86720, saving model to /content/saved_models/cifar10_Resnet18.046.h5
# 390/390 [==============================] - 104s 267ms/step - loss: 0.5034 - accuracy: 0.8884 - val_loss: 0.5784 - val_accuracy: 0.8672
# learning rate =  0.0001
# Epoch 47/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5032 - accuracy: 0.8888
# Epoch 00047: val_accuracy did not improve from 0.86720
# 390/390 [==============================] - 104s 265ms/step - loss: 0.5032 - accuracy: 0.8888 - val_loss: 0.5907 - val_accuracy: 0.8581
# learning rate =  0.0001
# Epoch 48/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5028 - accuracy: 0.8892
# Epoch 00048: val_accuracy did not improve from 0.86720
# 390/390 [==============================] - 103s 264ms/step - loss: 0.5026 - accuracy: 0.8893 - val_loss: 0.5918 - val_accuracy: 0.8601
# learning rate =  0.0001
# Epoch 49/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4958 - accuracy: 0.8898
# Epoch 00049: val_accuracy did not improve from 0.86720
# 390/390 [==============================] - 104s 266ms/step - loss: 0.4961 - accuracy: 0.8897 - val_loss: 0.5760 - val_accuracy: 0.8671
# learning rate =  0.0001
# Epoch 50/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4886 - accuracy: 0.8914
# Epoch 00050: val_accuracy did not improve from 0.86720
# 390/390 [==============================] - 104s 267ms/step - loss: 0.4885 - accuracy: 0.8914 - val_loss: 0.5662 - val_accuracy: 0.8656
