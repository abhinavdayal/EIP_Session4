# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavdayal/EIP_Session4/blob/master/Attempt06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, NumpyArrayIterator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import numpy as np
import os
# Out:
# TensorFlow 2.x selected.

# %%
# Training parameters
batch_size = 128
epochs = 50
data_augmentation = True
num_classes = 10

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=False,
                 dropout=0):
  
    #TODO: add dropout
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  use_bias=False,
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2_block(x, num_filters, downscale=False, first=False):
  
  # Residual path
  if first:
    y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1), batch_normalization=False, activation=None) # already getting activated input!
  else:  
    y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1))
  y = resnet_layer(inputs=y, num_filters=num_filters)

  # identity. Need to match the output for addition
  if first or downscale:
    x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1, strides = (2 if downscale else 1),  batch_normalization=False, activation=None)

  # add
  x = keras.layers.add([x, y])

  return x

# %%
def resnet_v2(input_shape, res_blocks, num_classes=10):
    # Start model definition.
    num_filters = 16

    inputs = Input(shape=input_shape)

    # first convolution before Resnet starts.
    # Should this be done, because we dont want to modify the input
    # But in actual resnet they are doing 7x7, may be they are not doing BN or activation here!!!
    x = resnet_layer(inputs=inputs, num_filters=num_filters)

    # Instantiate the stack of residual units
    for i, blockcount in enumerate(res_blocks):
        num_filters = num_filters*4 if i==0 else num_filters*2
        #num_filters *= 2
        for layer in range(blockcount):
          x = resnet_v2_block(x, num_filters=num_filters, downscale=i>0 and layer==0, first = layer==0 and i==0)

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=4)(x)
    x = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax', use_bias=False,
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v2(input_shape=input_shape, res_blocks=(2, 2, 2, 2))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# Learning rate:  0.01
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 3)    12          input_2[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 3)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 16)   432         activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 64)   9216        conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 64)   1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 64)   36864       activation_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 64)   0           conv2d_24[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 64)   256         add_8[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 64)   36864       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 64)   36864       activation_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 64)   0           add_8[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 64)   256         add_9[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 128)  73728       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 128)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 128)  8192        add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 128)  147456      activation_22[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 128)  0           conv2d_29[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 128)  512         add_10[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 128)  147456      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 128)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 128)  147456      activation_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 128)  0           add_10[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 128)  512         add_11[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 256)    294912      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 256)    1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 256)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 256)    32768       add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 256)    589824      activation_26[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 256)    0           conv2d_34[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 256)    1024        add_12[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 256)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 256)    589824      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 256)    1024        conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 256)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 256)    589824      activation_28[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 8, 8, 256)    0           add_12[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 256)    1024        add_13[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 256)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 512)    1179648     activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 512)    2048        conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 4, 4, 512)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 4, 512)    131072      add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 512)    2359296     activation_30[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 4, 512)    0           conv2d_39[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 512)    2048        add_14[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4, 4, 512)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 512)    2359296     activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 512)    2048        conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 512)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 4, 4, 512)    2359296     activation_32[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 4, 512)    0           add_14[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 4, 4, 512)    2048        add_15[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 4, 4, 512)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_33[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5120        flatten_1[0][0]
# ==================================================================================================
# Total params: 11,151,804
# Trainable params: 11,144,118
# Non-trainable params: 7,686
# __________________________________________________________________________________________________

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_Tesnet18.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
def lr_schedule(epoch):
    lr = round(0.01 * 1/(1 + 0.319 * epoch), 10)
    print('Learning rate: ', lr)
    return lr
    
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w # area of cutout
            r = np.random.uniform(r_1, r_2) # 
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=20,
        # randomly shift images horizontally
        width_shift_range=0.2,
        # randomly shift images vertically
        height_shift_range=0.2,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.2,
        # set range for random channel shifts
        channel_shift_range=0.2,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=True),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    #datagen.fit(x_train)

    train_iter = NumpyArrayIterator(x=x_train, y=y_train, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    val_iter = NumpyArrayIterator(x=x_test, y=y_test, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
# Out:
# Using real-time data augmentation.

# %%
# Fit the model on the batches generated by datagen.flow().
    #model.fit_generator(,
    #                    val_iter,
    #                    epochs=epochs, verbose=1, workers=4,
    #                   callbacks=callbacks)
    model.fit_generator(generator = train_iter,
                        steps_per_epoch = (x_train.shape[0]//batch_size), epochs = 50, 
                        validation_data = val_iter, verbose=1, workers=4, callbacks=callbacks)
# Out:
# Learning rate:  0.01
# Epoch 1/50
# 389/390 [============================>.] - ETA: 0s - loss: 2.4290 - accuracy: 0.2314
# Epoch 00001: val_accuracy improved from -inf to 0.22850, saving model to /content/saved_models/cifar10_Tesnet18.001.h5
# 390/390 [==============================] - 147s 377ms/step - loss: 2.4275 - accuracy: 0.2315 - val_loss: 2.1266 - val_accuracy: 0.2285
# Learning rate:  0.0075815011
# Epoch 2/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.8704 - accuracy: 0.3420
# Epoch 00002: val_accuracy improved from 0.22850 to 0.29310, saving model to /content/saved_models/cifar10_Tesnet18.002.h5
# 390/390 [==============================] - 145s 371ms/step - loss: 1.8699 - accuracy: 0.3421 - val_loss: 2.0133 - val_accuracy: 0.2931
# Learning rate:  0.0061050061
# Epoch 3/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.7117 - accuracy: 0.4149
# Epoch 00003: val_accuracy improved from 0.29310 to 0.30160, saving model to /content/saved_models/cifar10_Tesnet18.003.h5
# 390/390 [==============================] - 142s 365ms/step - loss: 1.7116 - accuracy: 0.4149 - val_loss: 2.0676 - val_accuracy: 0.3016
# Learning rate:  0.005109862
# Epoch 4/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.6093 - accuracy: 0.4531
# Epoch 00004: val_accuracy did not improve from 0.30160
# 390/390 [==============================] - 142s 365ms/step - loss: 1.6092 - accuracy: 0.4532 - val_loss: 2.0813 - val_accuracy: 0.2927
# Learning rate:  0.0043936731
# Epoch 5/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.5330 - accuracy: 0.4831
# Epoch 00005: val_accuracy improved from 0.30160 to 0.35670, saving model to /content/saved_models/cifar10_Tesnet18.005.h5
# 390/390 [==============================] - 144s 368ms/step - loss: 1.5328 - accuracy: 0.4831 - val_loss: 2.1658 - val_accuracy: 0.3567
# Learning rate:  0.0038535645
# Epoch 6/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.4653 - accuracy: 0.5124
# Epoch 00006: val_accuracy improved from 0.35670 to 0.46160, saving model to /content/saved_models/cifar10_Tesnet18.006.h5
# 390/390 [==============================] - 143s 366ms/step - loss: 1.4652 - accuracy: 0.5124 - val_loss: 1.6170 - val_accuracy: 0.4616
# Learning rate:  0.003431709
# Epoch 7/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.4079 - accuracy: 0.5371
# Epoch 00007: val_accuracy improved from 0.46160 to 0.46630, saving model to /content/saved_models/cifar10_Tesnet18.007.h5
# 390/390 [==============================] - 143s 367ms/step - loss: 1.4076 - accuracy: 0.5371 - val_loss: 1.6184 - val_accuracy: 0.4663
# Learning rate:  0.0030931024
# Epoch 8/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.3651 - accuracy: 0.5533
# Epoch 00008: val_accuracy did not improve from 0.46630
# 390/390 [==============================] - 141s 362ms/step - loss: 1.3651 - accuracy: 0.5533 - val_loss: 1.6022 - val_accuracy: 0.4653
# Learning rate:  0.0028153153
# Epoch 9/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.3177 - accuracy: 0.5702
# Epoch 00009: val_accuracy improved from 0.46630 to 0.51900, saving model to /content/saved_models/cifar10_Tesnet18.009.h5
# 390/390 [==============================] - 141s 361ms/step - loss: 1.3173 - accuracy: 0.5704 - val_loss: 1.5180 - val_accuracy: 0.5190
# Learning rate:  0.0025833118
# Epoch 10/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2828 - accuracy: 0.5847
# Epoch 00010: val_accuracy improved from 0.51900 to 0.52630, saving model to /content/saved_models/cifar10_Tesnet18.010.h5
# 390/390 [==============================] - 140s 358ms/step - loss: 1.2830 - accuracy: 0.5846 - val_loss: 1.4654 - val_accuracy: 0.5263
# Learning rate:  0.0023866348
# Epoch 11/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2436 - accuracy: 0.5968
# Epoch 00011: val_accuracy did not improve from 0.52630
# 390/390 [==============================] - 138s 353ms/step - loss: 1.2436 - accuracy: 0.5968 - val_loss: 1.4568 - val_accuracy: 0.5148
# Learning rate:  0.0022177866
# Epoch 12/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2225 - accuracy: 0.6039
# Epoch 00012: val_accuracy did not improve from 0.52630
# 390/390 [==============================] - 139s 356ms/step - loss: 1.2226 - accuracy: 0.6039 - val_loss: 1.9372 - val_accuracy: 0.4677
# Learning rate:  0.002071251
# Epoch 13/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1909 - accuracy: 0.6182
# Epoch 00013: val_accuracy improved from 0.52630 to 0.60570, saving model to /content/saved_models/cifar10_Tesnet18.013.h5
# 390/390 [==============================] - 137s 352ms/step - loss: 1.1913 - accuracy: 0.6181 - val_loss: 1.2303 - val_accuracy: 0.6057
# Learning rate:  0.0019428793
# Epoch 14/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1657 - accuracy: 0.6257
# Epoch 00014: val_accuracy did not improve from 0.60570
# 390/390 [==============================] - 138s 353ms/step - loss: 1.1652 - accuracy: 0.6259 - val_loss: 1.3027 - val_accuracy: 0.5910
# Learning rate:  0.0018294914
# Epoch 15/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1428 - accuracy: 0.6360
# Epoch 00015: val_accuracy did not improve from 0.60570
# 390/390 [==============================] - 138s 353ms/step - loss: 1.1431 - accuracy: 0.6360 - val_loss: 1.4965 - val_accuracy: 0.5256
# Learning rate:  0.0017286085
# Epoch 16/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1181 - accuracy: 0.6453
# Epoch 00016: val_accuracy did not improve from 0.60570
# 390/390 [==============================] - 138s 354ms/step - loss: 1.1182 - accuracy: 0.6453 - val_loss: 1.3292 - val_accuracy: 0.5819
# Learning rate:  0.00163827
# Epoch 17/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1048 - accuracy: 0.6497
# Epoch 00017: val_accuracy did not improve from 0.60570
# 390/390 [==============================] - 136s 349ms/step - loss: 1.1050 - accuracy: 0.6497 - val_loss: 1.4824 - val_accuracy: 0.5385
# Learning rate:  0.0015569049
# Epoch 18/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0871 - accuracy: 0.6566
# Epoch 00018: val_accuracy did not improve from 0.60570
# 390/390 [==============================] - 138s 354ms/step - loss: 1.0872 - accuracy: 0.6567 - val_loss: 1.2745 - val_accuracy: 0.5714
# Learning rate:  0.0014832394
# Epoch 19/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0740 - accuracy: 0.6618
# Epoch 00019: val_accuracy improved from 0.60570 to 0.60940, saving model to /content/saved_models/cifar10_Tesnet18.019.h5
# 390/390 [==============================] - 139s 358ms/step - loss: 1.0742 - accuracy: 0.6618 - val_loss: 1.2044 - val_accuracy: 0.6094
# Learning rate:  0.00141623
# Epoch 20/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0547 - accuracy: 0.6691
# Epoch 00020: val_accuracy did not improve from 0.60940
# 390/390 [==============================] - 139s 358ms/step - loss: 1.0548 - accuracy: 0.6690 - val_loss: 1.2525 - val_accuracy: 0.5969
# Learning rate:  0.0013550136
# Epoch 21/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0439 - accuracy: 0.6705
# Epoch 00021: val_accuracy improved from 0.60940 to 0.63710, saving model to /content/saved_models/cifar10_Tesnet18.021.h5
# 390/390 [==============================] - 140s 359ms/step - loss: 1.0438 - accuracy: 0.6705 - val_loss: 1.1433 - val_accuracy: 0.6371
# Learning rate:  0.00129887
# Epoch 22/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0318 - accuracy: 0.6750
# Epoch 00022: val_accuracy improved from 0.63710 to 0.63890, saving model to /content/saved_models/cifar10_Tesnet18.022.h5
# 390/390 [==============================] - 139s 356ms/step - loss: 1.0314 - accuracy: 0.6751 - val_loss: 1.1409 - val_accuracy: 0.6389
# Learning rate:  0.0012471938
# Epoch 23/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0174 - accuracy: 0.6824
# Epoch 00023: val_accuracy did not improve from 0.63890
# 390/390 [==============================] - 136s 349ms/step - loss: 1.0172 - accuracy: 0.6825 - val_loss: 1.2386 - val_accuracy: 0.6207
# Learning rate:  0.0011994722
# Epoch 24/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0026 - accuracy: 0.6877
# Epoch 00024: val_accuracy improved from 0.63890 to 0.65500, saving model to /content/saved_models/cifar10_Tesnet18.024.h5
# 390/390 [==============================] - 138s 353ms/step - loss: 1.0026 - accuracy: 0.6877 - val_loss: 1.0890 - val_accuracy: 0.6550
# Learning rate:  0.001155268
# Epoch 25/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9928 - accuracy: 0.6888
# Epoch 00025: val_accuracy did not improve from 0.65500
# 390/390 [==============================] - 137s 350ms/step - loss: 0.9923 - accuracy: 0.6890 - val_loss: 1.1127 - val_accuracy: 0.6505
# Learning rate:  0.0011142061
# Epoch 26/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9805 - accuracy: 0.6942
# Epoch 00026: val_accuracy did not improve from 0.65500
# 390/390 [==============================] - 137s 352ms/step - loss: 0.9805 - accuracy: 0.6941 - val_loss: 1.1491 - val_accuracy: 0.6309
# Learning rate:  0.001075963
# Epoch 27/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9689 - accuracy: 0.7004
# Epoch 00027: val_accuracy did not improve from 0.65500
# 390/390 [==============================] - 137s 352ms/step - loss: 0.9695 - accuracy: 0.7002 - val_loss: 1.1145 - val_accuracy: 0.6540
# Learning rate:  0.001040258
# Epoch 28/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9640 - accuracy: 0.7007
# Epoch 00028: val_accuracy did not improve from 0.65500
# 390/390 [==============================] - 137s 352ms/step - loss: 0.9638 - accuracy: 0.7008 - val_loss: 1.1132 - val_accuracy: 0.6452
# Learning rate:  0.0010068466
# Epoch 29/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9539 - accuracy: 0.7025
# Epoch 00029: val_accuracy improved from 0.65500 to 0.66350, saving model to /content/saved_models/cifar10_Tesnet18.029.h5
# 390/390 [==============================] - 136s 349ms/step - loss: 0.9537 - accuracy: 0.7026 - val_loss: 1.0943 - val_accuracy: 0.6635
# Learning rate:  0.0009755146
# Epoch 30/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9396 - accuracy: 0.7078
# Epoch 00030: val_accuracy did not improve from 0.66350
# 390/390 [==============================] - 137s 350ms/step - loss: 0.9398 - accuracy: 0.7077 - val_loss: 1.1665 - val_accuracy: 0.6307
# Learning rate:  0.0009460738
# Epoch 31/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9247 - accuracy: 0.7160
# Epoch 00031: val_accuracy did not improve from 0.66350
# 390/390 [==============================] - 141s 360ms/step - loss: 0.9244 - accuracy: 0.7160 - val_loss: 1.1139 - val_accuracy: 0.6448
# Learning rate:  0.000918358
# Epoch 32/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9265 - accuracy: 0.7138
# Epoch 00032: val_accuracy improved from 0.66350 to 0.69590, saving model to /content/saved_models/cifar10_Tesnet18.032.h5
# 390/390 [==============================] - 139s 355ms/step - loss: 0.9264 - accuracy: 0.7138 - val_loss: 0.9815 - val_accuracy: 0.6959
# Learning rate:  0.0008922198
# Epoch 33/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9106 - accuracy: 0.7213
# Epoch 00033: val_accuracy did not improve from 0.69590
# 390/390 [==============================] - 139s 356ms/step - loss: 0.9103 - accuracy: 0.7216 - val_loss: 0.9982 - val_accuracy: 0.6871
# Learning rate:  0.0008675284
# Epoch 34/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9046 - accuracy: 0.7230
# Epoch 00034: val_accuracy did not improve from 0.69590
# 390/390 [==============================] - 140s 358ms/step - loss: 0.9043 - accuracy: 0.7230 - val_loss: 0.9746 - val_accuracy: 0.6922
# Learning rate:  0.0008441668
# Epoch 35/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8989 - accuracy: 0.7233
# Epoch 00035: val_accuracy did not improve from 0.69590
# 390/390 [==============================] - 138s 355ms/step - loss: 0.8991 - accuracy: 0.7233 - val_loss: 1.0560 - val_accuracy: 0.6714
# Learning rate:  0.0008220304
# Epoch 36/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8859 - accuracy: 0.7277
# Epoch 00036: val_accuracy did not improve from 0.69590
# 390/390 [==============================] - 138s 353ms/step - loss: 0.8857 - accuracy: 0.7277 - val_loss: 1.0122 - val_accuracy: 0.6940
# Learning rate:  0.0008010253
# Epoch 37/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8793 - accuracy: 0.7307
# Epoch 00037: val_accuracy did not improve from 0.69590
# 390/390 [==============================] - 136s 349ms/step - loss: 0.8792 - accuracy: 0.7307 - val_loss: 0.9983 - val_accuracy: 0.6933
# Learning rate:  0.0007810669
# Epoch 38/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8755 - accuracy: 0.7333
# Epoch 00038: val_accuracy did not improve from 0.69590
# 390/390 [==============================] - 137s 352ms/step - loss: 0.8757 - accuracy: 0.7331 - val_loss: 1.0507 - val_accuracy: 0.6818
# Learning rate:  0.000762079
# Epoch 39/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8660 - accuracy: 0.7343
# Epoch 00039: val_accuracy did not improve from 0.69590
# 390/390 [==============================] - 143s 366ms/step - loss: 0.8655 - accuracy: 0.7345 - val_loss: 1.0092 - val_accuracy: 0.6928
# Learning rate:  0.0007439923
# Epoch 40/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8588 - accuracy: 0.7381
# Epoch 00040: val_accuracy did not improve from 0.69590
# 390/390 [==============================] - 141s 361ms/step - loss: 0.8589 - accuracy: 0.7380 - val_loss: 1.0054 - val_accuracy: 0.6846
# Learning rate:  0.0007267442
# Epoch 41/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8574 - accuracy: 0.7397
# Epoch 00041: val_accuracy improved from 0.69590 to 0.72040, saving model to /content/saved_models/cifar10_Tesnet18.041.h5
# 390/390 [==============================] - 143s 367ms/step - loss: 0.8575 - accuracy: 0.7398 - val_loss: 0.9094 - val_accuracy: 0.7204
# Learning rate:  0.0007102777
# Epoch 42/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8417 - accuracy: 0.7412
# Epoch 00042: val_accuracy did not improve from 0.72040
# 390/390 [==============================] - 143s 366ms/step - loss: 0.8417 - accuracy: 0.7411 - val_loss: 1.0582 - val_accuracy: 0.6739
# Learning rate:  0.0006945409
# Epoch 43/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8461 - accuracy: 0.7420
# Epoch 00043: val_accuracy did not improve from 0.72040
# 390/390 [==============================] - 142s 363ms/step - loss: 0.8465 - accuracy: 0.7419 - val_loss: 0.9707 - val_accuracy: 0.7036
# Learning rate:  0.0006794863
# Epoch 44/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8377 - accuracy: 0.7448
# Epoch 00044: val_accuracy did not improve from 0.72040
# 390/390 [==============================] - 139s 357ms/step - loss: 0.8379 - accuracy: 0.7447 - val_loss: 0.9621 - val_accuracy: 0.7075
# Learning rate:  0.0006650705
# Epoch 45/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8346 - accuracy: 0.7447
# Epoch 00045: val_accuracy did not improve from 0.72040
# 390/390 [==============================] - 140s 358ms/step - loss: 0.8348 - accuracy: 0.7447 - val_loss: 0.9246 - val_accuracy: 0.7122
# Learning rate:  0.0006512537
# Epoch 46/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8316 - accuracy: 0.7463
# Epoch 00046: val_accuracy did not improve from 0.72040
# 390/390 [==============================] - 141s 361ms/step - loss: 0.8316 - accuracy: 0.7464 - val_loss: 1.0082 - val_accuracy: 0.6969
# Learning rate:  0.0006379992
# Epoch 47/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8245 - accuracy: 0.7479
# Epoch 00047: val_accuracy improved from 0.72040 to 0.73220, saving model to /content/saved_models/cifar10_Tesnet18.047.h5
# 390/390 [==============================] - 141s 362ms/step - loss: 0.8246 - accuracy: 0.7479 - val_loss: 0.8793 - val_accuracy: 0.7322
# Learning rate:  0.0006252736
# Epoch 48/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8150 - accuracy: 0.7492
# Epoch 00048: val_accuracy did not improve from 0.73220
# 390/390 [==============================] - 142s 364ms/step - loss: 0.8151 - accuracy: 0.7492 - val_loss: 1.0325 - val_accuracy: 0.7000
# Learning rate:  0.0006130456
# Epoch 49/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8135 - accuracy: 0.7565
# Epoch 00049: val_accuracy did not improve from 0.73220
# 390/390 [==============================] - 142s 364ms/step - loss: 0.8134 - accuracy: 0.7565 - val_loss: 0.8738 - val_accuracy: 0.7319
# Learning rate:  0.0006012868
# Epoch 50/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8097 - accuracy: 0.7551
# Epoch 00050: val_accuracy did not improve from 0.73220
# 390/390 [==============================] - 142s 365ms/step - loss: 0.8096 - accuracy: 0.7551 - val_loss: 0.9445 - val_accuracy: 0.7114

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
