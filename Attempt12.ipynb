# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavdayal/EIP_Session4/blob/master/Attempt12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, NumpyArrayIterator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import numpy as np
import os
# Out:
# TensorFlow 2.x selected.

# %%
# Training parameters
batch_size = 128
epochs = 50
data_augmentation = True
num_classes = 10

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True,
                 dropout=0):
  
    #TODO: add dropout
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  use_bias=False,
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1_block(x, num_filters, downscale=False, first=False):
  
  # Residual path
  y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1))
  y = resnet_layer(inputs=y, num_filters=num_filters, activation=None)

  # identity. Need to match the output for addition
  if first or downscale:
    x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1, strides = (2 if downscale else 1),  batch_normalization=False, activation=None)

  # add
  x = keras.layers.add([x, y])
  x = Activation('relu')(x)
  return x

# %%
def resnet_v1(input_shape, res_blocks, num_classes=10):
    # Start model definition.
    num_filters = 16

    inputs = Input(shape=input_shape)

    # first convolution before Resnet starts.
    # Should this be done, because we dont want to modify the input
    # But in actual resnet they are doing 7x7, may be they are not doing BN or activation here!!!
    x = resnet_layer(inputs=inputs, num_filters=num_filters)

    # Instantiate the stack of residual units
    for i, blockcount in enumerate(res_blocks):
        num_filters = num_filters*4 if i==0 else num_filters*2
        #num_filters *= 2
        for layer in range(blockcount):
          x = resnet_v1_block(x, num_filters=num_filters, downscale=i>0 and layer==0, first = layer==0 and i==0)

    # Add classifier on top.
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes,
                    activation='softmax', use_bias=False,
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v1(input_shape=input_shape, res_blocks=(2, 2, 2, 2))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.003),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   432         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   36864       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   1024        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 64)   0           conv2d_3[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   36864       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   36864       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           activation_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  73728       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  147456      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  8192        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 128)  0           conv2d_8[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  147456      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  147456      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           activation_6[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 256)    294912      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 256)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 256)    589824      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    32768       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 256)    0           conv2d_13[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    589824      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 256)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 256)    589824      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           activation_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 512)    1179648     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 512)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 512)    2359296     activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 512)    131072      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 512)    0           conv2d_18[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 512)    2359296     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 512)    2359296     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 512)    0           activation_14[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5120        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 11,151,856
# Trainable params: 11,144,144
# Non-trainable params: 7,712
# __________________________________________________________________________________________________

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_Resnet18.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

#lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=3,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer]

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w # area of cutout
            r = np.random.uniform(r_1, r_2) # 
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=True,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=True,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=20,
        # randomly shift images horizontally
        width_shift_range=0.2,
        # randomly shift images vertically
        height_shift_range=0.2,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.2,
        # set range for random channel shifts
        channel_shift_range=0,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_h=1),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    train_iter = NumpyArrayIterator(x=x_train, y=y_train, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    val_iter = NumpyArrayIterator(x=x_test, y=y_test, image_data_generator=datagen, batch_size=batch_size, shuffle=True)

    model.fit_generator(generator = train_iter,
                        steps_per_epoch = (x_train.shape[0]//batch_size), epochs = 50, 
                        validation_data = val_iter, verbose=1, workers=4, callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/50
# 389/390 [============================>.] - ETA: 0s - loss: 2.8177 - accuracy: 0.2941
# Epoch 00001: val_accuracy improved from -inf to 0.28490, saving model to /content/saved_models/cifar10_Resnet18.001.h5
# 390/390 [==============================] - 108s 276ms/step - loss: 2.8161 - accuracy: 0.2943 - val_loss: 2.3561 - val_accuracy: 0.2849
# Epoch 2/50
# 389/390 [============================>.] - ETA: 0s - loss: 2.0355 - accuracy: 0.4136
# Epoch 00002: val_accuracy did not improve from 0.28490
# 390/390 [==============================] - 104s 266ms/step - loss: 2.0356 - accuracy: 0.4136 - val_loss: 9.2241 - val_accuracy: 0.1613
# Epoch 3/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.8098 - accuracy: 0.4600
# Epoch 00003: val_accuracy improved from 0.28490 to 0.44810, saving model to /content/saved_models/cifar10_Resnet18.003.h5
# 390/390 [==============================] - 104s 266ms/step - loss: 1.8090 - accuracy: 0.4603 - val_loss: 1.8100 - val_accuracy: 0.4481
# Epoch 4/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.6258 - accuracy: 0.5194
# Epoch 00004: val_accuracy did not improve from 0.44810
# 390/390 [==============================] - 103s 264ms/step - loss: 1.6258 - accuracy: 0.5192 - val_loss: 2.0148 - val_accuracy: 0.4440
# Epoch 5/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.5157 - accuracy: 0.5613
# Epoch 00005: val_accuracy improved from 0.44810 to 0.45810, saving model to /content/saved_models/cifar10_Resnet18.005.h5
# 390/390 [==============================] - 103s 263ms/step - loss: 1.5156 - accuracy: 0.5616 - val_loss: 2.2795 - val_accuracy: 0.4581
# Epoch 6/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.4493 - accuracy: 0.5842
# Epoch 00006: val_accuracy improved from 0.45810 to 0.55800, saving model to /content/saved_models/cifar10_Resnet18.006.h5
# 390/390 [==============================] - 104s 265ms/step - loss: 1.4491 - accuracy: 0.5843 - val_loss: 1.5010 - val_accuracy: 0.5580
# Epoch 7/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.3758 - accuracy: 0.6158
# Epoch 00007: val_accuracy did not improve from 0.55800
# 390/390 [==============================] - 104s 266ms/step - loss: 1.3754 - accuracy: 0.6159 - val_loss: 1.5412 - val_accuracy: 0.5459
# Epoch 8/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.3305 - accuracy: 0.6333
# Epoch 00008: val_accuracy improved from 0.55800 to 0.58110, saving model to /content/saved_models/cifar10_Resnet18.008.h5
# 390/390 [==============================] - 106s 271ms/step - loss: 1.3304 - accuracy: 0.6334 - val_loss: 1.4756 - val_accuracy: 0.5811
# Epoch 9/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2605 - accuracy: 0.6563
# Epoch 00009: val_accuracy did not improve from 0.58110
# 390/390 [==============================] - 104s 267ms/step - loss: 1.2603 - accuracy: 0.6564 - val_loss: 1.8340 - val_accuracy: 0.4701
# Epoch 10/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2382 - accuracy: 0.6669
# Epoch 00010: val_accuracy did not improve from 0.58110
# 390/390 [==============================] - 104s 268ms/step - loss: 1.2380 - accuracy: 0.6669 - val_loss: 2.2857 - val_accuracy: 0.4534
# Epoch 11/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1845 - accuracy: 0.6843
# Epoch 00011: val_accuracy did not improve from 0.58110
# 390/390 [==============================] - 103s 264ms/step - loss: 1.1845 - accuracy: 0.6842 - val_loss: 1.4944 - val_accuracy: 0.5724
# Epoch 12/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9959 - accuracy: 0.7399
# Epoch 00012: val_accuracy improved from 0.58110 to 0.73290, saving model to /content/saved_models/cifar10_Resnet18.012.h5
# 390/390 [==============================] - 105s 268ms/step - loss: 0.9956 - accuracy: 0.7400 - val_loss: 0.9982 - val_accuracy: 0.7329
# Epoch 13/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9286 - accuracy: 0.7546
# Epoch 00013: val_accuracy did not improve from 0.73290
# 390/390 [==============================] - 104s 266ms/step - loss: 0.9287 - accuracy: 0.7546 - val_loss: 1.0378 - val_accuracy: 0.7153
# Epoch 14/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9053 - accuracy: 0.7601
# Epoch 00014: val_accuracy improved from 0.73290 to 0.74000, saving model to /content/saved_models/cifar10_Resnet18.014.h5
# 390/390 [==============================] - 106s 273ms/step - loss: 0.9049 - accuracy: 0.7602 - val_loss: 0.9691 - val_accuracy: 0.7400
# Epoch 15/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8744 - accuracy: 0.7683
# Epoch 00015: val_accuracy did not improve from 0.74000
# 390/390 [==============================] - 104s 267ms/step - loss: 0.8744 - accuracy: 0.7682 - val_loss: 1.0002 - val_accuracy: 0.7242
# Epoch 16/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8504 - accuracy: 0.7759
# Epoch 00016: val_accuracy did not improve from 0.74000
# 390/390 [==============================] - 103s 264ms/step - loss: 0.8510 - accuracy: 0.7756 - val_loss: 0.9574 - val_accuracy: 0.7366
# Epoch 17/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8414 - accuracy: 0.7807
# Epoch 00017: val_accuracy did not improve from 0.74000
# 390/390 [==============================] - 105s 268ms/step - loss: 0.8411 - accuracy: 0.7807 - val_loss: 1.0582 - val_accuracy: 0.6996
# Epoch 18/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8201 - accuracy: 0.7836
# Epoch 00018: val_accuracy improved from 0.74000 to 0.77130, saving model to /content/saved_models/cifar10_Resnet18.018.h5
# 390/390 [==============================] - 105s 270ms/step - loss: 0.8199 - accuracy: 0.7837 - val_loss: 0.8572 - val_accuracy: 0.7713
# Epoch 19/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8066 - accuracy: 0.7878
# Epoch 00019: val_accuracy did not improve from 0.77130
# 390/390 [==============================] - 103s 263ms/step - loss: 0.8065 - accuracy: 0.7878 - val_loss: 0.9567 - val_accuracy: 0.7402
# Epoch 20/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7866 - accuracy: 0.7930
# Epoch 00020: val_accuracy did not improve from 0.77130
# 390/390 [==============================] - 103s 263ms/step - loss: 0.7865 - accuracy: 0.7930 - val_loss: 0.8781 - val_accuracy: 0.7638
# Epoch 21/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7696 - accuracy: 0.7973
# Epoch 00021: val_accuracy did not improve from 0.77130
# 390/390 [==============================] - 101s 260ms/step - loss: 0.7695 - accuracy: 0.7973 - val_loss: 0.8735 - val_accuracy: 0.7677
# Epoch 22/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7028 - accuracy: 0.8222
# Epoch 00022: val_accuracy improved from 0.77130 to 0.80450, saving model to /content/saved_models/cifar10_Resnet18.022.h5
# 390/390 [==============================] - 100s 257ms/step - loss: 0.7026 - accuracy: 0.8223 - val_loss: 0.7425 - val_accuracy: 0.8045
# Epoch 23/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.8291
# Epoch 00023: val_accuracy did not improve from 0.80450
# 390/390 [==============================] - 101s 260ms/step - loss: 0.6710 - accuracy: 0.8291 - val_loss: 0.7937 - val_accuracy: 0.7901
# Epoch 24/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6566 - accuracy: 0.8317
# Epoch 00024: val_accuracy improved from 0.80450 to 0.80520, saving model to /content/saved_models/cifar10_Resnet18.024.h5
# 390/390 [==============================] - 99s 255ms/step - loss: 0.6564 - accuracy: 0.8317 - val_loss: 0.7322 - val_accuracy: 0.8052
# Epoch 25/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6447 - accuracy: 0.8380
# Epoch 00025: val_accuracy improved from 0.80520 to 0.81820, saving model to /content/saved_models/cifar10_Resnet18.025.h5
# 390/390 [==============================] - 99s 253ms/step - loss: 0.6451 - accuracy: 0.8379 - val_loss: 0.7120 - val_accuracy: 0.8182
# Epoch 26/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6343 - accuracy: 0.8383
# Epoch 00026: val_accuracy did not improve from 0.81820
# 390/390 [==============================] - 98s 251ms/step - loss: 0.6343 - accuracy: 0.8383 - val_loss: 0.7236 - val_accuracy: 0.8151
# Epoch 27/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6335 - accuracy: 0.8399
# Epoch 00027: val_accuracy did not improve from 0.81820
# 390/390 [==============================] - 98s 252ms/step - loss: 0.6335 - accuracy: 0.8399 - val_loss: 0.7132 - val_accuracy: 0.8105
# Epoch 28/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6203 - accuracy: 0.8426
# Epoch 00028: val_accuracy improved from 0.81820 to 0.82180, saving model to /content/saved_models/cifar10_Resnet18.028.h5
# 390/390 [==============================] - 98s 252ms/step - loss: 0.6204 - accuracy: 0.8426 - val_loss: 0.6800 - val_accuracy: 0.8218
# Epoch 29/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6073 - accuracy: 0.8474
# Epoch 00029: val_accuracy improved from 0.82180 to 0.82190, saving model to /content/saved_models/cifar10_Resnet18.029.h5
# 390/390 [==============================] - 98s 252ms/step - loss: 0.6072 - accuracy: 0.8474 - val_loss: 0.6826 - val_accuracy: 0.8219
# Epoch 30/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6041 - accuracy: 0.8461
# Epoch 00030: val_accuracy did not improve from 0.82190
# 390/390 [==============================] - 98s 250ms/step - loss: 0.6040 - accuracy: 0.8461 - val_loss: 0.6953 - val_accuracy: 0.8170
# Epoch 31/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5911 - accuracy: 0.8486
# Epoch 00031: val_accuracy did not improve from 0.82190
# 390/390 [==============================] - 98s 251ms/step - loss: 0.5908 - accuracy: 0.8487 - val_loss: 0.7582 - val_accuracy: 0.8016
# Epoch 32/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5636 - accuracy: 0.8612
# Epoch 00032: val_accuracy improved from 0.82190 to 0.83170, saving model to /content/saved_models/cifar10_Resnet18.032.h5
# 390/390 [==============================] - 98s 251ms/step - loss: 0.5634 - accuracy: 0.8613 - val_loss: 0.6415 - val_accuracy: 0.8317
# Epoch 33/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5548 - accuracy: 0.8628
# Epoch 00033: val_accuracy improved from 0.83170 to 0.84160, saving model to /content/saved_models/cifar10_Resnet18.033.h5
# 390/390 [==============================] - 98s 250ms/step - loss: 0.5551 - accuracy: 0.8627 - val_loss: 0.6227 - val_accuracy: 0.8416
# Epoch 34/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5418 - accuracy: 0.8676
# Epoch 00034: val_accuracy did not improve from 0.84160
# 390/390 [==============================] - 97s 250ms/step - loss: 0.5418 - accuracy: 0.8676 - val_loss: 0.6218 - val_accuracy: 0.8387
# Epoch 35/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5423 - accuracy: 0.8656
# Epoch 00035: val_accuracy improved from 0.84160 to 0.84680, saving model to /content/saved_models/cifar10_Resnet18.035.h5
# 390/390 [==============================] - 98s 251ms/step - loss: 0.5421 - accuracy: 0.8657 - val_loss: 0.6015 - val_accuracy: 0.8468
# Epoch 36/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.8690
# Epoch 00036: val_accuracy did not improve from 0.84680
# 390/390 [==============================] - 97s 249ms/step - loss: 0.5348 - accuracy: 0.8693 - val_loss: 0.6064 - val_accuracy: 0.8454
# Epoch 37/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5240 - accuracy: 0.8729
# Epoch 00037: val_accuracy did not improve from 0.84680
# 390/390 [==============================] - 98s 250ms/step - loss: 0.5240 - accuracy: 0.8729 - val_loss: 0.6143 - val_accuracy: 0.8429
# Epoch 38/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5254 - accuracy: 0.8713
# Epoch 00038: val_accuracy did not improve from 0.84680
# 390/390 [==============================] - 97s 248ms/step - loss: 0.5252 - accuracy: 0.8714 - val_loss: 0.6060 - val_accuracy: 0.8435
# Epoch 39/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5133 - accuracy: 0.8753
# Epoch 00039: val_accuracy improved from 0.84680 to 0.85050, saving model to /content/saved_models/cifar10_Resnet18.039.h5
# 390/390 [==============================] - 97s 250ms/step - loss: 0.5133 - accuracy: 0.8753 - val_loss: 0.5877 - val_accuracy: 0.8505
# Epoch 40/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5043 - accuracy: 0.8776
# Epoch 00040: val_accuracy did not improve from 0.85050
# 390/390 [==============================] - 98s 252ms/step - loss: 0.5044 - accuracy: 0.8776 - val_loss: 0.5967 - val_accuracy: 0.8459
# Epoch 41/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5067 - accuracy: 0.8774
# Epoch 00041: val_accuracy improved from 0.85050 to 0.85080, saving model to /content/saved_models/cifar10_Resnet18.041.h5
# 390/390 [==============================] - 98s 251ms/step - loss: 0.5068 - accuracy: 0.8774 - val_loss: 0.5907 - val_accuracy: 0.8508
# Epoch 42/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4999 - accuracy: 0.8793
# Epoch 00042: val_accuracy improved from 0.85080 to 0.85400, saving model to /content/saved_models/cifar10_Resnet18.042.h5
# 390/390 [==============================] - 98s 250ms/step - loss: 0.5001 - accuracy: 0.8792 - val_loss: 0.5858 - val_accuracy: 0.8540
# Epoch 43/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4950 - accuracy: 0.8827
# Epoch 00043: val_accuracy did not improve from 0.85400
# 390/390 [==============================] - 98s 250ms/step - loss: 0.4954 - accuracy: 0.8825 - val_loss: 0.5890 - val_accuracy: 0.8520
# Epoch 44/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5002 - accuracy: 0.8789
# Epoch 00044: val_accuracy did not improve from 0.85400
# 390/390 [==============================] - 97s 249ms/step - loss: 0.5001 - accuracy: 0.8789 - val_loss: 0.5817 - val_accuracy: 0.8516
# Epoch 45/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4942 - accuracy: 0.8814
# Epoch 00045: val_accuracy did not improve from 0.85400
# 390/390 [==============================] - 97s 248ms/step - loss: 0.4942 - accuracy: 0.8815 - val_loss: 0.5951 - val_accuracy: 0.8473
# Epoch 46/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4969 - accuracy: 0.8807
# Epoch 00046: val_accuracy did not improve from 0.85400
# 390/390 [==============================] - 97s 248ms/step - loss: 0.4970 - accuracy: 0.8807 - val_loss: 0.5780 - val_accuracy: 0.8533
# Epoch 47/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4887 - accuracy: 0.8820
# Epoch 00047: val_accuracy did not improve from 0.85400
# 390/390 [==============================] - 97s 248ms/step - loss: 0.4889 - accuracy: 0.8820 - val_loss: 0.5800 - val_accuracy: 0.8536
# Epoch 48/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4930 - accuracy: 0.8800
# Epoch 00048: val_accuracy did not improve from 0.85400
# 390/390 [==============================] - 97s 247ms/step - loss: 0.4929 - accuracy: 0.8800 - val_loss: 0.5771 - val_accuracy: 0.8512
# Epoch 49/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4877 - accuracy: 0.8850
# Epoch 00049: val_accuracy did not improve from 0.85400
# 390/390 [==============================] - 96s 247ms/step - loss: 0.4880 - accuracy: 0.8848 - val_loss: 0.5887 - val_accuracy: 0.8510
# Epoch 50/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4875 - accuracy: 0.8826
# Epoch 00050: val_accuracy did not improve from 0.85400
# 390/390 [==============================] - 97s 249ms/step - loss: 0.4876 - accuracy: 0.8826 - val_loss: 0.5887 - val_accuracy: 0.8511
