# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavdayal/EIP_Session4/blob/master/Attempt11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, NumpyArrayIterator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import numpy as np
import os

# %%
# Training parameters
batch_size = 128
epochs = 50
data_augmentation = True
num_classes = 10

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True,
                 dropout=0):
  
    #TODO: add dropout
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  use_bias=False,
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1_block(x, num_filters, downscale=False, first=False):
  
  # Residual path
  y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1))
  y = resnet_layer(inputs=y, num_filters=num_filters, activation=None)

  # identity. Need to match the output for addition
  if first or downscale:
    x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1, strides = (2 if downscale else 1),  batch_normalization=False, activation=None)

  # add
  x = keras.layers.add([x, y])
  x = Activation('relu')(x)
  return x

# %%
def resnet_v1(input_shape, res_blocks, num_classes=10):
    # Start model definition.
    num_filters = 16

    inputs = Input(shape=input_shape)

    # first convolution before Resnet starts.
    # Should this be done, because we dont want to modify the input
    # But in actual resnet they are doing 7x7, may be they are not doing BN or activation here!!!
    x = resnet_layer(inputs=inputs, num_filters=num_filters)

    # Instantiate the stack of residual units
    for i, blockcount in enumerate(res_blocks):
        num_filters = num_filters*2
        #num_filters *= 2
        for layer in range(blockcount):
          x = resnet_v1_block(x, num_filters=num_filters, downscale=i>0 and layer==0, first = layer==0 and i==0)

    # Add classifier on top.
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes,
                    activation='softmax', use_bias=False,
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v1(input_shape=input_shape, res_blocks=(2, 2, 2, 2))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.003),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   432         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   4608        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9216        activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   512         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 32)   0           conv2d_4[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9216        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 32)   9216        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   18432       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   36864       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   2048        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 64)   0           conv2d_9[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36864       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   36864       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 64)   0           activation_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 128)    73728       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 128)    512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 128)    147456      activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    8192        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 128)    512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 128)    0           conv2d_14[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 128)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    147456      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 128)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 128)    147456      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 128)    512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 128)    0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 128)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 256)    294912      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 256)    1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 256)    589824      activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 256)    32768       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 256)    1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 256)    0           conv2d_19[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 256)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    589824      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 256)    589824      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 256)    0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 256)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           activation_17[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           2560        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 2,796,016
# Trainable params: 2,792,144
# Non-trainable params: 3,872
# __________________________________________________________________________________________________

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_Resnet18.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

#lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=3,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer]

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w # area of cutout
            r = np.random.uniform(r_1, r_2) # 
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=True,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=True,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=20,
        # randomly shift images horizontally
        width_shift_range=0.2,
        # randomly shift images vertically
        height_shift_range=0.2,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.2,
        # set range for random channel shifts
        channel_shift_range=0,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_h=1),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    train_iter = NumpyArrayIterator(x=x_train, y=y_train, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    val_iter = NumpyArrayIterator(x=x_test, y=y_test, image_data_generator=datagen, batch_size=batch_size, shuffle=True)

    model.fit_generator(generator = train_iter,
                        steps_per_epoch = (x_train.shape[0]//batch_size), epochs = 50, 
                        validation_data = val_iter, verbose=1, workers=4, callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/50
# 389/390 [============================>.] - ETA: 0s - loss: 2.2044 - accuracy: 0.3537
# Epoch 00001: val_accuracy improved from -inf to 0.37260, saving model to /content/saved_models/cifar10_Resnet18.001.h5
# 390/390 [==============================] - 115s 295ms/step - loss: 2.2035 - accuracy: 0.3540 - val_loss: 1.9704 - val_accuracy: 0.3726
# Epoch 2/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.7043 - accuracy: 0.4813
# Epoch 00002: val_accuracy improved from 0.37260 to 0.46490, saving model to /content/saved_models/cifar10_Resnet18.002.h5
# 390/390 [==============================] - 110s 282ms/step - loss: 1.7040 - accuracy: 0.4816 - val_loss: 1.7180 - val_accuracy: 0.4649
# Epoch 3/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.5250 - accuracy: 0.5457
# Epoch 00003: val_accuracy did not improve from 0.46490
# 390/390 [==============================] - 108s 277ms/step - loss: 1.5253 - accuracy: 0.5455 - val_loss: 1.8073 - val_accuracy: 0.4574
# Epoch 4/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.4343 - accuracy: 0.5780
# Epoch 00004: val_accuracy improved from 0.46490 to 0.49810, saving model to /content/saved_models/cifar10_Resnet18.004.h5
# 390/390 [==============================] - 106s 271ms/step - loss: 1.4341 - accuracy: 0.5782 - val_loss: 1.6707 - val_accuracy: 0.4981
# Epoch 5/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.3534 - accuracy: 0.6114
# Epoch 00005: val_accuracy improved from 0.49810 to 0.56090, saving model to /content/saved_models/cifar10_Resnet18.005.h5
# 390/390 [==============================] - 106s 272ms/step - loss: 1.3538 - accuracy: 0.6112 - val_loss: 1.5688 - val_accuracy: 0.5609
# Epoch 6/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2903 - accuracy: 0.6378
# Epoch 00006: val_accuracy improved from 0.56090 to 0.57140, saving model to /content/saved_models/cifar10_Resnet18.006.h5
# 390/390 [==============================] - 104s 267ms/step - loss: 1.2905 - accuracy: 0.6377 - val_loss: 1.4547 - val_accuracy: 0.5714
# Epoch 7/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2342 - accuracy: 0.6618
# Epoch 00007: val_accuracy improved from 0.57140 to 0.58420, saving model to /content/saved_models/cifar10_Resnet18.007.h5
# 390/390 [==============================] - 104s 267ms/step - loss: 1.2342 - accuracy: 0.6619 - val_loss: 1.4965 - val_accuracy: 0.5842
# Epoch 8/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1939 - accuracy: 0.6757
# Epoch 00008: val_accuracy improved from 0.58420 to 0.58730, saving model to /content/saved_models/cifar10_Resnet18.008.h5
# 390/390 [==============================] - 104s 266ms/step - loss: 1.1942 - accuracy: 0.6755 - val_loss: 1.5073 - val_accuracy: 0.5873
# Epoch 9/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1518 - accuracy: 0.6916
# Epoch 00009: val_accuracy did not improve from 0.58730
# 390/390 [==============================] - 103s 263ms/step - loss: 1.1520 - accuracy: 0.6916 - val_loss: 1.5846 - val_accuracy: 0.5773
# Epoch 10/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9791 - accuracy: 0.7442
# Epoch 00010: val_accuracy improved from 0.58730 to 0.72520, saving model to /content/saved_models/cifar10_Resnet18.010.h5
# 390/390 [==============================] - 103s 263ms/step - loss: 0.9786 - accuracy: 0.7443 - val_loss: 1.0204 - val_accuracy: 0.7252
# Epoch 11/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9173 - accuracy: 0.7595
# Epoch 00011: val_accuracy improved from 0.72520 to 0.73530, saving model to /content/saved_models/cifar10_Resnet18.011.h5
# 390/390 [==============================] - 103s 265ms/step - loss: 0.9173 - accuracy: 0.7596 - val_loss: 0.9650 - val_accuracy: 0.7353
# Epoch 12/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8838 - accuracy: 0.7667
# Epoch 00012: val_accuracy improved from 0.73530 to 0.74210, saving model to /content/saved_models/cifar10_Resnet18.012.h5
# 390/390 [==============================] - 103s 263ms/step - loss: 0.8844 - accuracy: 0.7666 - val_loss: 0.9531 - val_accuracy: 0.7421
# Epoch 13/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8639 - accuracy: 0.7699
# Epoch 00013: val_accuracy did not improve from 0.74210
# 390/390 [==============================] - 102s 262ms/step - loss: 0.8635 - accuracy: 0.7701 - val_loss: 0.9817 - val_accuracy: 0.7330
# Epoch 14/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8325 - accuracy: 0.7804
# Epoch 00014: val_accuracy did not improve from 0.74210
# 390/390 [==============================] - 103s 264ms/step - loss: 0.8323 - accuracy: 0.7804 - val_loss: 0.9401 - val_accuracy: 0.7412
# Epoch 15/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8157 - accuracy: 0.7854
# Epoch 00015: val_accuracy improved from 0.74210 to 0.75480, saving model to /content/saved_models/cifar10_Resnet18.015.h5
# 390/390 [==============================] - 103s 263ms/step - loss: 0.8154 - accuracy: 0.7855 - val_loss: 0.9130 - val_accuracy: 0.7548
# Epoch 16/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8020 - accuracy: 0.7896
# Epoch 00016: val_accuracy did not improve from 0.75480
# 390/390 [==============================] - 102s 262ms/step - loss: 0.8023 - accuracy: 0.7895 - val_loss: 0.9513 - val_accuracy: 0.7437
# Epoch 17/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7856 - accuracy: 0.7955
# Epoch 00017: val_accuracy did not improve from 0.75480
# 390/390 [==============================] - 102s 263ms/step - loss: 0.7859 - accuracy: 0.7954 - val_loss: 0.9311 - val_accuracy: 0.7476
# Epoch 18/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7756 - accuracy: 0.7984
# Epoch 00018: val_accuracy did not improve from 0.75480
# 390/390 [==============================] - 103s 263ms/step - loss: 0.7755 - accuracy: 0.7985 - val_loss: 0.9185 - val_accuracy: 0.7488
# Epoch 19/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7032 - accuracy: 0.8190
# Epoch 00019: val_accuracy improved from 0.75480 to 0.79750, saving model to /content/saved_models/cifar10_Resnet18.019.h5
# 390/390 [==============================] - 102s 262ms/step - loss: 0.7033 - accuracy: 0.8190 - val_loss: 0.7593 - val_accuracy: 0.7975
# Epoch 20/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6702 - accuracy: 0.8318
# Epoch 00020: val_accuracy improved from 0.79750 to 0.79820, saving model to /content/saved_models/cifar10_Resnet18.020.h5
# 390/390 [==============================] - 103s 263ms/step - loss: 0.6699 - accuracy: 0.8319 - val_loss: 0.7675 - val_accuracy: 0.7982
# Epoch 21/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6527 - accuracy: 0.8361
# Epoch 00021: val_accuracy improved from 0.79820 to 0.81010, saving model to /content/saved_models/cifar10_Resnet18.021.h5
# 390/390 [==============================] - 102s 263ms/step - loss: 0.6530 - accuracy: 0.8361 - val_loss: 0.7223 - val_accuracy: 0.8101
# Epoch 22/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6456 - accuracy: 0.8365
# Epoch 00022: val_accuracy improved from 0.81010 to 0.82160, saving model to /content/saved_models/cifar10_Resnet18.022.h5
# 390/390 [==============================] - 102s 262ms/step - loss: 0.6458 - accuracy: 0.8364 - val_loss: 0.7083 - val_accuracy: 0.8216
# Epoch 23/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6308 - accuracy: 0.8415
# Epoch 00023: val_accuracy did not improve from 0.82160
# 390/390 [==============================] - 102s 261ms/step - loss: 0.6307 - accuracy: 0.8415 - val_loss: 0.7327 - val_accuracy: 0.8079
# Epoch 24/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6221 - accuracy: 0.8426
# Epoch 00024: val_accuracy did not improve from 0.82160
# 390/390 [==============================] - 102s 262ms/step - loss: 0.6222 - accuracy: 0.8427 - val_loss: 0.7077 - val_accuracy: 0.8131
# Epoch 25/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6136 - accuracy: 0.8447
# Epoch 00025: val_accuracy did not improve from 0.82160
# 390/390 [==============================] - 102s 262ms/step - loss: 0.6137 - accuracy: 0.8446 - val_loss: 0.6872 - val_accuracy: 0.8173
# Epoch 26/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6066 - accuracy: 0.8467
# Epoch 00026: val_accuracy did not improve from 0.82160
# 390/390 [==============================] - 102s 263ms/step - loss: 0.6064 - accuracy: 0.8467 - val_loss: 0.7127 - val_accuracy: 0.8148
# Epoch 27/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5962 - accuracy: 0.8492
# Epoch 00027: val_accuracy did not improve from 0.82160
# 390/390 [==============================] - 102s 261ms/step - loss: 0.5962 - accuracy: 0.8493 - val_loss: 0.6745 - val_accuracy: 0.8202
# Epoch 28/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5951 - accuracy: 0.8499
# Epoch 00028: val_accuracy improved from 0.82160 to 0.83410, saving model to /content/saved_models/cifar10_Resnet18.028.h5
# 390/390 [==============================] - 102s 263ms/step - loss: 0.5950 - accuracy: 0.8499 - val_loss: 0.6457 - val_accuracy: 0.8341
# Epoch 29/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5863 - accuracy: 0.8515
# Epoch 00029: val_accuracy did not improve from 0.83410
# 390/390 [==============================] - 102s 262ms/step - loss: 0.5864 - accuracy: 0.8514 - val_loss: 0.6984 - val_accuracy: 0.8153
# Epoch 30/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5791 - accuracy: 0.8533
# Epoch 00030: val_accuracy did not improve from 0.83410
# 390/390 [==============================] - 103s 265ms/step - loss: 0.5792 - accuracy: 0.8533 - val_loss: 0.6840 - val_accuracy: 0.8153
# Epoch 31/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5704 - accuracy: 0.8566
# Epoch 00031: val_accuracy did not improve from 0.83410
# 390/390 [==============================] - 102s 261ms/step - loss: 0.5705 - accuracy: 0.8566 - val_loss: 0.6727 - val_accuracy: 0.8264
# Epoch 32/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5430 - accuracy: 0.8656
# Epoch 00032: val_accuracy improved from 0.83410 to 0.83940, saving model to /content/saved_models/cifar10_Resnet18.032.h5
# 390/390 [==============================] - 102s 263ms/step - loss: 0.5429 - accuracy: 0.8656 - val_loss: 0.6205 - val_accuracy: 0.8394
# Epoch 33/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5249 - accuracy: 0.8713
# Epoch 00033: val_accuracy improved from 0.83940 to 0.84520, saving model to /content/saved_models/cifar10_Resnet18.033.h5
# 390/390 [==============================] - 102s 263ms/step - loss: 0.5250 - accuracy: 0.8713 - val_loss: 0.6091 - val_accuracy: 0.8452
# Epoch 34/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5214 - accuracy: 0.8721
# Epoch 00034: val_accuracy improved from 0.84520 to 0.84610, saving model to /content/saved_models/cifar10_Resnet18.034.h5
# 390/390 [==============================] - 102s 262ms/step - loss: 0.5212 - accuracy: 0.8721 - val_loss: 0.6004 - val_accuracy: 0.8461
# Epoch 35/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5195 - accuracy: 0.8724
# Epoch 00035: val_accuracy improved from 0.84610 to 0.84810, saving model to /content/saved_models/cifar10_Resnet18.035.h5
# 390/390 [==============================] - 103s 264ms/step - loss: 0.5198 - accuracy: 0.8723 - val_loss: 0.5961 - val_accuracy: 0.8481
# Epoch 36/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5163 - accuracy: 0.8730
# Epoch 00036: val_accuracy did not improve from 0.84810
# 390/390 [==============================] - 102s 262ms/step - loss: 0.5163 - accuracy: 0.8730 - val_loss: 0.6017 - val_accuracy: 0.8454
# Epoch 37/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5173 - accuracy: 0.8717
# Epoch 00037: val_accuracy did not improve from 0.84810
# 390/390 [==============================] - 102s 261ms/step - loss: 0.5169 - accuracy: 0.8718 - val_loss: 0.6076 - val_accuracy: 0.8466
# Epoch 38/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5111 - accuracy: 0.8767
# Epoch 00038: val_accuracy did not improve from 0.84810
# 390/390 [==============================] - 103s 263ms/step - loss: 0.5112 - accuracy: 0.8767 - val_loss: 0.6004 - val_accuracy: 0.8420
# Epoch 39/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4993 - accuracy: 0.8798
# Epoch 00039: val_accuracy improved from 0.84810 to 0.85280, saving model to /content/saved_models/cifar10_Resnet18.039.h5
# 390/390 [==============================] - 102s 263ms/step - loss: 0.4991 - accuracy: 0.8799 - val_loss: 0.5907 - val_accuracy: 0.8528
# Epoch 40/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4973 - accuracy: 0.8792
# Epoch 00040: val_accuracy improved from 0.85280 to 0.85710, saving model to /content/saved_models/cifar10_Resnet18.040.h5
# 390/390 [==============================] - 102s 262ms/step - loss: 0.4972 - accuracy: 0.8792 - val_loss: 0.5694 - val_accuracy: 0.8571
# Epoch 41/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4972 - accuracy: 0.8798
# Epoch 00041: val_accuracy did not improve from 0.85710
# 390/390 [==============================] - 102s 262ms/step - loss: 0.4972 - accuracy: 0.8799 - val_loss: 0.5791 - val_accuracy: 0.8515
# Epoch 42/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4856 - accuracy: 0.8825
# Epoch 00042: val_accuracy did not improve from 0.85710
# 390/390 [==============================] - 102s 262ms/step - loss: 0.4856 - accuracy: 0.8824 - val_loss: 0.5774 - val_accuracy: 0.8542
# Epoch 43/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4863 - accuracy: 0.8812
# Epoch 00043: val_accuracy did not improve from 0.85710
# 390/390 [==============================] - 102s 262ms/step - loss: 0.4862 - accuracy: 0.8813 - val_loss: 0.5623 - val_accuracy: 0.8539
# Epoch 44/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4900 - accuracy: 0.8810
# Epoch 00044: val_accuracy did not improve from 0.85710
# 390/390 [==============================] - 102s 263ms/step - loss: 0.4899 - accuracy: 0.8810 - val_loss: 0.5798 - val_accuracy: 0.8504
# Epoch 45/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4831 - accuracy: 0.8855
# Epoch 00045: val_accuracy did not improve from 0.85710
# 390/390 [==============================] - 102s 262ms/step - loss: 0.4830 - accuracy: 0.8856 - val_loss: 0.5751 - val_accuracy: 0.8531
# Epoch 46/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4826 - accuracy: 0.8848
# Epoch 00046: val_accuracy did not improve from 0.85710
# 390/390 [==============================] - 102s 261ms/step - loss: 0.4827 - accuracy: 0.8848 - val_loss: 0.5785 - val_accuracy: 0.8538
# Epoch 47/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4784 - accuracy: 0.8837
# Epoch 00047: val_accuracy improved from 0.85710 to 0.86030, saving model to /content/saved_models/cifar10_Resnet18.047.h5
# 390/390 [==============================] - 103s 263ms/step - loss: 0.4788 - accuracy: 0.8836 - val_loss: 0.5535 - val_accuracy: 0.8603
# Epoch 48/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4787 - accuracy: 0.8834
# Epoch 00048: val_accuracy did not improve from 0.86030
# 390/390 [==============================] - 102s 261ms/step - loss: 0.4785 - accuracy: 0.8834 - val_loss: 0.5621 - val_accuracy: 0.8566
# Epoch 49/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4775 - accuracy: 0.8851
# Epoch 00049: val_accuracy did not improve from 0.86030
# 390/390 [==============================] - 102s 261ms/step - loss: 0.4773 - accuracy: 0.8851 - val_loss: 0.5731 - val_accuracy: 0.8525
# Epoch 50/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4800 - accuracy: 0.8840
# Epoch 00050: val_accuracy did not improve from 0.86030
# 390/390 [==============================] - 102s 261ms/step - loss: 0.4799 - accuracy: 0.8840 - val_loss: 0.5730 - val_accuracy: 0.8557
