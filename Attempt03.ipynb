# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavdayal/EIP_Session4/blob/master/Attempt03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, NumpyArrayIterator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import numpy as np
import os
# Out:
# TensorFlow 2.x selected.

# %%
# Training parameters
batch_size = 128
epochs = 50
data_augmentation = True
num_classes = 10

# %%
# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def lr_schedule(epoch):
    lr = round(0.01 * 1/(1 + 0.319 * epoch), 10)
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True,
                 dropout=0):
  
    #TODO: add dropout
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  use_bias=False,
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1_block(x, num_filters, downscale=False, first=False):
  
  # Residual path
  y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1))
  y = resnet_layer(inputs=y, num_filters=num_filters, activation=None)

  # identity. Need to match the output for addition
  if first or downscale:
    x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1, strides = (2 if downscale else 1))

  # add
  x = keras.layers.add([x, y])
  x = Activation('relu')(x)

  return x

# %%
def resnet_v1(input_shape, res_blocks, num_classes=10):
    # Start model definition.
    

    inputs = Input(shape=input_shape)

    # first convolution before Resnet starts.
    # Should this be done, because we dont want to modify the input
    # But in actual resnet they are doing 7x7, may be they are not doing BN or activation here!!!
    x = resnet_layer(inputs=inputs, num_filters=16)

    num_filters = 64
    # Instantiate the stack of residual units
    for i, blockcount in enumerate(res_blocks):
        for layer in range(blockcount):
            x = resnet_v1_block(x, num_filters=num_filters, downscale=i>0 and layer==0, first = layer==0 and i==0)
        num_filters *= 2

    # Add classifier on top.
    x = AveragePooling2D(pool_size=4)(x)
    x = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax', use_bias=False,
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v1(input_shape=input_shape, res_blocks=(2, 2, 2, 2))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# Learning rate:  0.01
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   432         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   1024        activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   36864       activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 64)   0           activation_3[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   36864       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36864       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           activation_4[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  73728       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  8192        activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  147456      activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 128)  0           activation_8[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  147456      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  147456      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           activation_9[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 256)    294912      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    32768       activation_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    589824      activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 256)    1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 256)    0           activation_13[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 256)    589824      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    589824      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 256)    1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           activation_14[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 512)    1179648     activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 512)    131072      activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 512)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 512)    2359296     activation_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, 4, 512)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 512)    0           activation_18[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, 4, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 512)    2359296     activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 4, 4, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, 4, 512)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 512)    2359296     activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, 4, 512)    2048        conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 512)    0           activation_19[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4, 4, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 512)    0           activation_21[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5120        flatten[0][0]
# ==================================================================================================
# Total params: 11,155,696
# Trainable params: 11,146,064
# Non-trainable params: 9,632
# __________________________________________________________________________________________________

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_Tesnet18.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

#lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer]

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w # area of cutout
            r = np.random.uniform(r_1, r_2) # 
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=True),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    train_iter = NumpyArrayIterator(x=x_train, y=y_train, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    val_iter = NumpyArrayIterator(x=x_test, y=y_test, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    #datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    #model.fit_generator(,
    #                    val_iter,
    #                    epochs=epochs, verbose=1, workers=4,
    #                   callbacks=callbacks)
    model.fit_generator(generator = train_iter,
                        steps_per_epoch = (x_train.shape[0]//batch_size), epochs = 50, 
                        validation_data = val_iter, verbose=1, workers=4, callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/50
# 389/390 [============================>.] - ETA: 0s - loss: 3.3348 - accuracy: 0.2837
# Epoch 00001: val_accuracy improved from -inf to 0.13000, saving model to /content/saved_models/cifar10_Tesnet18.001.h5
# 390/390 [==============================] - 103s 265ms/step - loss: 3.3320 - accuracy: 0.2838 - val_loss: 3.0477 - val_accuracy: 0.1300
# Epoch 2/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.9818 - accuracy: 0.4153
# Epoch 00002: val_accuracy improved from 0.13000 to 0.33980, saving model to /content/saved_models/cifar10_Tesnet18.002.h5
# 390/390 [==============================] - 99s 254ms/step - loss: 1.9813 - accuracy: 0.4154 - val_loss: 2.1613 - val_accuracy: 0.3398
# Epoch 3/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.6976 - accuracy: 0.4966
# Epoch 00003: val_accuracy did not improve from 0.33980
# 390/390 [==============================] - 99s 254ms/step - loss: 1.6969 - accuracy: 0.4969 - val_loss: 2.3509 - val_accuracy: 0.3358
# Epoch 4/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.4921 - accuracy: 0.5557
# Epoch 00004: val_accuracy improved from 0.33980 to 0.47730, saving model to /content/saved_models/cifar10_Tesnet18.004.h5
# 390/390 [==============================] - 99s 255ms/step - loss: 1.4920 - accuracy: 0.5557 - val_loss: 1.6722 - val_accuracy: 0.4773
# Epoch 5/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.3900 - accuracy: 0.5906
# Epoch 00005: val_accuracy did not improve from 0.47730
# 390/390 [==============================] - 99s 253ms/step - loss: 1.3905 - accuracy: 0.5905 - val_loss: 2.1936 - val_accuracy: 0.3884
# Epoch 6/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.3136 - accuracy: 0.6158
# Epoch 00006: val_accuracy improved from 0.47730 to 0.56700, saving model to /content/saved_models/cifar10_Tesnet18.006.h5
# 390/390 [==============================] - 99s 253ms/step - loss: 1.3139 - accuracy: 0.6158 - val_loss: 1.4930 - val_accuracy: 0.5670
# Epoch 7/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2588 - accuracy: 0.6363
# Epoch 00007: val_accuracy did not improve from 0.56700
# 390/390 [==============================] - 97s 249ms/step - loss: 1.2583 - accuracy: 0.6364 - val_loss: 2.1216 - val_accuracy: 0.4651
# Epoch 8/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1969 - accuracy: 0.6571
# Epoch 00008: val_accuracy did not improve from 0.56700
# 390/390 [==============================] - 97s 248ms/step - loss: 1.1968 - accuracy: 0.6571 - val_loss: 2.1743 - val_accuracy: 0.3884
# Epoch 9/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1739 - accuracy: 0.6669
# Epoch 00009: val_accuracy improved from 0.56700 to 0.58590, saving model to /content/saved_models/cifar10_Tesnet18.009.h5
# 390/390 [==============================] - 98s 251ms/step - loss: 1.1740 - accuracy: 0.6669 - val_loss: 1.3787 - val_accuracy: 0.5859
# Epoch 10/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1341 - accuracy: 0.6800
# Epoch 00010: val_accuracy improved from 0.58590 to 0.63610, saving model to /content/saved_models/cifar10_Tesnet18.010.h5
# 390/390 [==============================] - 97s 249ms/step - loss: 1.1339 - accuracy: 0.6800 - val_loss: 1.2286 - val_accuracy: 0.6361
# Epoch 11/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1016 - accuracy: 0.6884
# Epoch 00011: val_accuracy did not improve from 0.63610
# 390/390 [==============================] - 96s 247ms/step - loss: 1.1014 - accuracy: 0.6885 - val_loss: 1.3446 - val_accuracy: 0.6100
# Epoch 12/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0811 - accuracy: 0.6984
# Epoch 00012: val_accuracy did not improve from 0.63610
# 390/390 [==============================] - 97s 248ms/step - loss: 1.0813 - accuracy: 0.6983 - val_loss: 1.3533 - val_accuracy: 0.6150
# Epoch 13/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0653 - accuracy: 0.7003
# Epoch 00013: val_accuracy did not improve from 0.63610
# 390/390 [==============================] - 97s 247ms/step - loss: 1.0651 - accuracy: 0.7004 - val_loss: 1.6858 - val_accuracy: 0.5124
# Epoch 14/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0479 - accuracy: 0.7081
# Epoch 00014: val_accuracy did not improve from 0.63610
# 390/390 [==============================] - 96s 246ms/step - loss: 1.0477 - accuracy: 0.7082 - val_loss: 1.5951 - val_accuracy: 0.5627
# Epoch 15/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0354 - accuracy: 0.7121
# Epoch 00015: val_accuracy did not improve from 0.63610
# 390/390 [==============================] - 97s 248ms/step - loss: 1.0353 - accuracy: 0.7122 - val_loss: 1.6867 - val_accuracy: 0.5683
# Epoch 16/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8903 - accuracy: 0.7561
# Epoch 00016: val_accuracy improved from 0.63610 to 0.70070, saving model to /content/saved_models/cifar10_Tesnet18.016.h5
# 390/390 [==============================] - 96s 247ms/step - loss: 0.8900 - accuracy: 0.7561 - val_loss: 1.0394 - val_accuracy: 0.7007
# Epoch 17/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8396 - accuracy: 0.7674
# Epoch 00017: val_accuracy improved from 0.70070 to 0.71890, saving model to /content/saved_models/cifar10_Tesnet18.017.h5
# 390/390 [==============================] - 96s 247ms/step - loss: 0.8396 - accuracy: 0.7673 - val_loss: 0.9637 - val_accuracy: 0.7189
# Epoch 18/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8241 - accuracy: 0.7680
# Epoch 00018: val_accuracy did not improve from 0.71890
# 390/390 [==============================] - 96s 247ms/step - loss: 0.8241 - accuracy: 0.7679 - val_loss: 1.0623 - val_accuracy: 0.6776
# Epoch 19/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8023 - accuracy: 0.7721
# Epoch 00019: val_accuracy did not improve from 0.71890
# 390/390 [==============================] - 96s 247ms/step - loss: 0.8022 - accuracy: 0.7721 - val_loss: 1.0170 - val_accuracy: 0.6986
# Epoch 20/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7911 - accuracy: 0.7752
# Epoch 00020: val_accuracy improved from 0.71890 to 0.72860, saving model to /content/saved_models/cifar10_Tesnet18.020.h5
# 390/390 [==============================] - 96s 247ms/step - loss: 0.7910 - accuracy: 0.7753 - val_loss: 0.9297 - val_accuracy: 0.7286
# Epoch 21/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7693 - accuracy: 0.7787
# Epoch 00021: val_accuracy did not improve from 0.72860
# 390/390 [==============================] - 96s 247ms/step - loss: 0.7693 - accuracy: 0.7787 - val_loss: 1.0256 - val_accuracy: 0.6966
# Epoch 22/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7692 - accuracy: 0.7820
# Epoch 00022: val_accuracy did not improve from 0.72860
# 390/390 [==============================] - 96s 247ms/step - loss: 0.7692 - accuracy: 0.7820 - val_loss: 1.0174 - val_accuracy: 0.6871
# Epoch 23/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7578 - accuracy: 0.7834
# Epoch 00023: val_accuracy did not improve from 0.72860
# 390/390 [==============================] - 96s 246ms/step - loss: 0.7580 - accuracy: 0.7834 - val_loss: 0.9199 - val_accuracy: 0.7276
# Epoch 24/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7518 - accuracy: 0.7834
# Epoch 00024: val_accuracy did not improve from 0.72860
# 390/390 [==============================] - 96s 246ms/step - loss: 0.7515 - accuracy: 0.7835 - val_loss: 1.0356 - val_accuracy: 0.6960
# Epoch 25/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7407 - accuracy: 0.7894
# Epoch 00025: val_accuracy did not improve from 0.72860
# 390/390 [==============================] - 99s 253ms/step - loss: 0.7403 - accuracy: 0.7895 - val_loss: 1.0097 - val_accuracy: 0.6982
# Epoch 26/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7430 - accuracy: 0.7887
# Epoch 00026: val_accuracy did not improve from 0.72860
# 390/390 [==============================] - 98s 251ms/step - loss: 0.7431 - accuracy: 0.7887 - val_loss: 1.0119 - val_accuracy: 0.7044
# Epoch 27/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7401 - accuracy: 0.7885
# Epoch 00027: val_accuracy did not improve from 0.72860
# 390/390 [==============================] - 96s 246ms/step - loss: 0.7400 - accuracy: 0.7885 - val_loss: 0.9994 - val_accuracy: 0.7083
# Epoch 28/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7328 - accuracy: 0.7912
# Epoch 00028: val_accuracy improved from 0.72860 to 0.74490, saving model to /content/saved_models/cifar10_Tesnet18.028.h5
# 390/390 [==============================] - 96s 247ms/step - loss: 0.7329 - accuracy: 0.7911 - val_loss: 0.8713 - val_accuracy: 0.7449
# Epoch 29/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7301 - accuracy: 0.7929
# Epoch 00029: val_accuracy did not improve from 0.74490
# 390/390 [==============================] - 96s 246ms/step - loss: 0.7302 - accuracy: 0.7930 - val_loss: 0.8955 - val_accuracy: 0.7402
# Epoch 30/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7186 - accuracy: 0.7970
# Epoch 00030: val_accuracy did not improve from 0.74490
# 390/390 [==============================] - 96s 245ms/step - loss: 0.7181 - accuracy: 0.7972 - val_loss: 0.8905 - val_accuracy: 0.7383
# Epoch 31/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7230 - accuracy: 0.7944
# Epoch 00031: val_accuracy did not improve from 0.74490
# 390/390 [==============================] - 96s 247ms/step - loss: 0.7231 - accuracy: 0.7944 - val_loss: 1.2573 - val_accuracy: 0.6304
# Epoch 32/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7169 - accuracy: 0.7959
# Epoch 00032: val_accuracy did not improve from 0.74490
# 390/390 [==============================] - 97s 249ms/step - loss: 0.7169 - accuracy: 0.7959 - val_loss: 1.2069 - val_accuracy: 0.6422
# Epoch 33/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7133 - accuracy: 0.7964
# Epoch 00033: val_accuracy did not improve from 0.74490
# 390/390 [==============================] - 96s 245ms/step - loss: 0.7133 - accuracy: 0.7964 - val_loss: 0.9317 - val_accuracy: 0.7189
# Epoch 34/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6491 - accuracy: 0.8190
# Epoch 00034: val_accuracy improved from 0.74490 to 0.78840, saving model to /content/saved_models/cifar10_Tesnet18.034.h5
# 390/390 [==============================] - 96s 246ms/step - loss: 0.6492 - accuracy: 0.8190 - val_loss: 0.7424 - val_accuracy: 0.7884
# Epoch 35/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6265 - accuracy: 0.8251
# Epoch 00035: val_accuracy did not improve from 0.78840
# 390/390 [==============================] - 97s 249ms/step - loss: 0.6265 - accuracy: 0.8251 - val_loss: 0.7604 - val_accuracy: 0.7791
# Epoch 36/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6119 - accuracy: 0.8283
# Epoch 00036: val_accuracy improved from 0.78840 to 0.79120, saving model to /content/saved_models/cifar10_Tesnet18.036.h5
# 390/390 [==============================] - 97s 249ms/step - loss: 0.6119 - accuracy: 0.8283 - val_loss: 0.7330 - val_accuracy: 0.7912
# Epoch 37/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6071 - accuracy: 0.8291
# Epoch 00037: val_accuracy did not improve from 0.79120
# 390/390 [==============================] - 96s 245ms/step - loss: 0.6068 - accuracy: 0.8293 - val_loss: 0.7392 - val_accuracy: 0.7851
# Epoch 38/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6004 - accuracy: 0.8316
# Epoch 00038: val_accuracy improved from 0.79120 to 0.80270, saving model to /content/saved_models/cifar10_Tesnet18.038.h5
# 390/390 [==============================] - 97s 248ms/step - loss: 0.6005 - accuracy: 0.8316 - val_loss: 0.6930 - val_accuracy: 0.8027
# Epoch 39/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5930 - accuracy: 0.8331
# Epoch 00039: val_accuracy did not improve from 0.80270
# 390/390 [==============================] - 98s 250ms/step - loss: 0.5929 - accuracy: 0.8331 - val_loss: 0.7026 - val_accuracy: 0.8011
# Epoch 40/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5897 - accuracy: 0.8361
# Epoch 00040: val_accuracy did not improve from 0.80270
# 390/390 [==============================] - 96s 245ms/step - loss: 0.5896 - accuracy: 0.8361 - val_loss: 0.7449 - val_accuracy: 0.7864
# Epoch 41/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5848 - accuracy: 0.8329
# Epoch 00041: val_accuracy improved from 0.80270 to 0.80690, saving model to /content/saved_models/cifar10_Tesnet18.041.h5
# 390/390 [==============================] - 96s 246ms/step - loss: 0.5847 - accuracy: 0.8330 - val_loss: 0.6567 - val_accuracy: 0.8069
# Epoch 42/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5755 - accuracy: 0.8379
# Epoch 00042: val_accuracy did not improve from 0.80690
# 390/390 [==============================] - 97s 248ms/step - loss: 0.5752 - accuracy: 0.8380 - val_loss: 0.7313 - val_accuracy: 0.7823
# Epoch 43/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5766 - accuracy: 0.8348
# Epoch 00043: val_accuracy did not improve from 0.80690
# 390/390 [==============================] - 96s 246ms/step - loss: 0.5769 - accuracy: 0.8347 - val_loss: 0.6709 - val_accuracy: 0.8023
# Epoch 44/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5642 - accuracy: 0.8390
# Epoch 00044: val_accuracy improved from 0.80690 to 0.80710, saving model to /content/saved_models/cifar10_Tesnet18.044.h5
# 390/390 [==============================] - 96s 247ms/step - loss: 0.5645 - accuracy: 0.8389 - val_loss: 0.6579 - val_accuracy: 0.8071
# Epoch 45/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5690 - accuracy: 0.8375
# Epoch 00045: val_accuracy did not improve from 0.80710
# 390/390 [==============================] - 96s 245ms/step - loss: 0.5690 - accuracy: 0.8374 - val_loss: 0.7435 - val_accuracy: 0.7742
# Epoch 46/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5644 - accuracy: 0.8383
# Epoch 00046: val_accuracy did not improve from 0.80710
# 390/390 [==============================] - 95s 245ms/step - loss: 0.5646 - accuracy: 0.8382 - val_loss: 0.6804 - val_accuracy: 0.7992
# Epoch 47/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5367 - accuracy: 0.8471
# Epoch 00047: val_accuracy improved from 0.80710 to 0.82430, saving model to /content/saved_models/cifar10_Tesnet18.047.h5
# 390/390 [==============================] - 96s 245ms/step - loss: 0.5366 - accuracy: 0.8471 - val_loss: 0.6108 - val_accuracy: 0.8243
# Epoch 48/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5300 - accuracy: 0.8494
# Epoch 00048: val_accuracy improved from 0.82430 to 0.82840, saving model to /content/saved_models/cifar10_Tesnet18.048.h5
# 390/390 [==============================] - 98s 251ms/step - loss: 0.5302 - accuracy: 0.8493 - val_loss: 0.6026 - val_accuracy: 0.8284
# Epoch 49/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5208 - accuracy: 0.8534
# Epoch 00049: val_accuracy improved from 0.82840 to 0.83090, saving model to /content/saved_models/cifar10_Tesnet18.049.h5
# 390/390 [==============================] - 96s 246ms/step - loss: 0.5209 - accuracy: 0.8534 - val_loss: 0.5826 - val_accuracy: 0.8309
# Epoch 50/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5207 - accuracy: 0.8529
# Epoch 00050: val_accuracy did not improve from 0.83090
# 390/390 [==============================] - 95s 244ms/step - loss: 0.5205 - accuracy: 0.8530 - val_loss: 0.6043 - val_accuracy: 0.8228

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test loss: 0.5736425711154938
# Test accuracy: 0.839
