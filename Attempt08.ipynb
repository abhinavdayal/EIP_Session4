# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavdayal/EIP_Session4/blob/master/Attempt08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, NumpyArrayIterator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import numpy as np
import os

# %%
# Training parameters
batch_size = 128
epochs = 50
data_augmentation = True
num_classes = 10

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=False,
                 dropout=0):
  
    #TODO: add dropout
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  use_bias=False,
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2_block(x, num_filters, downscale=False, first=False):
  
  # Residual path
  if first:
    y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1), batch_normalization=False, activation=None) # already getting activated input!
  else:  
    y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1))
  y = resnet_layer(inputs=y, num_filters=num_filters)

  # identity. Need to match the output for addition
  if first or downscale:
    x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1, strides = (2 if downscale else 1),  batch_normalization=False, activation=None)

  # add
  x = keras.layers.add([x, y])

  return x

# %%
def resnet_v2(input_shape, res_blocks, num_classes=10):
    # Start model definition.
    num_filters = 16

    inputs = Input(shape=input_shape)

    # first convolution before Resnet starts.
    # Should this be done, because we dont want to modify the input
    # But in actual resnet they are doing 7x7, may be they are not doing BN or activation here!!!
    x = resnet_layer(inputs=inputs, num_filters=num_filters)

    # Instantiate the stack of residual units
    for i, blockcount in enumerate(res_blocks):
        num_filters = num_filters*2
        #num_filters *= 2
        for layer in range(blockcount):
          x = resnet_v2_block(x, num_filters=num_filters, downscale=i>0 and layer==0, first = layer==0 and i==0)

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes,
                    activation='softmax', use_bias=False,
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def lr_schedule(epoch):
    lr = round(0.01 * 1/(1 + 0.319 * epoch), 10)
    print('Learning rate: ', lr)
    return lr
    
model = resnet_v2(input_shape=input_shape, res_blocks=(2, 2, 2, 2))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# Learning rate:  0.01
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 3)    12          input_2[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 3)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 16)   432         activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 32)   4608        conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 32)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 32)   512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 32)   9216        activation_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 32)   0           conv2d_24[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 32)   128         add_8[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 32)   9216        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 32)   128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 32)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 32)   9216        activation_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 32)   0           add_8[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 32)   128         add_9[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 64)   18432       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 64)   2048        add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 64)   36864       activation_22[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 64)   0           conv2d_29[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 64)   256         add_10[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 64)   36864       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 64)   36864       activation_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 64)   0           add_10[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 64)   256         add_11[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 128)    73728       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 128)    512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 128)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 128)    8192        add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 128)    147456      activation_26[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 128)    0           conv2d_34[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 128)    512         add_12[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 128)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 128)    147456      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 128)    512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 128)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 128)    147456      activation_28[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 8, 8, 128)    0           add_12[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 128)    512         add_13[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 128)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 256)    294912      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 256)    1024        conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 4, 4, 256)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 4, 256)    32768       add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 256)    589824      activation_30[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 4, 256)    0           conv2d_39[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 256)    1024        add_14[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4, 4, 256)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 256)    589824      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 256)    1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 256)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 4, 4, 256)    589824      activation_32[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 4, 256)    0           add_14[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 4, 4, 256)    1024        add_15[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 4, 4, 256)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           activation_33[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           2560        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 2,795,964
# Trainable params: 2,792,118
# Non-trainable params: 3,846
# __________________________________________________________________________________________________

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_Tesnet18.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
    
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w # area of cutout
            r = np.random.uniform(r_1, r_2) # 
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
data_augmentation = False
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=20,
        # randomly shift images horizontally
        width_shift_range=0.2,
        # randomly shift images vertically
        height_shift_range=0.2,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.2,
        # set range for random channel shifts
        channel_shift_range=0.2,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=True),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    #datagen.fit(x_train)

    train_iter = NumpyArrayIterator(x=x_train, y=y_train, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    val_iter = NumpyArrayIterator(x=x_test, y=y_test, image_data_generator=datagen, batch_size=batch_size, shuffle=True)

    model.fit_generator(generator = train_iter,
                        steps_per_epoch = (x_train.shape[0]//batch_size), epochs = 50, 
                        validation_data = val_iter, verbose=1, workers=4, callbacks=callbacks)
# Out:
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Learning rate:  0.01
# Epoch 1/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.8656 - accuracy: 0.3942
# Epoch 00001: val_accuracy improved from -inf to 0.36440, saving model to /content/saved_models/cifar10_Tesnet18.001.h5
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.8649 - accuracy: 0.3944 - val_loss: 1.9377 - val_accuracy: 0.3644
# Learning rate:  0.0075815011
# Epoch 2/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.3638 - accuracy: 0.5655
# Epoch 00002: val_accuracy improved from 0.36440 to 0.43930, saving model to /content/saved_models/cifar10_Tesnet18.002.h5
# 50000/50000 [==============================] - 43s 870us/sample - loss: 1.3635 - accuracy: 0.5657 - val_loss: 1.7982 - val_accuracy: 0.4393
# Learning rate:  0.0061050061
# Epoch 3/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.1877 - accuracy: 0.6329
# Epoch 00003: val_accuracy improved from 0.43930 to 0.57110, saving model to /content/saved_models/cifar10_Tesnet18.003.h5
# 50000/50000 [==============================] - 44s 871us/sample - loss: 1.1876 - accuracy: 0.6328 - val_loss: 1.3478 - val_accuracy: 0.5711
# Learning rate:  0.005109862
# Epoch 4/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.0796 - accuracy: 0.6734
# Epoch 00004: val_accuracy did not improve from 0.57110
# 50000/50000 [==============================] - 43s 867us/sample - loss: 1.0793 - accuracy: 0.6735 - val_loss: 1.4672 - val_accuracy: 0.5424
# Learning rate:  0.0043936731
# Epoch 5/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.9809 - accuracy: 0.7116
# Epoch 00005: val_accuracy improved from 0.57110 to 0.60590, saving model to /content/saved_models/cifar10_Tesnet18.005.h5
# 50000/50000 [==============================] - 44s 871us/sample - loss: 0.9808 - accuracy: 0.7116 - val_loss: 1.3287 - val_accuracy: 0.6059
# Learning rate:  0.0038535645
# Epoch 6/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.9031 - accuracy: 0.7400
# Epoch 00006: val_accuracy did not improve from 0.60590
# 50000/50000 [==============================] - 43s 867us/sample - loss: 0.9030 - accuracy: 0.7401 - val_loss: 1.6270 - val_accuracy: 0.5221
# Learning rate:  0.003431709
# Epoch 7/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.8385 - accuracy: 0.7640
# Epoch 00007: val_accuracy improved from 0.60590 to 0.70470, saving model to /content/saved_models/cifar10_Tesnet18.007.h5
# 50000/50000 [==============================] - 43s 867us/sample - loss: 0.8383 - accuracy: 0.7641 - val_loss: 1.0524 - val_accuracy: 0.7047
# Learning rate:  0.0030931024
# Epoch 8/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7743 - accuracy: 0.7886
# Epoch 00008: val_accuracy did not improve from 0.70470
# 50000/50000 [==============================] - 43s 865us/sample - loss: 0.7743 - accuracy: 0.7886 - val_loss: 1.3133 - val_accuracy: 0.5923
# Learning rate:  0.0028153153
# Epoch 9/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7202 - accuracy: 0.8046
# Epoch 00009: val_accuracy did not improve from 0.70470
# 50000/50000 [==============================] - 43s 864us/sample - loss: 0.7200 - accuracy: 0.8047 - val_loss: 1.4805 - val_accuracy: 0.5914
# Learning rate:  0.0025833118
# Epoch 10/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6784 - accuracy: 0.8207
# Epoch 00010: val_accuracy improved from 0.70470 to 0.72470, saving model to /content/saved_models/cifar10_Tesnet18.010.h5
# 50000/50000 [==============================] - 43s 870us/sample - loss: 0.6784 - accuracy: 0.8206 - val_loss: 1.0369 - val_accuracy: 0.7247
# Learning rate:  0.0023866348
# Epoch 11/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.6315 - accuracy: 0.8380
# Epoch 00011: val_accuracy did not improve from 0.72470
# 50000/50000 [==============================] - 43s 864us/sample - loss: 0.6317 - accuracy: 0.8380 - val_loss: 1.1059 - val_accuracy: 0.7187
# Learning rate:  0.0022177866
# Epoch 12/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5970 - accuracy: 0.8493
# Epoch 00012: val_accuracy did not improve from 0.72470
# 50000/50000 [==============================] - 43s 867us/sample - loss: 0.5970 - accuracy: 0.8493 - val_loss: 1.0521 - val_accuracy: 0.7236
# Learning rate:  0.002071251
# Epoch 13/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5653 - accuracy: 0.8589
# Epoch 00013: val_accuracy did not improve from 0.72470
# 50000/50000 [==============================] - 43s 864us/sample - loss: 0.5653 - accuracy: 0.8589 - val_loss: 1.1951 - val_accuracy: 0.7000
# Learning rate:  0.0019428793
# Epoch 14/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5249 - accuracy: 0.8742
# Epoch 00014: val_accuracy improved from 0.72470 to 0.75290, saving model to /content/saved_models/cifar10_Tesnet18.014.h5
# 50000/50000 [==============================] - 44s 871us/sample - loss: 0.5249 - accuracy: 0.8742 - val_loss: 1.0268 - val_accuracy: 0.7529
# Learning rate:  0.0018294914
# Epoch 15/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5012 - accuracy: 0.8810
# Epoch 00015: val_accuracy improved from 0.75290 to 0.76760, saving model to /content/saved_models/cifar10_Tesnet18.015.h5
# 50000/50000 [==============================] - 44s 870us/sample - loss: 0.5012 - accuracy: 0.8810 - val_loss: 0.9073 - val_accuracy: 0.7676
# Learning rate:  0.0017286085
# Epoch 16/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.4659 - accuracy: 0.8954
# Epoch 00016: val_accuracy improved from 0.76760 to 0.77390, saving model to /content/saved_models/cifar10_Tesnet18.016.h5
# 50000/50000 [==============================] - 44s 872us/sample - loss: 0.4664 - accuracy: 0.8952 - val_loss: 0.9351 - val_accuracy: 0.7739
# Learning rate:  0.00163827
# Epoch 17/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.4385 - accuracy: 0.9033
# Epoch 00017: val_accuracy did not improve from 0.77390
# 50000/50000 [==============================] - 43s 866us/sample - loss: 0.4385 - accuracy: 0.9034 - val_loss: 0.9424 - val_accuracy: 0.7597
# Learning rate:  0.0015569049
# Epoch 18/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.4098 - accuracy: 0.9135
# Epoch 00018: val_accuracy improved from 0.77390 to 0.78120, saving model to /content/saved_models/cifar10_Tesnet18.018.h5
# 50000/50000 [==============================] - 44s 872us/sample - loss: 0.4100 - accuracy: 0.9135 - val_loss: 0.9786 - val_accuracy: 0.7812
# Learning rate:  0.0014832394
# Epoch 19/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.3870 - accuracy: 0.9201
# Epoch 00019: val_accuracy improved from 0.78120 to 0.79670, saving model to /content/saved_models/cifar10_Tesnet18.019.h5
# 50000/50000 [==============================] - 44s 871us/sample - loss: 0.3871 - accuracy: 0.9201 - val_loss: 0.8524 - val_accuracy: 0.7967
# Learning rate:  0.00141623
# Epoch 20/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.3627 - accuracy: 0.9296
# Epoch 00020: val_accuracy improved from 0.79670 to 0.80090, saving model to /content/saved_models/cifar10_Tesnet18.020.h5
# 50000/50000 [==============================] - 43s 870us/sample - loss: 0.3628 - accuracy: 0.9296 - val_loss: 0.8849 - val_accuracy: 0.8009
# Learning rate:  0.0013550136
# Epoch 21/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.3383 - accuracy: 0.9372
# Epoch 00021: val_accuracy did not improve from 0.80090
# 50000/50000 [==============================] - 43s 863us/sample - loss: 0.3384 - accuracy: 0.9372 - val_loss: 1.0695 - val_accuracy: 0.7707
# Learning rate:  0.00129887
# Epoch 22/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.3163 - accuracy: 0.9458
# Epoch 00022: val_accuracy did not improve from 0.80090
# 50000/50000 [==============================] - 43s 866us/sample - loss: 0.3163 - accuracy: 0.9457 - val_loss: 1.1063 - val_accuracy: 0.7636
# Learning rate:  0.0012471938
# Epoch 23/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.2997 - accuracy: 0.9511
# Epoch 00023: val_accuracy did not improve from 0.80090
# 50000/50000 [==============================] - 43s 863us/sample - loss: 0.2999 - accuracy: 0.9510 - val_loss: 1.2257 - val_accuracy: 0.7490
# Learning rate:  0.0011994722
# Epoch 24/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.2836 - accuracy: 0.9558
# Epoch 00024: val_accuracy did not improve from 0.80090
# 50000/50000 [==============================] - 43s 864us/sample - loss: 0.2837 - accuracy: 0.9558 - val_loss: 1.0746 - val_accuracy: 0.7831
# Learning rate:  0.001155268
# Epoch 25/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.2721 - accuracy: 0.9598
# Epoch 00025: val_accuracy did not improve from 0.80090
# 50000/50000 [==============================] - 43s 864us/sample - loss: 0.2721 - accuracy: 0.9598 - val_loss: 1.0640 - val_accuracy: 0.7870
# Learning rate:  0.0011142061
# Epoch 26/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.2527 - accuracy: 0.9666
# Epoch 00026: val_accuracy did not improve from 0.80090
# 50000/50000 [==============================] - 43s 866us/sample - loss: 0.2528 - accuracy: 0.9666 - val_loss: 1.0540 - val_accuracy: 0.8000
# Learning rate:  0.001075963
# Epoch 27/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.2482 - accuracy: 0.9677
# Epoch 00027: val_accuracy did not improve from 0.80090
# 50000/50000 [==============================] - 43s 865us/sample - loss: 0.2482 - accuracy: 0.9677 - val_loss: 1.6484 - val_accuracy: 0.7147
# Learning rate:  0.001040258
# Epoch 28/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.2388 - accuracy: 0.9710
# Epoch 00028: val_accuracy did not improve from 0.80090
# 50000/50000 [==============================] - 43s 866us/sample - loss: 0.2388 - accuracy: 0.9709 - val_loss: 1.1013 - val_accuracy: 0.7971
# Learning rate:  0.0010068466
# Epoch 29/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.2271 - accuracy: 0.9740
# Epoch 00029: val_accuracy did not improve from 0.80090
# 50000/50000 [==============================] - 43s 865us/sample - loss: 0.2272 - accuracy: 0.9740 - val_loss: 1.2074 - val_accuracy: 0.7839
# Learning rate:  0.0009755146
# Epoch 30/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.2264 - accuracy: 0.9733
# Epoch 00030: val_accuracy did not improve from 0.80090
# 50000/50000 [==============================] - 43s 867us/sample - loss: 0.2264 - accuracy: 0.9732 - val_loss: 1.3273 - val_accuracy: 0.7751
# Learning rate:  0.0009460738
# Epoch 31/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.2076 - accuracy: 0.9798
# Epoch 00031: val_accuracy improved from 0.80090 to 0.80150, saving model to /content/saved_models/cifar10_Tesnet18.031.h5
# 50000/50000 [==============================] - 44s 871us/sample - loss: 0.2076 - accuracy: 0.9798 - val_loss: 1.1164 - val_accuracy: 0.8015
# Learning rate:  0.000918358
# Epoch 32/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.2088 - accuracy: 0.9790
# Epoch 00032: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 865us/sample - loss: 0.2088 - accuracy: 0.9790 - val_loss: 1.1464 - val_accuracy: 0.7975
# Learning rate:  0.0008922198
# Epoch 33/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.2067 - accuracy: 0.9792
# Epoch 00033: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 865us/sample - loss: 0.2067 - accuracy: 0.9792 - val_loss: 1.3219 - val_accuracy: 0.7895
# Learning rate:  0.0008675284
# Epoch 34/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1977 - accuracy: 0.9816
# Epoch 00034: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 865us/sample - loss: 0.1979 - accuracy: 0.9815 - val_loss: 1.4576 - val_accuracy: 0.7611
# Learning rate:  0.0008441668
# Epoch 35/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1955 - accuracy: 0.9820
# Epoch 00035: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 866us/sample - loss: 0.1954 - accuracy: 0.9820 - val_loss: 1.4704 - val_accuracy: 0.7691
# Learning rate:  0.0008220304
# Epoch 36/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1919 - accuracy: 0.9827
# Epoch 00036: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 866us/sample - loss: 0.1918 - accuracy: 0.9827 - val_loss: 1.3093 - val_accuracy: 0.7788
# Learning rate:  0.0008010253
# Epoch 37/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1857 - accuracy: 0.9840
# Epoch 00037: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 864us/sample - loss: 0.1858 - accuracy: 0.9840 - val_loss: 1.3515 - val_accuracy: 0.7777
# Learning rate:  0.0007810669
# Epoch 38/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1848 - accuracy: 0.9837
# Epoch 00038: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 866us/sample - loss: 0.1848 - accuracy: 0.9837 - val_loss: 1.2188 - val_accuracy: 0.7982
# Learning rate:  0.000762079
# Epoch 39/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1765 - accuracy: 0.9870
# Epoch 00039: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 866us/sample - loss: 0.1765 - accuracy: 0.9870 - val_loss: 1.2520 - val_accuracy: 0.7946
# Learning rate:  0.0007439923
# Epoch 40/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1707 - accuracy: 0.9882
# Epoch 00040: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 866us/sample - loss: 0.1708 - accuracy: 0.9882 - val_loss: 1.3926 - val_accuracy: 0.7820
# Learning rate:  0.0007267442
# Epoch 41/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1734 - accuracy: 0.9861
# Epoch 00041: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 864us/sample - loss: 0.1734 - accuracy: 0.9861 - val_loss: 1.2480 - val_accuracy: 0.8002
# Learning rate:  0.0007102777
# Epoch 42/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1647 - accuracy: 0.9896
# Epoch 00042: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 866us/sample - loss: 0.1648 - accuracy: 0.9896 - val_loss: 1.4246 - val_accuracy: 0.7828
# Learning rate:  0.0006945409
# Epoch 43/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1635 - accuracy: 0.9890
# Epoch 00043: val_accuracy did not improve from 0.80150
# 50000/50000 [==============================] - 43s 864us/sample - loss: 0.1636 - accuracy: 0.9890 - val_loss: 1.6063 - val_accuracy: 0.7681
# Learning rate:  0.0006794863
# Epoch 44/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1666 - accuracy: 0.9870
# Epoch 00044: val_accuracy improved from 0.80150 to 0.81440, saving model to /content/saved_models/cifar10_Tesnet18.044.h5
# 50000/50000 [==============================] - 44s 871us/sample - loss: 0.1667 - accuracy: 0.9869 - val_loss: 1.1908 - val_accuracy: 0.8144
# Learning rate:  0.0006650705
# Epoch 45/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1566 - accuracy: 0.9907
# Epoch 00045: val_accuracy did not improve from 0.81440
# 50000/50000 [==============================] - 43s 865us/sample - loss: 0.1566 - accuracy: 0.9907 - val_loss: 1.2270 - val_accuracy: 0.8113
# Learning rate:  0.0006512537
# Epoch 46/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1553 - accuracy: 0.9902
# Epoch 00046: val_accuracy did not improve from 0.81440
# 50000/50000 [==============================] - 43s 865us/sample - loss: 0.1553 - accuracy: 0.9902 - val_loss: 1.3468 - val_accuracy: 0.7892
# Learning rate:  0.0006379992
# Epoch 47/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1541 - accuracy: 0.9901
# Epoch 00047: val_accuracy did not improve from 0.81440
# 50000/50000 [==============================] - 43s 865us/sample - loss: 0.1542 - accuracy: 0.9901 - val_loss: 1.2492 - val_accuracy: 0.8044
# Learning rate:  0.0006252736
# Epoch 48/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1585 - accuracy: 0.9881
# Epoch 00048: val_accuracy did not improve from 0.81440
# 50000/50000 [==============================] - 43s 865us/sample - loss: 0.1586 - accuracy: 0.9880 - val_loss: 1.2283 - val_accuracy: 0.8111
# Learning rate:  0.0006130456
# Epoch 49/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1510 - accuracy: 0.9908
# Epoch 00049: val_accuracy did not improve from 0.81440
# 50000/50000 [==============================] - 43s 864us/sample - loss: 0.1510 - accuracy: 0.9908 - val_loss: 1.2600 - val_accuracy: 0.8009
# Learning rate:  0.0006012868
# Epoch 50/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.1473 - accuracy: 0.9908
# Epoch 00050: val_accuracy did not improve from 0.81440
# 50000/50000 [==============================] - 43s 866us/sample - loss: 0.1472 - accuracy: 0.9908 - val_loss: 1.5128 - val_accuracy: 0.7687

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test loss: 1.512761744594574
# Test accuracy: 0.7687
