# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavdayal/EIP_Session4/blob/master/Success03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, NumpyArrayIterator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import numpy as np
import os

# Training parameters
batch_size = 128
epochs = 50
data_augmentation = True
num_classes = 10

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
subtract_pixel_mean = True

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True,
                 dropout=0):
  
    #TODO: add dropout
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  use_bias=False,
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

def resnet_v1_block(x, num_filters, downscale=False, first=False):
  
  # Residual path
  y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1))
  y = resnet_layer(inputs=y, num_filters=num_filters, activation=None)

  # identity. Need to match the output for addition
  if first or downscale:
    x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1, strides = (2 if downscale else 1),  batch_normalization=False, activation=None)

  # add
  x = keras.layers.add([x, y])
  x = Activation('relu')(x)
  return x
  
def resnet_v1(input_shape, res_blocks, num_classes=10):
    # Start model definition.
    num_filters = 16

    inputs = Input(shape=input_shape)

    # first convolution before Resnet starts.
    # Should this be done, because we dont want to modify the input
    # But in actual resnet they are doing 7x7, may be they are not doing BN or activation here!!!
    x = resnet_layer(inputs=inputs, num_filters=num_filters)

    # Instantiate the stack of residual units
    for i, blockcount in enumerate(res_blocks):
        num_filters = num_filters*2
        #num_filters *= 2
        for layer in range(blockcount):
          x = resnet_v1_block(x, num_filters=num_filters, downscale=i>1 and layer==0, first = layer==0 and i<2)

    # Add classifier on top.
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes,
                    activation='softmax', use_bias=False,
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def lr_schedule(epoch):
    lr = 0.003 * pow(0.5, epoch//5)
    print("Learning rate = ", lr)
    return lr

model = resnet_v1(input_shape=input_shape, res_blocks=(2, 2, 2, 2))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_Resnet18.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)


# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w # area of cutout
            r = np.random.uniform(r_1, r_2) # 
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=20,
        # randomly shift images horizontally
        width_shift_range=0.2,
        # randomly shift images vertically
        height_shift_range=0.2,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.2,
        # set range for random channel shifts
        channel_shift_range=0,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    train_iter = NumpyArrayIterator(x=x_train, y=y_train, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    val_iter = NumpyArrayIterator(x=x_test, y=y_test, image_data_generator=datagen, batch_size=batch_size, shuffle=True)

    model.fit_generator(generator = train_iter,
                        steps_per_epoch = (x_train.shape[0]//batch_size), epochs = 50, 
                        validation_data = val_iter, verbose=1, workers=4, callbacks=callbacks)
# Out:
# TensorFlow 2.x selected.
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# Learning rate =  0.003
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   432         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   4608        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   9216        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   512         activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 32)   0           conv2d_3[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   9216        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9216        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           activation_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18432       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36864       activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   2048        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           conv2d_8[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   36864       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 64)   36864       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 64)   0           activation_6[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73728       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147456      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  8192        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 128)  0           conv2d_13[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147456      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  147456      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 128)  0           activation_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 128)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    294912      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 256)    1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    589824      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    32768       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 256)    1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 256)    0           conv2d_18[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 256)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    589824      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 256)    589824      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 256)    0           activation_14[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 256)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           2560        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 2,796,016
# Trainable params: 2,792,144
# Non-trainable params: 3,872
# __________________________________________________________________________________________________
# Using real-time data augmentation.
# Learning rate =  0.003
# Epoch 1/50
# 389/390 [============================>.] - ETA: 0s - loss: 2.1484 - accuracy: 0.3648
# Epoch 00001: val_accuracy improved from -inf to 0.38720, saving model to /content/saved_models/cifar10_Resnet18.001.h5
# 390/390 [==============================] - 124s 318ms/step - loss: 2.1473 - accuracy: 0.3651 - val_loss: 1.9331 - val_accuracy: 0.3872
# Learning rate =  0.003
# Epoch 2/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.5979 - accuracy: 0.5191
# Epoch 00002: val_accuracy improved from 0.38720 to 0.42740, saving model to /content/saved_models/cifar10_Resnet18.002.h5
# 390/390 [==============================] - 122s 313ms/step - loss: 1.5981 - accuracy: 0.5189 - val_loss: 1.8469 - val_accuracy: 0.4274
# Learning rate =  0.003
# Epoch 3/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.4067 - accuracy: 0.5947
# Epoch 00003: val_accuracy improved from 0.42740 to 0.47620, saving model to /content/saved_models/cifar10_Resnet18.003.h5
# 390/390 [==============================] - 121s 311ms/step - loss: 1.4062 - accuracy: 0.5949 - val_loss: 1.7016 - val_accuracy: 0.4762
# Learning rate =  0.003
# Epoch 4/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.3211 - accuracy: 0.6298
# Epoch 00004: val_accuracy improved from 0.47620 to 0.50600, saving model to /content/saved_models/cifar10_Resnet18.004.h5
# 390/390 [==============================] - 121s 311ms/step - loss: 1.3208 - accuracy: 0.6298 - val_loss: 1.6850 - val_accuracy: 0.5060
# Learning rate =  0.003
# Epoch 5/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2428 - accuracy: 0.6648
# Epoch 00005: val_accuracy improved from 0.50600 to 0.56760, saving model to /content/saved_models/cifar10_Resnet18.005.h5
# 390/390 [==============================] - 122s 312ms/step - loss: 1.2429 - accuracy: 0.6649 - val_loss: 1.6089 - val_accuracy: 0.5676
# Learning rate =  0.0015
# Epoch 6/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0461 - accuracy: 0.7250
# Epoch 00006: val_accuracy improved from 0.56760 to 0.62890, saving model to /content/saved_models/cifar10_Resnet18.006.h5
# 390/390 [==============================] - 122s 312ms/step - loss: 1.0457 - accuracy: 0.7251 - val_loss: 1.2721 - val_accuracy: 0.6289
# Learning rate =  0.0015
# Epoch 7/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9879 - accuracy: 0.7405
# Epoch 00007: val_accuracy improved from 0.62890 to 0.63780, saving model to /content/saved_models/cifar10_Resnet18.007.h5
# 390/390 [==============================] - 122s 313ms/step - loss: 0.9876 - accuracy: 0.7406 - val_loss: 1.3188 - val_accuracy: 0.6378
# Learning rate =  0.0015
# Epoch 8/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9482 - accuracy: 0.7568
# Epoch 00008: val_accuracy improved from 0.63780 to 0.71650, saving model to /content/saved_models/cifar10_Resnet18.008.h5
# 390/390 [==============================] - 122s 313ms/step - loss: 0.9481 - accuracy: 0.7569 - val_loss: 1.0487 - val_accuracy: 0.7165
# Learning rate =  0.0015
# Epoch 9/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.9155 - accuracy: 0.7676
# Epoch 00009: val_accuracy did not improve from 0.71650
# 390/390 [==============================] - 122s 312ms/step - loss: 0.9152 - accuracy: 0.7676 - val_loss: 1.5170 - val_accuracy: 0.5902
# Learning rate =  0.0015
# Epoch 10/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8785 - accuracy: 0.7808
# Epoch 00010: val_accuracy improved from 0.71650 to 0.74230, saving model to /content/saved_models/cifar10_Resnet18.010.h5
# 390/390 [==============================] - 122s 312ms/step - loss: 0.8787 - accuracy: 0.7807 - val_loss: 0.9833 - val_accuracy: 0.7423
# Learning rate =  0.00075
# Epoch 11/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7719 - accuracy: 0.8119
# Epoch 00011: val_accuracy improved from 0.74230 to 0.77580, saving model to /content/saved_models/cifar10_Resnet18.011.h5
# 390/390 [==============================] - 122s 312ms/step - loss: 0.7716 - accuracy: 0.8120 - val_loss: 0.8684 - val_accuracy: 0.7758
# Learning rate =  0.00075
# Epoch 12/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7296 - accuracy: 0.8239
# Epoch 00012: val_accuracy did not improve from 0.77580
# 390/390 [==============================] - 121s 311ms/step - loss: 0.7295 - accuracy: 0.8238 - val_loss: 0.9321 - val_accuracy: 0.7472
# Learning rate =  0.00075
# Epoch 13/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7069 - accuracy: 0.8279
# Epoch 00013: val_accuracy improved from 0.77580 to 0.79740, saving model to /content/saved_models/cifar10_Resnet18.013.h5
# 390/390 [==============================] - 121s 311ms/step - loss: 0.7070 - accuracy: 0.8278 - val_loss: 0.8051 - val_accuracy: 0.7974
# Learning rate =  0.00075
# Epoch 14/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6840 - accuracy: 0.8366
# Epoch 00014: val_accuracy did not improve from 0.79740
# 390/390 [==============================] - 121s 311ms/step - loss: 0.6840 - accuracy: 0.8367 - val_loss: 0.9350 - val_accuracy: 0.7524
# Learning rate =  0.00075
# Epoch 15/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6655 - accuracy: 0.8394
# Epoch 00015: val_accuracy improved from 0.79740 to 0.79880, saving model to /content/saved_models/cifar10_Resnet18.015.h5
# 390/390 [==============================] - 121s 311ms/step - loss: 0.6655 - accuracy: 0.8393 - val_loss: 0.7891 - val_accuracy: 0.7988
# Learning rate =  0.000375
# Epoch 16/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6015 - accuracy: 0.8590
# Epoch 00016: val_accuracy improved from 0.79880 to 0.83550, saving model to /content/saved_models/cifar10_Resnet18.016.h5
# 390/390 [==============================] - 122s 313ms/step - loss: 0.6016 - accuracy: 0.8590 - val_loss: 0.6847 - val_accuracy: 0.8355
# Learning rate =  0.000375
# Epoch 17/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5772 - accuracy: 0.8664
# Epoch 00017: val_accuracy improved from 0.83550 to 0.83640, saving model to /content/saved_models/cifar10_Resnet18.017.h5
# 390/390 [==============================] - 122s 312ms/step - loss: 0.5775 - accuracy: 0.8664 - val_loss: 0.6592 - val_accuracy: 0.8364
# Learning rate =  0.000375
# Epoch 18/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5637 - accuracy: 0.8688
# Epoch 00018: val_accuracy did not improve from 0.83640
# 390/390 [==============================] - 122s 312ms/step - loss: 0.5635 - accuracy: 0.8689 - val_loss: 0.7159 - val_accuracy: 0.8179
# Learning rate =  0.000375
# Epoch 19/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5442 - accuracy: 0.8763
# Epoch 00019: val_accuracy improved from 0.83640 to 0.84110, saving model to /content/saved_models/cifar10_Resnet18.019.h5
# 390/390 [==============================] - 122s 312ms/step - loss: 0.5441 - accuracy: 0.8764 - val_loss: 0.6371 - val_accuracy: 0.8411
# Learning rate =  0.000375
# Epoch 20/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5402 - accuracy: 0.8754
# Epoch 00020: val_accuracy improved from 0.84110 to 0.84720, saving model to /content/saved_models/cifar10_Resnet18.020.h5
# 390/390 [==============================] - 122s 312ms/step - loss: 0.5401 - accuracy: 0.8754 - val_loss: 0.6373 - val_accuracy: 0.8472
# Learning rate =  0.0001875
# Epoch 21/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4928 - accuracy: 0.8918
# Epoch 00021: val_accuracy improved from 0.84720 to 0.86350, saving model to /content/saved_models/cifar10_Resnet18.021.h5
# 390/390 [==============================] - 121s 311ms/step - loss: 0.4930 - accuracy: 0.8918 - val_loss: 0.5697 - val_accuracy: 0.8635
# Learning rate =  0.0001875
# Epoch 22/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4800 - accuracy: 0.8942
# Epoch 00022: val_accuracy improved from 0.86350 to 0.86510, saving model to /content/saved_models/cifar10_Resnet18.022.h5
# 390/390 [==============================] - 121s 311ms/step - loss: 0.4797 - accuracy: 0.8943 - val_loss: 0.5616 - val_accuracy: 0.8651
# Learning rate =  0.0001875
# Epoch 23/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4677 - accuracy: 0.8985
# Epoch 00023: val_accuracy did not improve from 0.86510
# 390/390 [==============================] - 122s 313ms/step - loss: 0.4675 - accuracy: 0.8986 - val_loss: 0.5689 - val_accuracy: 0.8637
# Learning rate =  0.0001875
# Epoch 24/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4630 - accuracy: 0.8994
# Epoch 00024: val_accuracy did not improve from 0.86510
# 390/390 [==============================] - 121s 311ms/step - loss: 0.4627 - accuracy: 0.8995 - val_loss: 0.6144 - val_accuracy: 0.8509
# Learning rate =  0.0001875
# Epoch 25/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4528 - accuracy: 0.9010
# Epoch 00025: val_accuracy improved from 0.86510 to 0.87070, saving model to /content/saved_models/cifar10_Resnet18.025.h5
# 390/390 [==============================] - 122s 314ms/step - loss: 0.4527 - accuracy: 0.9010 - val_loss: 0.5536 - val_accuracy: 0.8707
# Learning rate =  9.375e-05
# Epoch 26/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4263 - accuracy: 0.9086
# Epoch 00026: val_accuracy improved from 0.87070 to 0.87460, saving model to /content/saved_models/cifar10_Resnet18.026.h5
# 390/390 [==============================] - 122s 312ms/step - loss: 0.4263 - accuracy: 0.9086 - val_loss: 0.5255 - val_accuracy: 0.8746
# Learning rate =  9.375e-05
# Epoch 27/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4230 - accuracy: 0.9110
# Epoch 00027: val_accuracy improved from 0.87460 to 0.87850, saving model to /content/saved_models/cifar10_Resnet18.027.h5
# 390/390 [==============================] - 121s 311ms/step - loss: 0.4227 - accuracy: 0.9111 - val_loss: 0.5196 - val_accuracy: 0.8785
# Learning rate =  9.375e-05
# Epoch 28/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4163 - accuracy: 0.9125
# Epoch 00028: val_accuracy did not improve from 0.87850
# 390/390 [==============================] - 122s 312ms/step - loss: 0.4161 - accuracy: 0.9126 - val_loss: 0.5327 - val_accuracy: 0.8738
# Learning rate =  9.375e-05
# Epoch 29/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4071 - accuracy: 0.9155
# Epoch 00029: val_accuracy did not improve from 0.87850
# 390/390 [==============================] - 122s 313ms/step - loss: 0.4072 - accuracy: 0.9155 - val_loss: 0.5316 - val_accuracy: 0.8753
# Learning rate =  9.375e-05
# Epoch 30/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.4029 - accuracy: 0.9174
# Epoch 00030: val_accuracy did not improve from 0.87850
# 390/390 [==============================] - 121s 311ms/step - loss: 0.4030 - accuracy: 0.9173 - val_loss: 0.5216 - val_accuracy: 0.8751
# Learning rate =  4.6875e-05
# Epoch 31/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3938 - accuracy: 0.9194
# Epoch 00031: val_accuracy improved from 0.87850 to 0.88470, saving model to /content/saved_models/cifar10_Resnet18.031.h5
# 390/390 [==============================] - 122s 314ms/step - loss: 0.3937 - accuracy: 0.9195 - val_loss: 0.5008 - val_accuracy: 0.8847
# Learning rate =  4.6875e-05
# Epoch 32/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3835 - accuracy: 0.9227
# Epoch 00032: val_accuracy improved from 0.88470 to 0.88770, saving model to /content/saved_models/cifar10_Resnet18.032.h5
# 390/390 [==============================] - 122s 312ms/step - loss: 0.3832 - accuracy: 0.9228 - val_loss: 0.5005 - val_accuracy: 0.8877
# Learning rate =  4.6875e-05
# Epoch 33/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3798 - accuracy: 0.9237
# Epoch 00033: val_accuracy did not improve from 0.88770
# 390/390 [==============================] - 122s 312ms/step - loss: 0.3798 - accuracy: 0.9237 - val_loss: 0.4981 - val_accuracy: 0.8860
# Learning rate =  4.6875e-05
# Epoch 34/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3807 - accuracy: 0.9240
# Epoch 00034: val_accuracy did not improve from 0.88770
# 390/390 [==============================] - 122s 312ms/step - loss: 0.3807 - accuracy: 0.9239 - val_loss: 0.4971 - val_accuracy: 0.8862
# Learning rate =  4.6875e-05
# Epoch 35/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3771 - accuracy: 0.9247
# Epoch 00035: val_accuracy did not improve from 0.88770
# 390/390 [==============================] - 121s 311ms/step - loss: 0.3773 - accuracy: 0.9247 - val_loss: 0.5180 - val_accuracy: 0.8780
# Learning rate =  2.34375e-05
# Epoch 36/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3733 - accuracy: 0.9257
# Epoch 00036: val_accuracy improved from 0.88770 to 0.88990, saving model to /content/saved_models/cifar10_Resnet18.036.h5
# 390/390 [==============================] - 122s 313ms/step - loss: 0.3732 - accuracy: 0.9257 - val_loss: 0.4877 - val_accuracy: 0.8899
# Learning rate =  2.34375e-05
# Epoch 37/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3653 - accuracy: 0.9283
# Epoch 00037: val_accuracy did not improve from 0.88990
# 390/390 [==============================] - 122s 313ms/step - loss: 0.3654 - accuracy: 0.9283 - val_loss: 0.4920 - val_accuracy: 0.8893
# Learning rate =  2.34375e-05
# Epoch 38/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3595 - accuracy: 0.9300
# Epoch 00038: val_accuracy did not improve from 0.88990
# 390/390 [==============================] - 123s 314ms/step - loss: 0.3594 - accuracy: 0.9301 - val_loss: 0.4999 - val_accuracy: 0.8870
# Learning rate =  2.34375e-05
# Epoch 39/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3659 - accuracy: 0.9282
# Epoch 00039: val_accuracy did not improve from 0.88990
# 390/390 [==============================] - 122s 313ms/step - loss: 0.3662 - accuracy: 0.9281 - val_loss: 0.4917 - val_accuracy: 0.8863
# Learning rate =  2.34375e-05
# Epoch 40/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3607 - accuracy: 0.9304
# Epoch 00040: val_accuracy did not improve from 0.88990
# 390/390 [==============================] - 122s 313ms/step - loss: 0.3605 - accuracy: 0.9304 - val_loss: 0.5014 - val_accuracy: 0.8861
# Learning rate =  1.171875e-05
# Epoch 41/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3583 - accuracy: 0.9315
# Epoch 00041: val_accuracy improved from 0.88990 to 0.89010, saving model to /content/saved_models/cifar10_Resnet18.041.h5
# 390/390 [==============================] - 123s 315ms/step - loss: 0.3584 - accuracy: 0.9314 - val_loss: 0.4803 - val_accuracy: 0.8901
# Learning rate =  1.171875e-05
# Epoch 42/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3546 - accuracy: 0.9322
# Epoch 00042: val_accuracy did not improve from 0.89010
# 390/390 [==============================] - 122s 313ms/step - loss: 0.3545 - accuracy: 0.9322 - val_loss: 0.4803 - val_accuracy: 0.8898
# Learning rate =  1.171875e-05
# Epoch 43/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3529 - accuracy: 0.9318
# Epoch 00043: val_accuracy improved from 0.89010 to 0.89310, saving model to /content/saved_models/cifar10_Resnet18.043.h5
# 390/390 [==============================] - 122s 314ms/step - loss: 0.3529 - accuracy: 0.9317 - val_loss: 0.4733 - val_accuracy: 0.8931
# Learning rate =  1.171875e-05
# Epoch 44/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3536 - accuracy: 0.9320
# Epoch 00044: val_accuracy improved from 0.89310 to 0.89350, saving model to /content/saved_models/cifar10_Resnet18.044.h5
# 390/390 [==============================] - 122s 313ms/step - loss: 0.3538 - accuracy: 0.9319 - val_loss: 0.4805 - val_accuracy: 0.8935
# Learning rate =  1.171875e-05
# Epoch 45/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3520 - accuracy: 0.9320
# Epoch 00045: val_accuracy improved from 0.89350 to 0.89430, saving model to /content/saved_models/cifar10_Resnet18.045.h5
# 390/390 [==============================] - 123s 314ms/step - loss: 0.3519 - accuracy: 0.9321 - val_loss: 0.4803 - val_accuracy: 0.8943
# Learning rate =  5.859375e-06
# Epoch 46/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3520 - accuracy: 0.9325
# Epoch 00046: val_accuracy did not improve from 0.89430
# 390/390 [==============================] - 123s 315ms/step - loss: 0.3520 - accuracy: 0.9325 - val_loss: 0.4935 - val_accuracy: 0.8913
# Learning rate =  5.859375e-06
# Epoch 47/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3494 - accuracy: 0.9334
# Epoch 00047: val_accuracy did not improve from 0.89430
# 390/390 [==============================] - 122s 314ms/step - loss: 0.3493 - accuracy: 0.9334 - val_loss: 0.4833 - val_accuracy: 0.8930
# Learning rate =  5.859375e-06
# Epoch 48/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3481 - accuracy: 0.9338
# Epoch 00048: val_accuracy did not improve from 0.89430
# 390/390 [==============================] - 122s 313ms/step - loss: 0.3480 - accuracy: 0.9338 - val_loss: 0.4780 - val_accuracy: 0.8925
# Learning rate =  5.859375e-06
# Epoch 49/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3486 - accuracy: 0.9333
# Epoch 00049: val_accuracy did not improve from 0.89430
# 390/390 [==============================] - 122s 314ms/step - loss: 0.3486 - accuracy: 0.9333 - val_loss: 0.4945 - val_accuracy: 0.8884
# Learning rate =  5.859375e-06
# Epoch 50/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.3465 - accuracy: 0.9339
# Epoch 00050: val_accuracy did not improve from 0.89430
# 390/390 [==============================] - 122s 312ms/step - loss: 0.3464 - accuracy: 0.9340 - val_loss: 0.4766 - val_accuracy: 0.8900
