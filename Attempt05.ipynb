# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavdayal/EIP_Session4/blob/master/Attempt05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, NumpyArrayIterator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import numpy as np
import os
# Out:
# TensorFlow 2.x selected.

# %%
# Training parameters
batch_size = 128
epochs = 50
data_augmentation = True
num_classes = 10

# %%
# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
#if subtract_pixel_mean:
#    x_train_mean = np.mean(x_train, axis=0)
#    x_train -= x_train_mean
#    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def lr_schedule(epoch):
    lr = round(0.01 * 1/(1 + 0.319 * epoch), 10)
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True,
                 dropout=0):
  
    #TODO: add dropout
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  use_bias=False,
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if dropout > 0:
            x = Dropout(dropout)(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1_block(x, num_filters, downscale=False, first=False):
  
  # Residual path
  y = resnet_layer(inputs=x, num_filters=num_filters, strides = (2 if downscale else 1))
  y = resnet_layer(inputs=y, num_filters=num_filters, activation=None)

  # identity. Need to match the output for addition
  if first or downscale:
    x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1, strides = (2 if downscale else 1))

  # add
  x = keras.layers.add([x, y])
  x = Activation('relu')(x)

  return x

# %%
def resnet_v1(input_shape, res_blocks, num_classes=10):
    # Start model definition.
    

    inputs = Input(shape=input_shape)

    # first convolution before Resnet starts.
    # Should this be done, because we dont want to modify the input
    # But in actual resnet they are doing 7x7, may be they are not doing BN or activation here!!!
    x = resnet_layer(inputs=inputs, num_filters=16)

    num_filters = 64
    # Instantiate the stack of residual units
    for i, blockcount in enumerate(res_blocks):
        for layer in range(blockcount):
            x = resnet_v1_block(x, num_filters=num_filters, downscale=i>0 and layer==0, first = layer==0 and i==0)
        num_filters *= 2

    # Add classifier on top.
    x = AveragePooling2D(pool_size=4)(x)
    x = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax', use_bias=False,
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v1(input_shape=input_shape, res_blocks=(2, 2, 2, 2))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# Learning rate:  0.01
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   432         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   1024        activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   36864       activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 64)   0           activation_2[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   36864       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   36864       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  73728       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  8192        activation_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  147456      activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 128)  0           activation_7[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  147456      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  147456      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           activation_8[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 256)    294912      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    32768       activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 256)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 256)    1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 256)    589824      activation_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 256)    0           activation_12[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    589824      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 256)    589824      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           activation_13[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 512)    1179648     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 512)    131072      activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 512)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 512)    2359296     activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 512)    0           activation_17[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, 4, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 512)    2359296     activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, 4, 512)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 512)    2359296     activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 4, 4, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 512)    0           activation_18[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, 4, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 512)    0           activation_20[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5120        flatten[0][0]
# ==================================================================================================
# Total params: 11,155,696
# Trainable params: 11,146,064
# Non-trainable params: 9,632
# __________________________________________________________________________________________________

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_Tesnet18.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

#lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer]

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w # area of cutout
            r = np.random.uniform(r_1, r_2) # 
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=True,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=True,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=True),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    train_iter = NumpyArrayIterator(x=x_train, y=y_train, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    val_iter = NumpyArrayIterator(x=x_test, y=y_test, image_data_generator=datagen, batch_size=batch_size, shuffle=True)
    

    # Fit the model on the batches generated by datagen.flow().
    #model.fit_generator(,
    #                    val_iter,
    #                    epochs=epochs, verbose=1, workers=4,
    #                   callbacks=callbacks)
    model.fit_generator(generator = train_iter,
                        steps_per_epoch = (x_train.shape[0]//batch_size), epochs = 50, 
                        validation_data = val_iter, verbose=1, workers=4, callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/50
# 389/390 [============================>.] - ETA: 0s - loss: 3.2918 - accuracy: 0.2896
# Epoch 00001: val_accuracy improved from -inf to 0.14280, saving model to /content/saved_models/cifar10_Tesnet18.001.h5
# 390/390 [==============================] - 204s 524ms/step - loss: 3.2892 - accuracy: 0.2899 - val_loss: 3.1531 - val_accuracy: 0.1428
# Epoch 2/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.9584 - accuracy: 0.4101
# Epoch 00002: val_accuracy improved from 0.14280 to 0.29690, saving model to /content/saved_models/cifar10_Tesnet18.002.h5
# 390/390 [==============================] - 199s 509ms/step - loss: 1.9574 - accuracy: 0.4104 - val_loss: 2.1451 - val_accuracy: 0.2969
# Epoch 3/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.6530 - accuracy: 0.4987
# Epoch 00003: val_accuracy did not improve from 0.29690
# 390/390 [==============================] - 198s 508ms/step - loss: 1.6525 - accuracy: 0.4990 - val_loss: 3.8984 - val_accuracy: 0.2045
# Epoch 4/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.4932 - accuracy: 0.5540
# Epoch 00004: val_accuracy improved from 0.29690 to 0.47950, saving model to /content/saved_models/cifar10_Tesnet18.004.h5
# 390/390 [==============================] - 198s 508ms/step - loss: 1.4931 - accuracy: 0.5541 - val_loss: 1.7047 - val_accuracy: 0.4795
# Epoch 5/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.3793 - accuracy: 0.5910
# Epoch 00005: val_accuracy did not improve from 0.47950
# 390/390 [==============================] - 198s 508ms/step - loss: 1.3793 - accuracy: 0.5911 - val_loss: 2.6627 - val_accuracy: 0.3261
# Epoch 6/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.3088 - accuracy: 0.6158
# Epoch 00006: val_accuracy improved from 0.47950 to 0.48980, saving model to /content/saved_models/cifar10_Tesnet18.006.h5
# 390/390 [==============================] - 199s 510ms/step - loss: 1.3088 - accuracy: 0.6157 - val_loss: 1.6449 - val_accuracy: 0.4898
# Epoch 7/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2575 - accuracy: 0.6329
# Epoch 00007: val_accuracy improved from 0.48980 to 0.50430, saving model to /content/saved_models/cifar10_Tesnet18.007.h5
# 390/390 [==============================] - 199s 509ms/step - loss: 1.2574 - accuracy: 0.6330 - val_loss: 1.6231 - val_accuracy: 0.5043
# Epoch 8/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.2072 - accuracy: 0.6488
# Epoch 00008: val_accuracy did not improve from 0.50430
# 390/390 [==============================] - 197s 506ms/step - loss: 1.2068 - accuracy: 0.6490 - val_loss: 2.0276 - val_accuracy: 0.4609
# Epoch 9/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1747 - accuracy: 0.6607
# Epoch 00009: val_accuracy improved from 0.50430 to 0.56560, saving model to /content/saved_models/cifar10_Tesnet18.009.h5
# 390/390 [==============================] - 198s 507ms/step - loss: 1.1744 - accuracy: 0.6608 - val_loss: 1.4483 - val_accuracy: 0.5656
# Epoch 10/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1374 - accuracy: 0.6747
# Epoch 00010: val_accuracy improved from 0.56560 to 0.61830, saving model to /content/saved_models/cifar10_Tesnet18.010.h5
# 390/390 [==============================] - 198s 508ms/step - loss: 1.1373 - accuracy: 0.6748 - val_loss: 1.3032 - val_accuracy: 0.6183
# Epoch 11/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.1038 - accuracy: 0.6840
# Epoch 00011: val_accuracy did not improve from 0.61830
# 390/390 [==============================] - 197s 506ms/step - loss: 1.1038 - accuracy: 0.6840 - val_loss: 1.4782 - val_accuracy: 0.5856
# Epoch 12/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0802 - accuracy: 0.6931
# Epoch 00012: val_accuracy did not improve from 0.61830
# 390/390 [==============================] - 197s 506ms/step - loss: 1.0800 - accuracy: 0.6930 - val_loss: 1.3963 - val_accuracy: 0.5587
# Epoch 13/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0623 - accuracy: 0.6989
# Epoch 00013: val_accuracy did not improve from 0.61830
# 390/390 [==============================] - 197s 505ms/step - loss: 1.0619 - accuracy: 0.6990 - val_loss: 2.1779 - val_accuracy: 0.4351
# Epoch 14/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0461 - accuracy: 0.7027
# Epoch 00014: val_accuracy did not improve from 0.61830
# 390/390 [==============================] - 197s 506ms/step - loss: 1.0458 - accuracy: 0.7027 - val_loss: 1.6248 - val_accuracy: 0.5505
# Epoch 15/50
# 389/390 [============================>.] - ETA: 0s - loss: 1.0378 - accuracy: 0.7090
# Epoch 00015: val_accuracy did not improve from 0.61830
# 390/390 [==============================] - 197s 504ms/step - loss: 1.0375 - accuracy: 0.7091 - val_loss: 1.4409 - val_accuracy: 0.5769
# Epoch 16/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8940 - accuracy: 0.7525
# Epoch 00016: val_accuracy improved from 0.61830 to 0.71200, saving model to /content/saved_models/cifar10_Tesnet18.016.h5
# 390/390 [==============================] - 198s 507ms/step - loss: 0.8941 - accuracy: 0.7524 - val_loss: 0.9961 - val_accuracy: 0.7120
# Epoch 17/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8440 - accuracy: 0.7636
# Epoch 00017: val_accuracy did not improve from 0.71200
# 390/390 [==============================] - 197s 504ms/step - loss: 0.8446 - accuracy: 0.7634 - val_loss: 1.0493 - val_accuracy: 0.6832
# Epoch 18/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8249 - accuracy: 0.7675
# Epoch 00018: val_accuracy did not improve from 0.71200
# 390/390 [==============================] - 198s 508ms/step - loss: 0.8244 - accuracy: 0.7677 - val_loss: 1.0214 - val_accuracy: 0.6949
# Epoch 19/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.8077 - accuracy: 0.7698
# Epoch 00019: val_accuracy improved from 0.71200 to 0.73100, saving model to /content/saved_models/cifar10_Tesnet18.019.h5
# 390/390 [==============================] - 198s 508ms/step - loss: 0.8078 - accuracy: 0.7698 - val_loss: 0.9125 - val_accuracy: 0.7310
# Epoch 20/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7954 - accuracy: 0.7715
# Epoch 00020: val_accuracy improved from 0.73100 to 0.73560, saving model to /content/saved_models/cifar10_Tesnet18.020.h5
# 390/390 [==============================] - 198s 507ms/step - loss: 0.7952 - accuracy: 0.7715 - val_loss: 0.8973 - val_accuracy: 0.7356
# Epoch 21/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7853 - accuracy: 0.7763
# Epoch 00021: val_accuracy did not improve from 0.73560
# 390/390 [==============================] - 197s 505ms/step - loss: 0.7855 - accuracy: 0.7764 - val_loss: 1.1570 - val_accuracy: 0.6660
# Epoch 22/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7777 - accuracy: 0.7760
# Epoch 00022: val_accuracy did not improve from 0.73560
# 390/390 [==============================] - 197s 505ms/step - loss: 0.7778 - accuracy: 0.7759 - val_loss: 0.9044 - val_accuracy: 0.7313
# Epoch 23/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7693 - accuracy: 0.7769
# Epoch 00023: val_accuracy improved from 0.73560 to 0.73700, saving model to /content/saved_models/cifar10_Tesnet18.023.h5
# 390/390 [==============================] - 198s 507ms/step - loss: 0.7694 - accuracy: 0.7770 - val_loss: 0.8764 - val_accuracy: 0.7370
# Epoch 24/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7585 - accuracy: 0.7830
# Epoch 00024: val_accuracy did not improve from 0.73700
# 390/390 [==============================] - 196s 503ms/step - loss: 0.7591 - accuracy: 0.7827 - val_loss: 1.0611 - val_accuracy: 0.6918
# Epoch 25/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7492 - accuracy: 0.7838
# Epoch 00025: val_accuracy did not improve from 0.73700
# 390/390 [==============================] - 197s 504ms/step - loss: 0.7490 - accuracy: 0.7837 - val_loss: 1.1689 - val_accuracy: 0.6661
# Epoch 26/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7470 - accuracy: 0.7846
# Epoch 00026: val_accuracy did not improve from 0.73700
# 390/390 [==============================] - 198s 506ms/step - loss: 0.7469 - accuracy: 0.7847 - val_loss: 1.0472 - val_accuracy: 0.6910
# Epoch 27/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7441 - accuracy: 0.7836
# Epoch 00027: val_accuracy did not improve from 0.73700
# 390/390 [==============================] - 197s 505ms/step - loss: 0.7444 - accuracy: 0.7835 - val_loss: 0.9109 - val_accuracy: 0.7349
# Epoch 28/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.7420 - accuracy: 0.7859
# Epoch 00028: val_accuracy did not improve from 0.73700
# 390/390 [==============================] - 196s 504ms/step - loss: 0.7418 - accuracy: 0.7860 - val_loss: 0.9142 - val_accuracy: 0.7304
# Epoch 29/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6703 - accuracy: 0.8099
# Epoch 00029: val_accuracy improved from 0.73700 to 0.79210, saving model to /content/saved_models/cifar10_Tesnet18.029.h5
# 390/390 [==============================] - 195s 501ms/step - loss: 0.6699 - accuracy: 0.8101 - val_loss: 0.7347 - val_accuracy: 0.7921
# Epoch 30/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6507 - accuracy: 0.8157
# Epoch 00030: val_accuracy improved from 0.79210 to 0.79460, saving model to /content/saved_models/cifar10_Tesnet18.030.h5
# 390/390 [==============================] - 196s 503ms/step - loss: 0.6506 - accuracy: 0.8157 - val_loss: 0.7100 - val_accuracy: 0.7946
# Epoch 31/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6354 - accuracy: 0.8215
# Epoch 00031: val_accuracy did not improve from 0.79460
# 390/390 [==============================] - 200s 514ms/step - loss: 0.6354 - accuracy: 0.8214 - val_loss: 0.7450 - val_accuracy: 0.7852
# Epoch 32/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6267 - accuracy: 0.8202
# Epoch 00032: val_accuracy did not improve from 0.79460
# 390/390 [==============================] - 199s 510ms/step - loss: 0.6266 - accuracy: 0.8204 - val_loss: 0.7386 - val_accuracy: 0.7897
# Epoch 33/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6202 - accuracy: 0.8228
# Epoch 00033: val_accuracy improved from 0.79460 to 0.80410, saving model to /content/saved_models/cifar10_Tesnet18.033.h5
# 390/390 [==============================] - 199s 511ms/step - loss: 0.6201 - accuracy: 0.8229 - val_loss: 0.6830 - val_accuracy: 0.8041
# Epoch 34/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6154 - accuracy: 0.8241
# Epoch 00034: val_accuracy did not improve from 0.80410
# 390/390 [==============================] - 199s 510ms/step - loss: 0.6149 - accuracy: 0.8244 - val_loss: 0.6961 - val_accuracy: 0.7940
# Epoch 35/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6070 - accuracy: 0.8269
# Epoch 00035: val_accuracy did not improve from 0.80410
# 390/390 [==============================] - 198s 508ms/step - loss: 0.6070 - accuracy: 0.8269 - val_loss: 0.7117 - val_accuracy: 0.7904
# Epoch 36/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.6052 - accuracy: 0.8265
# Epoch 00036: val_accuracy did not improve from 0.80410
# 390/390 [==============================] - 198s 508ms/step - loss: 0.6050 - accuracy: 0.8265 - val_loss: 0.7122 - val_accuracy: 0.7889
# Epoch 37/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5955 - accuracy: 0.8291
# Epoch 00037: val_accuracy did not improve from 0.80410
# 390/390 [==============================] - 199s 510ms/step - loss: 0.5953 - accuracy: 0.8292 - val_loss: 0.7082 - val_accuracy: 0.7951
# Epoch 38/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5912 - accuracy: 0.8296
# Epoch 00038: val_accuracy did not improve from 0.80410
# 390/390 [==============================] - 198s 508ms/step - loss: 0.5910 - accuracy: 0.8296 - val_loss: 0.7411 - val_accuracy: 0.7770
# Epoch 39/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5695 - accuracy: 0.8378
# Epoch 00039: val_accuracy improved from 0.80410 to 0.81580, saving model to /content/saved_models/cifar10_Tesnet18.039.h5
# 390/390 [==============================] - 199s 511ms/step - loss: 0.5696 - accuracy: 0.8378 - val_loss: 0.6341 - val_accuracy: 0.8158
# Epoch 40/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5568 - accuracy: 0.8411
# Epoch 00040: val_accuracy improved from 0.81580 to 0.82120, saving model to /content/saved_models/cifar10_Tesnet18.040.h5
# 390/390 [==============================] - 200s 512ms/step - loss: 0.5569 - accuracy: 0.8411 - val_loss: 0.6125 - val_accuracy: 0.8212
# Epoch 41/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5466 - accuracy: 0.8452
# Epoch 00041: val_accuracy improved from 0.82120 to 0.82830, saving model to /content/saved_models/cifar10_Tesnet18.041.h5
# 390/390 [==============================] - 199s 511ms/step - loss: 0.5465 - accuracy: 0.8453 - val_loss: 0.6072 - val_accuracy: 0.8283
# Epoch 42/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5535 - accuracy: 0.8414
# Epoch 00042: val_accuracy did not improve from 0.82830
# 390/390 [==============================] - 199s 511ms/step - loss: 0.5531 - accuracy: 0.8415 - val_loss: 0.6134 - val_accuracy: 0.8228
# Epoch 43/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5503 - accuracy: 0.8424
# Epoch 00043: val_accuracy did not improve from 0.82830
# 390/390 [==============================] - 198s 508ms/step - loss: 0.5502 - accuracy: 0.8425 - val_loss: 0.6303 - val_accuracy: 0.8125
# Epoch 44/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5419 - accuracy: 0.8461
# Epoch 00044: val_accuracy did not improve from 0.82830
# 390/390 [==============================] - 199s 510ms/step - loss: 0.5421 - accuracy: 0.8460 - val_loss: 0.6112 - val_accuracy: 0.8246
# Epoch 45/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5427 - accuracy: 0.8451
# Epoch 00045: val_accuracy did not improve from 0.82830
# 390/390 [==============================] - 199s 510ms/step - loss: 0.5425 - accuracy: 0.8452 - val_loss: 0.6004 - val_accuracy: 0.8266
# Epoch 46/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5405 - accuracy: 0.8458
# Epoch 00046: val_accuracy did not improve from 0.82830
# 390/390 [==============================] - 199s 509ms/step - loss: 0.5403 - accuracy: 0.8459 - val_loss: 0.6166 - val_accuracy: 0.8181
# Epoch 47/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5335 - accuracy: 0.8488
# Epoch 00047: val_accuracy improved from 0.82830 to 0.82950, saving model to /content/saved_models/cifar10_Tesnet18.047.h5
# 390/390 [==============================] - 199s 511ms/step - loss: 0.5333 - accuracy: 0.8489 - val_loss: 0.5939 - val_accuracy: 0.8295
# Epoch 48/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5365 - accuracy: 0.8456
# Epoch 00048: val_accuracy did not improve from 0.82950
# 390/390 [==============================] - 199s 510ms/step - loss: 0.5364 - accuracy: 0.8457 - val_loss: 0.6071 - val_accuracy: 0.8264
# Epoch 49/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5323 - accuracy: 0.8462
# Epoch 00049: val_accuracy did not improve from 0.82950
# 390/390 [==============================] - 198s 508ms/step - loss: 0.5325 - accuracy: 0.8461 - val_loss: 0.5937 - val_accuracy: 0.8239
# Epoch 50/50
# 389/390 [============================>.] - ETA: 0s - loss: 0.5321 - accuracy: 0.8468
# Epoch 00050: val_accuracy did not improve from 0.82950
# 390/390 [==============================] - 199s 511ms/step - loss: 0.5322 - accuracy: 0.8468 - val_loss: 0.6027 - val_accuracy: 0.8249

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
